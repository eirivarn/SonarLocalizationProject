# %% [markdown]
# # Full Net Tracking Analysis: Multi-System Performance Assessment
#
# This notebook performs comprehensive analysis of synchronized comparison data from three net-tracking systems using the `comparison_analysis` utility module.
#
# **What this does:**
# 1. Loads and optionally smooths comparison data
# 2. Detects stable baseline segments
# 3. Computes noise, bias, and outlier statistics
# 4. Generates visualizations and summary reports
#
# **Quick Start:**
# 1. Set `TARGET_BAG` to your bag ID
# 2. Run all cells
# 3. Check outputs in comparison_data and plots directories
#
# #### **Generate for summary to csv for all of the available comparison data:**
# `Use defaults`
# python scripts/generate_bag_summary.py

# %% [markdown]
# ## Configuration

# %%
from pathlib import Path
from utils.comparison_analysis import (
    load_and_prepare_data,
    compute_pairwise_differences,
    detect_stable_segments,
    compute_baseline_statistics,
    detect_outliers,
    analyze_failure_correlation,
    create_visualizations,
    generate_summary_report,
    print_multi_bag_summary
)

# Configuration
TARGET_BAG = "2024-08-20_17-02-00"
COMPARISON_DATA_DIR = Path("/Volumes/LaCie/SOLAQUA/exports/basic_full_batch")
PLOTS_DIR = Path("/Volumes/LaCie/SOLAQUA/exports/plots")
PLOTS_DIR.mkdir(parents=True, exist_ok=True)

# Analysis parameters
SMOOTHING_ALPHA = None      # None = no smoothing, 0-1 = smoothing factor 
ROLLING_WINDOW_SEC = 2.0
SIGMA_THRESH = 0.25          # increase to allow more variance (e.g., 0.4 → 0.6)
DELTA_THRESH = 0.25          # increase to tolerate larger inter-system drift
MIN_SEGMENT_SEC = 1.0       # lower to accept shorter stable periods
OUTLIER_K = 3.5

print(f"Target: {TARGET_BAG}")
print(f"Smoothing: {'Disabled' if SMOOTHING_ALPHA is None else f'α={SMOOTHING_ALPHA:.2f}'}")
print(f"Stability thresholds: σ={SIGMA_THRESH}m, Δ={DELTA_THRESH}m")
# Out:
# Target: 2024-08-20_17-02-00
# Smoothing: Disabled
# Stability thresholds: σ=0.25m, Δ=0.25m

# %% [markdown]
# ## Load and Process Data

# %%
import pandas as pd
# Load comparison data strictly from the CSV on disk
data_path = COMPARISON_DATA_DIR / f"{TARGET_BAG}_raw_comparison.csv"
if not data_path.exists():
    raise FileNotFoundError(f"Comparison data not found: {data_path}")
print(f"Loading comparison dataset:\n  {data_path}")

ts_only = pd.read_csv(data_path, usecols=["sync_timestamp"], parse_dates=["sync_timestamp"])
ts_series = ts_only["sync_timestamp"].dropna().dt.tz_localize(None)
if ts_series.empty:
    raise ValueError("sync_timestamp column is empty in comparison CSV.")
ts_sorted = ts_series.sort_values()
sampling_interval = ts_sorted.diff().dt.total_seconds().median()
sampling_rate = 1.0 / sampling_interval if sampling_interval and sampling_interval > 0 else float("nan")
print(
    f"Data loaded: {len(ts_series)} timestamp samples\n"
    f"Time range (sync_timestamp): {ts_sorted.iloc[0]} to {ts_sorted.iloc[-1]}\n"
    f"Duration: {(ts_sorted.iloc[-1] - ts_sorted.iloc[0]).total_seconds():.1f} seconds\n"
    f"Median sampling interval: {sampling_interval:.3f} s ({(1.0 / sampling_interval) if sampling_interval else float('nan'):.1f} Hz)"
)

df = pd.read_csv(data_path)
df["sync_timestamp"] = pd.to_datetime(df["sync_timestamp"], errors="coerce", utc=True).dt.tz_localize(None)
df = df.sort_values("sync_timestamp").set_index("sync_timestamp")
available_systems = sorted({
    col.split("_", 1)[0].upper()
    for col in df.columns
    if col.startswith(("fft_", "sonar_", "nav_", "dvl_"))
})
print(f"Available systems: {', '.join(available_systems)}")

# Compute pairwise differences using the CSV-backed DataFrame
df = compute_pairwise_differences(df)
# Out:
# Loading comparison dataset:
#   /Volumes/LaCie/SOLAQUA/exports/basic_full_batch/2024-08-20_17-02-00_raw_comparison.csv
# Data loaded: 1851 timestamp samples
# Time range (sync_timestamp): 2024-08-20 15:02:03.319382668 to 2024-08-20 15:03:03.660551786
# Duration: 60.3 seconds
# Median sampling interval: 0.030 s (33.5 Hz)
# Available systems: DVL, FFT, NAV, SONAR
# Pairwise differences computed:
#   diff_fft_nav: 1739 valid samples, mean=-0.268, std=0.444
#   diff_sonar_nav: 1813 valid samples, mean=-0.143, std=0.383
#   diff_fft_sonar: 1769 valid samples, mean=-0.162, std=0.373
#   diff_pitch_fft_nav: 1739 valid samples, mean=5.272, std=17.470
#   diff_pitch_sonar_nav: 1813 valid samples, mean=-3.766, std=14.019
#   diff_pitch_fft_sonar: 1769 valid samples, mean=8.429, std=17.513
#   diff_x_fft_nav: 1739 valid samples, mean=-0.258, std=0.415
#   diff_x_sonar_nav: 1813 valid samples, mean=-0.125, std=0.345
#   diff_x_fft_sonar: 1769 valid samples, mean=-0.163, std=0.364
#   diff_y_fft_nav: 1739 valid samples, mean=0.101, std=0.227
#   diff_y_sonar_nav: 1813 valid samples, mean=-0.015, std=0.277
#   diff_y_fft_sonar: 1769 valid samples, mean=0.128, std=0.145

# %% [markdown]
# ## Detect Stable Baseline Segments

# %%
df, segments, window_samples = detect_stable_segments(
    df, sampling_rate,
    rolling_window_sec=ROLLING_WINDOW_SEC,
    sigma_thresh=SIGMA_THRESH,
    delta_thresh=DELTA_THRESH,
    min_segment_sec=MIN_SEGMENT_SEC
)
# Out:
# Rolling window: 67 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 1151 / 1851 (62.2%)
#
# Identifying stable baseline segments...
# Found 3 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 15:02:06 - 15:02:21 (15.2 s, 506 samples)
#   Segment 2: 15:02:23 - 15:02:24 (1.0 s, 34 samples)
#   Segment 3: 15:02:26 - 15:02:44 (17.7 s, 571 samples)

# %% [markdown]
# ## Baseline Statistics

# %%
baseline_stats = compute_baseline_statistics(df)
# Out:
# === BASELINE STATISTICS (1151 samples) ===
#
# 1. PER-METHOD NOISE - DISTANCE
#   FFT: σ = 0.0613 m, MAD = 0.0346 m
#   Sonar: σ = 0.0658 m, MAD = 0.0314 m
#   DVL: σ = 0.0618 m, MAD = 0.0297 m
#
# 2. PER-METHOD NOISE - PITCH
#   FFT: σ = 5.0700°, MAD = 4.2237°
#   Sonar: σ = 2.8335°, MAD = 2.1085°
#   DVL: σ = 4.1158°, MAD = 2.4626°
#
# 3. PER-METHOD NOISE - X POSITION
#   FFT: σ = 0.0632 m, MAD = 0.0360 m
#   Sonar: σ = 0.0643 m, MAD = 0.0305 m
#   DVL: σ = 0.0639 m, MAD = 0.0252 m
#
# 4. PER-METHOD NOISE - Y POSITION
#   FFT: σ = 0.0769 m, MAD = 0.0654 m
#   Sonar: σ = 0.0495 m, MAD = 0.0350 m
#   DVL: σ = 0.0699 m, MAD = 0.0439 m
#
# 5. PAIRWISE BIASES - DISTANCE
#   FFT vs DVL: Bias = -0.1263 m, Std = 0.0340 m
#   Sonar vs DVL: Bias = -0.0654 m, Std = 0.0445 m
#   FFT vs Sonar: Bias = -0.0609 m, Std = 0.0468 m
#
# 6. PAIRWISE BIASES - PITCH
#   FFT vs DVL: Bias = +5.8493 °, Std = 5.7936 °
#   Sonar vs DVL: Bias = -2.5253 °, Std = 3.9834 °
#   FFT vs Sonar: Bias = +8.3746 °, Std = 5.4126 °
#
# 7. PAIRWISE BIASES - X POSITION
#   FFT vs DVL: Bias = -0.1282 m, Std = 0.0392 m
#   Sonar vs DVL: Bias = -0.0667 m, Std = 0.0467 m
#   FFT vs Sonar: Bias = -0.0615 m, Std = 0.0474 m
#
# 8. PAIRWISE BIASES - Y POSITION
#   FFT vs DVL: Bias = +0.0960 m, Std = 0.0906 m
#   Sonar vs DVL: Bias = -0.0401 m, Std = 0.0684 m
#   FFT vs Sonar: Bias = +0.1360 m, Std = 0.0850 m
#
# 9. LINEAR RELATIONSHIPS (in baseline)
#   Distance - FFT vs DVL: R² = 0.7179
#   Distance - Sonar vs DVL: R² = 0.5750
#   Pitch - FFT vs DVL: R² = 0.0473
#   Pitch - Sonar vs DVL: R² = 0.1523

# %% [markdown]
# ## Outlier Detection

# %%
df, outlier_stats = detect_outliers(df, window_samples, outlier_k=OUTLIER_K)
correlation_stats = analyze_failure_correlation(df)
# Out:
# === OUTLIER DETECTION ===
#
# FFT: 226 outliers (12.21%), MAD = 0.0145 m
# Sonar: 343 outliers (18.53%), MAD = 0.0124 m
# DVL: 317 outliers (17.13%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.6251 m, Median: 0.5741 m, Max: 2.7162 m
#   Magnitude Categories:
#     Small (≤0.1946m): 78 (34.5%)
#     Medium (0.1946-0.8110m): 75 (33.2%)
#     Large (>0.8110m): 73 (32.3%)
#   Clustering:
#     Total clusters: 15
#     Avg cluster size: 16.1 frames
#     Max cluster size: 97 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 15 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1999 m, Median: 0.1301 m, Max: 0.8240 m
#   Magnitude Categories:
#     Small (≤0.0781m): 113 (32.9%)
#     Medium (0.0781-0.2098m): 122 (35.6%)
#     Large (>0.2098m): 108 (31.5%)
#   Clustering:
#     Total clusters: 28
#     Avg cluster size: 13.2 frames
#     Max cluster size: 107 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 28 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.4115 m, Median: 0.2350 m, Max: 1.9300 m
#   Magnitude Categories:
#     Small (≤0.1300m): 108 (34.1%)
#     Medium (0.1300-0.3650m): 106 (33.4%)
#     Large (>0.3650m): 103 (32.5%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 25.4 frames
#     Max cluster size: 75 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
#
# === FAILURE CORRELATION ===
#
# 1. INDIVIDUAL OUTLIER RATES
#   P(FFT outlier) = 12.21%
#   P(SONAR outlier) = 18.53%
#   P(DVL outlier) = 17.13%
#
# 2. CO-OCCURRENCE ANALYSIS
#   Jaccard(FFT, SONAR) = 0.180
#     P(SONAR outlier | FFT outlier) = 0.385
#     P(FFT outlier | SONAR outlier) = 0.254
#   Jaccard(FFT, DVL) = 0.389
#     P(DVL outlier | FFT outlier) = 0.673
#     P(FFT outlier | DVL outlier) = 0.479
#   Jaccard(SONAR, DVL) = 0.341
#     P(DVL outlier | SONAR outlier) = 0.490
#     P(SONAR outlier | DVL outlier) = 0.530

# %% [markdown]
# ## Generate Visualizations

# %%
print("\n=== GENERATING VISUALIZATIONS ===\n")

figs = create_visualizations(
    df, segments, TARGET_BAG, PLOTS_DIR,
    sigma_thresh=SIGMA_THRESH,
    outlier_k=OUTLIER_K
)

# Display plots
for name, fig in figs.items():
    print(f"\nDisplaying {name}...")
    fig.show()

print(f"\n✓ All plots saved to: {PLOTS_DIR}")
# Out:
# === GENERATING VISUALIZATIONS ===
# /Users/eirikvarnes/code/SOLAQUA/venv/lib/python3.13/site-packages/plotly/io/_json.py:558: UserWarning:
#
# Discarding nonzero nanoseconds in conversion.
# Saved: 2024-08-20_17-02-00_xy_positions.html
# Saved: 2024-08-20_17-02-00_timeseries.html
# Saved: 2024-08-20_17-02-00_stability.html
# Saved: 2024-08-20_17-02-00_stability.html
# Saved: 2024-08-20_17-02-00_outliers.html
# Saved: 2024-08-20_17-02-00_xy_positions.html
#
# Displaying timeseries...
# Saved: 2024-08-20_17-02-00_outliers.html
# Saved: 2024-08-20_17-02-00_xy_positions.html
#
# Displaying timeseries...
# Displaying stability...
# Displaying outliers...
# Displaying xy_positions...
# ✓ All plots saved to: /Volumes/LaCie/SOLAQUA/exports/plots

# %% [markdown]
# ## Generate Summary Report

# %%
config = {
    'Smoothing': f'α={SMOOTHING_ALPHA:.2f}' if SMOOTHING_ALPHA else 'Disabled',
    'Rolling Window': f'{ROLLING_WINDOW_SEC} s ({window_samples} samples)',
    'Stability σ Threshold': f'{SIGMA_THRESH} m',
    'Stability Δ Threshold': f'{DELTA_THRESH} m',
    'Min Segment Length': f'{MIN_SEGMENT_SEC} s',
    'Outlier Threshold': f'{OUTLIER_K} × MAD'
}

report_path = COMPARISON_DATA_DIR / f"{TARGET_BAG}_analysis_summary.md"
generate_summary_report(
    df, segments, baseline_stats, available_systems,
    TARGET_BAG, report_path, config, outlier_stats
)

print(f"\n✓ Analysis complete!")
print(f"  Plots: {PLOTS_DIR}")
print(f"  Report: {report_path}")
# Out:
# === GENERATING SUMMARY REPORT ===
#
# ✓ Summary report saved: 2024-08-20_17-02-00_analysis_summary.md
#   Location: /Volumes/LaCie/SOLAQUA/exports/basic_full_batch/2024-08-20_17-02-00_analysis_summary.md
#
# ✓ Analysis complete!
#   Plots: /Volumes/LaCie/SOLAQUA/exports/plots
#   Report: /Volumes/LaCie/SOLAQUA/exports/basic_full_batch/2024-08-20_17-02-00_analysis_summary.md
# ✓ Summary report saved: 2024-08-20_17-02-00_analysis_summary.md
#   Location: /Volumes/LaCie/SOLAQUA/exports/basic_full_batch/2024-08-20_17-02-00_analysis_summary.md
#
# ✓ Analysis complete!
#   Plots: /Volumes/LaCie/SOLAQUA/exports/plots
#   Report: /Volumes/LaCie/SOLAQUA/exports/basic_full_batch/2024-08-20_17-02-00_analysis_summary.md

# %%
# Regenerate the multi-bag summary CSV with all metrics
from utils.comparison_analysis import generate_multi_bag_summary_csv

print("Regenerating bag_summary.csv with all metrics...")
print("This may take a few minutes depending on the number of bags.\n")

output_path = generate_multi_bag_summary_csv(
    comparison_data_dir=COMPARISON_DATA_DIR,
    output_path=COMPARISON_DATA_DIR / "bag_summary.csv",
    smoothing_alpha=SMOOTHING_ALPHA,
    rolling_window_sec=ROLLING_WINDOW_SEC,
    sigma_thresh=SIGMA_THRESH,
    delta_thresh=DELTA_THRESH,
    min_segment_sec=MIN_SEGMENT_SEC,
    outlier_k=OUTLIER_K
)

if output_path:
    print("\n" + "="*70)
    print("✓ Summary CSV regenerated successfully!")
    print(f"  Location: {output_path}")
    print("\nThe summary now includes:")
    print("  ✓ Outlier magnitude metrics (mean, median, max)")
    print("  ✓ Outlier clustering analysis (cluster count, sizes)")
    print("  ✓ Isolated vs. multi-frame outlier statistics")
    print("\nRe-run the 'Multi-Bag Summary Analysis' cell above to see the updated statistics.")
else:
    print("\n✗ Failed to regenerate summary CSV")
# Out:
# Regenerating bag_summary.csv with all metrics...
# This may take a few minutes depending on the number of bags.
#
#
# === GENERATING MULTI-BAG SUMMARY CSV ===
#
# Found 46 bags to process
#
# Processing: ._2024-08-20_13-39-34
#   ✗ Error processing ._2024-08-20_13-39-34: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-40-35
#   ✗ Error processing ._2024-08-20_13-40-35: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-42-51
#   ✗ Error processing ._2024-08-20_13-42-51: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-55-34
#   ✗ Error processing ._2024-08-20_13-55-34: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-57-42
#   ✗ Error processing ._2024-08-20_13-57-42: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-16-05
#   ✗ Error processing ._2024-08-20_14-16-05: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-22-12
#   ✗ Error processing ._2024-08-20_14-22-12: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-24-35
#
# === GENERATING MULTI-BAG SUMMARY CSV ===
#
# Found 46 bags to process
#
# Processing: ._2024-08-20_13-39-34
#   ✗ Error processing ._2024-08-20_13-39-34: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-40-35
#   ✗ Error processing ._2024-08-20_13-40-35: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-42-51
#   ✗ Error processing ._2024-08-20_13-42-51: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-55-34
#   ✗ Error processing ._2024-08-20_13-55-34: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-57-42
#   ✗ Error processing ._2024-08-20_13-57-42: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-16-05
#   ✗ Error processing ._2024-08-20_14-16-05: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-22-12
#   ✗ Error processing ._2024-08-20_14-22-12: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-24-35
#   ✗ Error processing ._2024-08-20_14-24-35: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-31-29
#   ✗ Error processing ._2024-08-20_14-31-29: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-57-38
#   ✗ Error processing ._2024-08-20_14-57-38: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_15-00-24
#   ✗ Error processing ._2024-08-20_15-00-24: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_15-14-40
#   ✗ Error processing ._2024-08-20_15-14-40: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_16-57-46
#   ✗ Error processing ._2024-08-20_16-57-46: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-02-00
#   ✗ Error processing ._2024-08-20_17-02-00: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-08-14
#   ✗ Error processing ._2024-08-20_17-08-14: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-14-36
#   ✗ Error processing ._2024-08-20_17-14-36: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-39-32
#   ✗ Error processing ._2024-08-20_14-24-35: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-31-29
#   ✗ Error processing ._2024-08-20_14-31-29: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-57-38
#   ✗ Error processing ._2024-08-20_14-57-38: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_15-00-24
#   ✗ Error processing ._2024-08-20_15-00-24: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_15-14-40
#   ✗ Error processing ._2024-08-20_15-14-40: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_16-57-46
#   ✗ Error processing ._2024-08-20_16-57-46: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-02-00
#   ✗ Error processing ._2024-08-20_17-02-00: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-08-14
#   ✗ Error processing ._2024-08-20_17-08-14: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-14-36
#   ✗ Error processing ._2024-08-20_17-14-36: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-39-32
#   ✗ Error processing ._2024-08-20_17-39-32: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-40-54
#   ✗ Error processing ._2024-08-20_17-40-54: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_18-12-20
#   ✗ Error processing ._2024-08-20_18-12-20: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_18-47-40
#   ✗ Error processing ._2024-08-20_18-47-40: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-06-43
#   ✗ Error processing ._2024-08-20_17-39-32: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-40-54
#   ✗ Error processing ._2024-08-20_17-40-54: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_18-12-20
#   ✗ Error processing ._2024-08-20_18-12-20: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_18-47-40
#   ✗ Error processing ._2024-08-20_18-47-40: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-06-43
#   ✗ Error processing ._2024-08-22_14-06-43: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-29-05
#   ✗ Error processing ._2024-08-22_14-29-05: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-47-39
#   ✗ Error processing ._2024-08-22_14-47-39: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: 2024-08-20_13-39-34
#   ✗ Error processing ._2024-08-22_14-06-43: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-29-05
#   ✗ Error processing ._2024-08-22_14-29-05: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-47-39
#   ✗ Error processing ._2024-08-22_14-47-39: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: 2024-08-20_13-39-34
# Pairwise differences computed:
#   diff_fft_nav: 1453 valid samples, mean=-0.474, std=0.591
#   diff_sonar_nav: 1453 valid samples, mean=0.286, std=0.603
#   diff_fft_sonar: 1502 valid samples, mean=-0.760, std=0.230
#   diff_pitch_fft_nav: 1453 valid samples, mean=-8.567, std=19.733
#   diff_pitch_sonar_nav: 1453 valid samples, mean=-1.884, std=19.116
#   diff_pitch_fft_sonar: 1502 valid samples, mean=-6.107, std=18.991
#   diff_x_fft_nav: 1453 valid samples, mean=-0.436, std=0.609
#   diff_x_sonar_nav: 1453 valid samples, mean=0.247, std=0.650
#   diff_x_fft_sonar: 1502 valid samples, mean=-0.683, std=0.299
#   diff_y_fft_nav: 1453 valid samples, mean=-0.221, std=0.462
#   diff_y_sonar_nav: 1453 valid samples, mean=-0.054, std=0.484
#   diff_y_fft_sonar: 1502 valid samples, mean=-0.145, std=0.599
# Rolling window: 74 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1502 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 88 outliers (5.86%), MAD = 0.0350 m
# Sonar: 120 outliers (7.99%), MAD = 0.0386 m
# DVL: 385 outliers (25.63%), MAD = 0.0593 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3513 m, Median: 0.1845 m, Max: 1.5304 m
#   Magnitude Categories:
#     Small (≤0.1533m): 29 (33.0%)
#     Medium (0.1533-0.2195m): 30 (34.1%)
#     Large (>0.2195m): 29 (33.0%)
#   Clustering:
#     Total clusters: 23
#     Avg cluster size: 4.8 frames
#     Max cluster size: 12 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 23 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.2194 m, Median: 0.1793 m, Max: 0.4338 m
#   Magnitude Categories:
#     Small (≤0.1622m): 40 (33.3%)
#     Medium (0.1622-0.2199m): 42 (35.0%)
#     Large (>0.2199m): 38 (31.7%)
#   Clustering:
#     Total clusters: 17
#     Avg cluster size: 8.1 frames
#     Max cluster size: 25 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 17 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.6625 m, Median: 0.5600 m, Max: 1.5700 m
#   Magnitude Categories:
#     Small (≤0.3472m): 127 (33.0%)
#     Medium (0.3472-0.8000m): 133 (34.5%)
#     Large (>0.8000m): 125 (32.5%)
#   Clustering:
#     Total clusters: 41
#     Avg cluster size: 10.4 frames
#     Max cluster size: 35 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 41 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-40-35
# Pairwise differences computed:
#   diff_fft_nav: 1596 valid samples, mean=-0.379, std=0.779
#   diff_sonar_nav: 1596 valid samples, mean=0.190, std=0.410
#   diff_fft_sonar: 1610 valid samples, mean=-0.568, std=0.798
#   diff_pitch_fft_nav: 1596 valid samples, mean=-1.352, std=25.446
#   diff_pitch_sonar_nav: 1596 valid samples, mean=-3.301, std=14.074
#   diff_pitch_fft_sonar: 1610 valid samples, mean=2.115, std=29.706
#   diff_x_fft_nav: 1596 valid samples, mean=-0.351, std=0.749
#   diff_x_sonar_nav: 1596 valid samples, mean=0.067, std=0.374
#   diff_x_fft_sonar: 1610 valid samples, mean=-0.418, std=0.604
#   diff_y_fft_nav: 1596 valid samples, mean=-0.027, std=0.537
#   diff_y_sonar_nav: 1596 valid samples, mean=-0.206, std=0.474
#   diff_y_fft_sonar: 1610 valid samples, mean=0.184, std=0.851
# Rolling window: 75 samples (2.0 s)
#
# Computing rolling statistics...
# Pairwise differences computed:
#   diff_fft_nav: 1453 valid samples, mean=-0.474, std=0.591
#   diff_sonar_nav: 1453 valid samples, mean=0.286, std=0.603
#   diff_fft_sonar: 1502 valid samples, mean=-0.760, std=0.230
#   diff_pitch_fft_nav: 1453 valid samples, mean=-8.567, std=19.733
#   diff_pitch_sonar_nav: 1453 valid samples, mean=-1.884, std=19.116
#   diff_pitch_fft_sonar: 1502 valid samples, mean=-6.107, std=18.991
#   diff_x_fft_nav: 1453 valid samples, mean=-0.436, std=0.609
#   diff_x_sonar_nav: 1453 valid samples, mean=0.247, std=0.650
#   diff_x_fft_sonar: 1502 valid samples, mean=-0.683, std=0.299
#   diff_y_fft_nav: 1453 valid samples, mean=-0.221, std=0.462
#   diff_y_sonar_nav: 1453 valid samples, mean=-0.054, std=0.484
#   diff_y_fft_sonar: 1502 valid samples, mean=-0.145, std=0.599
# Rolling window: 74 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1502 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 88 outliers (5.86%), MAD = 0.0350 m
# Sonar: 120 outliers (7.99%), MAD = 0.0386 m
# DVL: 385 outliers (25.63%), MAD = 0.0593 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3513 m, Median: 0.1845 m, Max: 1.5304 m
#   Magnitude Categories:
#     Small (≤0.1533m): 29 (33.0%)
#     Medium (0.1533-0.2195m): 30 (34.1%)
#     Large (>0.2195m): 29 (33.0%)
#   Clustering:
#     Total clusters: 23
#     Avg cluster size: 4.8 frames
#     Max cluster size: 12 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 23 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.2194 m, Median: 0.1793 m, Max: 0.4338 m
#   Magnitude Categories:
#     Small (≤0.1622m): 40 (33.3%)
#     Medium (0.1622-0.2199m): 42 (35.0%)
#     Large (>0.2199m): 38 (31.7%)
#   Clustering:
#     Total clusters: 17
#     Avg cluster size: 8.1 frames
#     Max cluster size: 25 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 17 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.6625 m, Median: 0.5600 m, Max: 1.5700 m
#   Magnitude Categories:
#     Small (≤0.3472m): 127 (33.0%)
#     Medium (0.3472-0.8000m): 133 (34.5%)
#     Large (>0.8000m): 125 (32.5%)
#   Clustering:
#     Total clusters: 41
#     Avg cluster size: 10.4 frames
#     Max cluster size: 35 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 41 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-40-35
# Pairwise differences computed:
#   diff_fft_nav: 1596 valid samples, mean=-0.379, std=0.779
#   diff_sonar_nav: 1596 valid samples, mean=0.190, std=0.410
#   diff_fft_sonar: 1610 valid samples, mean=-0.568, std=0.798
#   diff_pitch_fft_nav: 1596 valid samples, mean=-1.352, std=25.446
#   diff_pitch_sonar_nav: 1596 valid samples, mean=-3.301, std=14.074
#   diff_pitch_fft_sonar: 1610 valid samples, mean=2.115, std=29.706
#   diff_x_fft_nav: 1596 valid samples, mean=-0.351, std=0.749
#   diff_x_sonar_nav: 1596 valid samples, mean=0.067, std=0.374
#   diff_x_fft_sonar: 1610 valid samples, mean=-0.418, std=0.604
#   diff_y_fft_nav: 1596 valid samples, mean=-0.027, std=0.537
#   diff_y_sonar_nav: 1596 valid samples, mean=-0.206, std=0.474
#   diff_y_fft_sonar: 1610 valid samples, mean=0.184, std=0.851
# Rolling window: 75 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 163 / 1611 (10.1%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 11:40:55 - 11:40:58 (2.2 s, 80 samples)
#   Segment 2: 11:41:21 - 11:41:23 (1.4 s, 49 samples)
# === OUTLIER DETECTION ===
#
# FFT: 158 outliers (9.81%), MAD = 0.0589 m
# Sonar: 142 outliers (8.81%), MAD = 0.0162 m
# DVL: 376 outliers (23.34%), MAD = 0.0741 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3776 m, Median: 0.2671 m, Max: 3.0585 m
#   Magnitude Categories:
#     Small (≤0.2466m): 53 (33.5%)
#     Medium (0.2466-0.3454m): 53 (33.5%)
#     Large (>0.3454m): 52 (32.9%)
#   Clustering:
#     Total clusters: 26
#     Avg cluster size: 7.0 frames
#     Max cluster size: 23 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 26 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1096 m, Median: 0.0965 m, Max: 0.2411 m
#   Magnitude Categories:
#     Small (≤0.0852m): 47 (33.1%)
#     Medium (0.0852-0.1104m): 48 (33.8%)
#     Large (>0.1104m): 47 (33.1%)
#   Clustering:
#     Total clusters: 15
#     Avg cluster size: 10.5 frames
#     Max cluster size: 49 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 15 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.4257 m, Median: 0.3400 m, Max: 1.2600 m
#   Magnitude Categories:
#     Small (≤0.3100m): 126 (33.5%)
#     Medium (0.3100-0.3800m): 126 (33.5%)
#     Large (>0.3800m): 124 (33.0%)
#   Clustering:
#     Total clusters: 37
#     Avg cluster size: 11.2 frames
#     Max cluster size: 66 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 37 (100.0%)
#
#   ✓ Processed 163 baseline samples, 2 stable segments
# Processing: 2024-08-20_13-42-51
# Pairwise differences computed:
#   diff_fft_nav: 1499 valid samples, mean=-0.973, std=0.990
#   diff_sonar_nav: 1590 valid samples, mean=2.839, std=3.066
#   diff_fft_sonar: 1515 valid samples, mean=-3.712, std=3.502
#   diff_pitch_fft_nav: 1499 valid samples, mean=6.985, std=35.772
#   diff_pitch_sonar_nav: 1590 valid samples, mean=34.180, std=48.403
#   diff_pitch_fft_sonar: 1515 valid samples, mean=-26.147, std=46.071
#   diff_x_fft_nav: 1499 valid samples, mean=-0.835, std=0.979
#   diff_x_sonar_nav: 1590 valid samples, mean=0.731, std=1.038
#   diff_x_fft_sonar: 1515 valid samples, mean=-1.552, std=1.311
#   diff_y_fft_nav: 1499 valid samples, mean=0.294, std=0.770
#   diff_y_sonar_nav: 1590 valid samples, mean=3.460, std=4.354
#   diff_y_fft_sonar: 1515 valid samples, mean=-2.982, std=4.174
# Rolling window: 67 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1612 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 309 outliers (19.17%), MAD = 0.0655 m
# Sonar: 372 outliers (23.08%), MAD = 0.0746 m
# DVL: 343 outliers (21.28%), MAD = 0.1186 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.0741 m, Median: 0.9207 m, Max: 4.6005 m
#   Magnitude Categories:
#     Small (≤0.7789m): 103 (33.3%)
#     Medium (0.7789-1.1217m): 105 (34.0%)
#     Large (>1.1217m): 101 (32.7%)
#   Clustering:
#     Total clusters: 31
#     Avg cluster size: 10.9 frames
#     Max cluster size: 48 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 31 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.6043 m, Median: 0.5472 m, Max: 1.4451 m
#   Magnitude Categories:
#     Small (≤0.3784m): 123 (33.1%)
#     Medium (0.3784-0.7123m): 126 (33.9%)
#     Large (>0.7123m): 123 (33.1%)
#   Clustering:
#     Total clusters: 32
#     Avg cluster size: 12.6 frames
#     Max cluster size: 49 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 32 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.8688 m, Median: 0.7000 m, Max: 2.3400 m
#   Magnitude Categories:
#     Small (≤0.5800m): 114 (33.2%)
#     Medium (0.5800-1.0000m): 121 (35.3%)
#     Large (>1.0000m): 108 (31.5%)
#   Clustering:
#     Total clusters: 34
#     Avg cluster size: 11.1 frames
#     Max cluster size: 62 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 34 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-55-34
# Applying stability criteria...
# Stable samples: 163 / 1611 (10.1%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 11:40:55 - 11:40:58 (2.2 s, 80 samples)
#   Segment 2: 11:41:21 - 11:41:23 (1.4 s, 49 samples)
# === OUTLIER DETECTION ===
#
# FFT: 158 outliers (9.81%), MAD = 0.0589 m
# Sonar: 142 outliers (8.81%), MAD = 0.0162 m
# DVL: 376 outliers (23.34%), MAD = 0.0741 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3776 m, Median: 0.2671 m, Max: 3.0585 m
#   Magnitude Categories:
#     Small (≤0.2466m): 53 (33.5%)
#     Medium (0.2466-0.3454m): 53 (33.5%)
#     Large (>0.3454m): 52 (32.9%)
#   Clustering:
#     Total clusters: 26
#     Avg cluster size: 7.0 frames
#     Max cluster size: 23 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 26 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1096 m, Median: 0.0965 m, Max: 0.2411 m
#   Magnitude Categories:
#     Small (≤0.0852m): 47 (33.1%)
#     Medium (0.0852-0.1104m): 48 (33.8%)
#     Large (>0.1104m): 47 (33.1%)
#   Clustering:
#     Total clusters: 15
#     Avg cluster size: 10.5 frames
#     Max cluster size: 49 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 15 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.4257 m, Median: 0.3400 m, Max: 1.2600 m
#   Magnitude Categories:
#     Small (≤0.3100m): 126 (33.5%)
#     Medium (0.3100-0.3800m): 126 (33.5%)
#     Large (>0.3800m): 124 (33.0%)
#   Clustering:
#     Total clusters: 37
#     Avg cluster size: 11.2 frames
#     Max cluster size: 66 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 37 (100.0%)
#
#   ✓ Processed 163 baseline samples, 2 stable segments
# Processing: 2024-08-20_13-42-51
# Pairwise differences computed:
#   diff_fft_nav: 1499 valid samples, mean=-0.973, std=0.990
#   diff_sonar_nav: 1590 valid samples, mean=2.839, std=3.066
#   diff_fft_sonar: 1515 valid samples, mean=-3.712, std=3.502
#   diff_pitch_fft_nav: 1499 valid samples, mean=6.985, std=35.772
#   diff_pitch_sonar_nav: 1590 valid samples, mean=34.180, std=48.403
#   diff_pitch_fft_sonar: 1515 valid samples, mean=-26.147, std=46.071
#   diff_x_fft_nav: 1499 valid samples, mean=-0.835, std=0.979
#   diff_x_sonar_nav: 1590 valid samples, mean=0.731, std=1.038
#   diff_x_fft_sonar: 1515 valid samples, mean=-1.552, std=1.311
#   diff_y_fft_nav: 1499 valid samples, mean=0.294, std=0.770
#   diff_y_sonar_nav: 1590 valid samples, mean=3.460, std=4.354
#   diff_y_fft_sonar: 1515 valid samples, mean=-2.982, std=4.174
# Rolling window: 67 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1612 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 309 outliers (19.17%), MAD = 0.0655 m
# Sonar: 372 outliers (23.08%), MAD = 0.0746 m
# DVL: 343 outliers (21.28%), MAD = 0.1186 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.0741 m, Median: 0.9207 m, Max: 4.6005 m
#   Magnitude Categories:
#     Small (≤0.7789m): 103 (33.3%)
#     Medium (0.7789-1.1217m): 105 (34.0%)
#     Large (>1.1217m): 101 (32.7%)
#   Clustering:
#     Total clusters: 31
#     Avg cluster size: 10.9 frames
#     Max cluster size: 48 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 31 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.6043 m, Median: 0.5472 m, Max: 1.4451 m
#   Magnitude Categories:
#     Small (≤0.3784m): 123 (33.1%)
#     Medium (0.3784-0.7123m): 126 (33.9%)
#     Large (>0.7123m): 123 (33.1%)
#   Clustering:
#     Total clusters: 32
#     Avg cluster size: 12.6 frames
#     Max cluster size: 49 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 32 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.8688 m, Median: 0.7000 m, Max: 2.3400 m
#   Magnitude Categories:
#     Small (≤0.5800m): 114 (33.2%)
#     Medium (0.5800-1.0000m): 121 (35.3%)
#     Large (>1.0000m): 108 (31.5%)
#   Clustering:
#     Total clusters: 34
#     Avg cluster size: 11.1 frames
#     Max cluster size: 62 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 34 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-55-34
# Pairwise differences computed:
#   diff_fft_nav: 1470 valid samples, mean=-2.023, std=1.227
#   diff_sonar_nav: 1469 valid samples, mean=0.338, std=1.196
#   diff_fft_sonar: 1473 valid samples, mean=-2.355, std=1.714
#   diff_pitch_fft_nav: 1470 valid samples, mean=-2.462, std=42.578
#   diff_pitch_sonar_nav: 1469 valid samples, mean=-8.905, std=19.584
#   diff_pitch_fft_sonar: 1473 valid samples, mean=6.453, std=45.440
#   diff_x_fft_nav: 1470 valid samples, mean=-1.992, std=1.217
#   diff_x_sonar_nav: 1469 valid samples, mean=0.086, std=0.543
#   diff_x_fft_sonar: 1473 valid samples, mean=-2.073, std=1.298
#   diff_y_fft_nav: 1470 valid samples, mean=-0.078, std=0.549
#   diff_y_sonar_nav: 1469 valid samples, mean=-0.661, std=1.560
#   diff_y_fft_sonar: 1473 valid samples, mean=0.582, std=1.538
# Rolling window: 63 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1476 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 594 outliers (40.24%), MAD = 0.0014 m
# Sonar: 253 outliers (17.14%), MAD = 0.0171 m
# DVL: 198 outliers (13.41%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.6465 m, Median: 0.0787 m, Max: 6.2905 m
#   Magnitude Categories:
#     Small (≤0.0337m): 197 (33.2%)
#     Medium (0.0337-0.2561m): 202 (34.0%)
#     Large (>0.2561m): 195 (32.8%)
#   Clustering:
#     Total clusters: 48
#     Avg cluster size: 13.4 frames
#     Max cluster size: 181 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 48 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1638 m, Median: 0.1191 m, Max: 0.6052 m
#   Magnitude Categories:
#     Small (≤0.0992m): 84 (33.2%)
#     Medium (0.0992-0.1488m): 85 (33.6%)
#     Large (>0.1488m): 84 (33.2%)
#   Clustering:
#     Total clusters: 47
#     Avg cluster size: 6.4 frames
#     Max cluster size: 30 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 47 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2048 m, Median: 0.0750 m, Max: 0.5300 m
#   Magnitude Categories:
#     Small (≤0.0700m): 89 (44.9%)
#     Medium (0.0700-0.3199m): 43 (21.7%)
#     Large (>0.3199m): 66 (33.3%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 16.2 frames
#     Max cluster size: 57 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-57-42
# Pairwise differences computed:
#   diff_fft_nav: 1470 valid samples, mean=-2.023, std=1.227
#   diff_sonar_nav: 1469 valid samples, mean=0.338, std=1.196
#   diff_fft_sonar: 1473 valid samples, mean=-2.355, std=1.714
#   diff_pitch_fft_nav: 1470 valid samples, mean=-2.462, std=42.578
#   diff_pitch_sonar_nav: 1469 valid samples, mean=-8.905, std=19.584
#   diff_pitch_fft_sonar: 1473 valid samples, mean=6.453, std=45.440
#   diff_x_fft_nav: 1470 valid samples, mean=-1.992, std=1.217
#   diff_x_sonar_nav: 1469 valid samples, mean=0.086, std=0.543
#   diff_x_fft_sonar: 1473 valid samples, mean=-2.073, std=1.298
#   diff_y_fft_nav: 1470 valid samples, mean=-0.078, std=0.549
#   diff_y_sonar_nav: 1469 valid samples, mean=-0.661, std=1.560
#   diff_y_fft_sonar: 1473 valid samples, mean=0.582, std=1.538
# Rolling window: 63 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1476 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 594 outliers (40.24%), MAD = 0.0014 m
# Sonar: 253 outliers (17.14%), MAD = 0.0171 m
# DVL: 198 outliers (13.41%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.6465 m, Median: 0.0787 m, Max: 6.2905 m
#   Magnitude Categories:
#     Small (≤0.0337m): 197 (33.2%)
#     Medium (0.0337-0.2561m): 202 (34.0%)
#     Large (>0.2561m): 195 (32.8%)
#   Clustering:
#     Total clusters: 48
#     Avg cluster size: 13.4 frames
#     Max cluster size: 181 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 48 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1638 m, Median: 0.1191 m, Max: 0.6052 m
#   Magnitude Categories:
#     Small (≤0.0992m): 84 (33.2%)
#     Medium (0.0992-0.1488m): 85 (33.6%)
#     Large (>0.1488m): 84 (33.2%)
#   Clustering:
#     Total clusters: 47
#     Avg cluster size: 6.4 frames
#     Max cluster size: 30 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 47 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2048 m, Median: 0.0750 m, Max: 0.5300 m
#   Magnitude Categories:
#     Small (≤0.0700m): 89 (44.9%)
#     Medium (0.0700-0.3199m): 43 (21.7%)
#     Large (>0.3199m): 66 (33.3%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 16.2 frames
#     Max cluster size: 57 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-57-42
# Pairwise differences computed:
#   diff_fft_nav: 2704 valid samples, mean=-0.133, std=1.176
#   diff_sonar_nav: 2702 valid samples, mean=0.014, std=0.239
#   diff_fft_sonar: 2742 valid samples, mean=-0.145, std=1.149
#   diff_pitch_fft_nav: 2704 valid samples, mean=-1.633, std=21.451
#   diff_pitch_sonar_nav: 2702 valid samples, mean=-1.854, std=8.974
#   diff_pitch_fft_sonar: 2742 valid samples, mean=0.316, std=21.098
#   diff_x_fft_nav: 2704 valid samples, mean=-0.145, std=1.167
#   diff_x_sonar_nav: 2702 valid samples, mean=0.014, std=0.254
#   diff_x_fft_sonar: 2742 valid samples, mean=-0.156, std=1.137
#   diff_y_fft_nav: 2704 valid samples, mean=-0.003, std=0.430
#   diff_y_sonar_nav: 2702 valid samples, mean=-0.050, std=0.218
#   diff_y_fft_sonar: 2742 valid samples, mean=0.049, std=0.420
# Rolling window: 78 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Pairwise differences computed:
#   diff_fft_nav: 2704 valid samples, mean=-0.133, std=1.176
#   diff_sonar_nav: 2702 valid samples, mean=0.014, std=0.239
#   diff_fft_sonar: 2742 valid samples, mean=-0.145, std=1.149
#   diff_pitch_fft_nav: 2704 valid samples, mean=-1.633, std=21.451
#   diff_pitch_sonar_nav: 2702 valid samples, mean=-1.854, std=8.974
#   diff_pitch_fft_sonar: 2742 valid samples, mean=0.316, std=21.098
#   diff_x_fft_nav: 2704 valid samples, mean=-0.145, std=1.167
#   diff_x_sonar_nav: 2702 valid samples, mean=0.014, std=0.254
#   diff_x_fft_sonar: 2742 valid samples, mean=-0.156, std=1.137
#   diff_y_fft_nav: 2704 valid samples, mean=-0.003, std=0.430
#   diff_y_sonar_nav: 2702 valid samples, mean=-0.050, std=0.218
#   diff_y_fft_sonar: 2742 valid samples, mean=0.049, std=0.420
# Rolling window: 78 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 481 / 2744 (17.5%)
#
# Identifying stable baseline segments...
# Found 5 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 11:58:09 - 11:58:12 (2.8 s, 96 samples)
#   Segment 2: 11:58:21 - 11:58:22 (1.5 s, 51 samples)
#   Segment 3: 11:58:23 - 11:58:26 (2.1 s, 74 samples)
#   Segment 4: 11:58:50 - 11:58:53 (2.9 s, 99 samples)
#   Segment 5: 11:58:58 - 11:59:03 (4.7 s, 157 samples)
# === OUTLIER DETECTION ===
#
# FFT: 619 outliers (22.56%), MAD = 0.0405 m
# Sonar: 415 outliers (15.12%), MAD = 0.0141 m
# DVL: 451 outliers (16.44%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.1394 m, Median: 0.6306 m, Max: 19.5937 m
#   Magnitude Categories:
#     Small (≤0.2542m): 206 (33.3%)
#     Medium (0.2542-1.2885m): 209 (33.8%)
#     Large (>1.2885m): 204 (33.0%)
#   Clustering:
#     Total clusters: 55
#     Avg cluster size: 12.2 frames
#     Max cluster size: 72 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 55 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.2257 m, Median: 0.0968 m, Max: 0.6135 m
#   Magnitude Categories:
#     Small (≤0.0757m): 137 (33.0%)
#     Medium (0.0757-0.2098m): 141 (34.0%)
#     Large (>0.2098m): 137 (33.0%)
#   Clustering:
#     Total clusters: 39
#     Avg cluster size: 11.6 frames
#     Max cluster size: 77 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 39 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1749 m, Median: 0.1200 m, Max: 0.8050 m
#   Magnitude Categories:
#     Small (≤0.0900m): 151 (33.5%)
#     Medium (0.0900-0.1750m): 152 (33.7%)
#     Large (>0.1750m): 148 (32.8%)
#   Clustering:
#     Total clusters: 23
#     Avg cluster size: 20.6 frames
#     Max cluster size: 69 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 23 (100.0%)
#
#   ✓ Processed 481 baseline samples, 5 stable segments
# Processing: 2024-08-20_14-16-05
# Pairwise differences computed:
#   diff_fft_nav: 1602 valid samples, mean=0.007, std=0.679
#   diff_sonar_nav: 1602 valid samples, mean=-0.023, std=0.127
#   diff_fft_sonar: 1726 valid samples, mean=0.048, std=0.626
#   diff_pitch_fft_nav: 1602 valid samples, mean=-13.677, std=15.095
#   diff_pitch_sonar_nav: 1602 valid samples, mean=4.107, std=8.065
#   diff_pitch_fft_sonar: 1726 valid samples, mean=-17.120, std=13.092
#   diff_x_fft_nav: 1602 valid samples, mean=0.035, std=0.681
#   diff_x_sonar_nav: 1602 valid samples, mean=-0.042, std=0.144
#   diff_x_fft_sonar: 1726 valid samples, mean=0.092, std=0.619
#   diff_y_fft_nav: 1602 valid samples, mean=-0.354, std=0.293
#   diff_y_sonar_nav: 1602 valid samples, mean=0.094, std=0.156
#   diff_y_fft_sonar: 1726 valid samples, mean=-0.430, std=0.270
# Rolling window: 74 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 62 / 1727 (3.6%)
#
# Identifying stable baseline segments...
# Found 1 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:16:56 - 12:16:58 (1.8 s, 63 samples)
# === OUTLIER DETECTION ===
#
# Stable samples: 481 / 2744 (17.5%)
#
# Identifying stable baseline segments...
# Found 5 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 11:58:09 - 11:58:12 (2.8 s, 96 samples)
#   Segment 2: 11:58:21 - 11:58:22 (1.5 s, 51 samples)
#   Segment 3: 11:58:23 - 11:58:26 (2.1 s, 74 samples)
#   Segment 4: 11:58:50 - 11:58:53 (2.9 s, 99 samples)
#   Segment 5: 11:58:58 - 11:59:03 (4.7 s, 157 samples)
# === OUTLIER DETECTION ===
#
# FFT: 619 outliers (22.56%), MAD = 0.0405 m
# Sonar: 415 outliers (15.12%), MAD = 0.0141 m
# DVL: 451 outliers (16.44%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.1394 m, Median: 0.6306 m, Max: 19.5937 m
#   Magnitude Categories:
#     Small (≤0.2542m): 206 (33.3%)
#     Medium (0.2542-1.2885m): 209 (33.8%)
#     Large (>1.2885m): 204 (33.0%)
#   Clustering:
#     Total clusters: 55
#     Avg cluster size: 12.2 frames
#     Max cluster size: 72 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 55 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.2257 m, Median: 0.0968 m, Max: 0.6135 m
#   Magnitude Categories:
#     Small (≤0.0757m): 137 (33.0%)
#     Medium (0.0757-0.2098m): 141 (34.0%)
#     Large (>0.2098m): 137 (33.0%)
#   Clustering:
#     Total clusters: 39
#     Avg cluster size: 11.6 frames
#     Max cluster size: 77 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 39 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1749 m, Median: 0.1200 m, Max: 0.8050 m
#   Magnitude Categories:
#     Small (≤0.0900m): 151 (33.5%)
#     Medium (0.0900-0.1750m): 152 (33.7%)
#     Large (>0.1750m): 148 (32.8%)
#   Clustering:
#     Total clusters: 23
#     Avg cluster size: 20.6 frames
#     Max cluster size: 69 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 23 (100.0%)
#
#   ✓ Processed 481 baseline samples, 5 stable segments
# Processing: 2024-08-20_14-16-05
# Pairwise differences computed:
#   diff_fft_nav: 1602 valid samples, mean=0.007, std=0.679
#   diff_sonar_nav: 1602 valid samples, mean=-0.023, std=0.127
#   diff_fft_sonar: 1726 valid samples, mean=0.048, std=0.626
#   diff_pitch_fft_nav: 1602 valid samples, mean=-13.677, std=15.095
#   diff_pitch_sonar_nav: 1602 valid samples, mean=4.107, std=8.065
#   diff_pitch_fft_sonar: 1726 valid samples, mean=-17.120, std=13.092
#   diff_x_fft_nav: 1602 valid samples, mean=0.035, std=0.681
#   diff_x_sonar_nav: 1602 valid samples, mean=-0.042, std=0.144
#   diff_x_fft_sonar: 1726 valid samples, mean=0.092, std=0.619
#   diff_y_fft_nav: 1602 valid samples, mean=-0.354, std=0.293
#   diff_y_sonar_nav: 1602 valid samples, mean=0.094, std=0.156
#   diff_y_fft_sonar: 1726 valid samples, mean=-0.430, std=0.270
# Rolling window: 74 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 62 / 1727 (3.6%)
#
# Identifying stable baseline segments...
# Found 1 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:16:56 - 12:16:58 (1.8 s, 63 samples)
# === OUTLIER DETECTION ===
#
# FFT: 269 outliers (15.58%), MAD = 0.0306 m
# Sonar: 131 outliers (7.59%), MAD = 0.0162 m
# DVL: 168 outliers (9.73%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.0016 m, Median: 0.5553 m, Max: 6.4420 m
#   Magnitude Categories:
#     Small (≤0.1584m): 89 (33.1%)
#     Medium (0.1584-1.3286m): 91 (33.8%)
#     Large (>1.3286m): 89 (33.1%)
#   Clustering:
#     Total clusters: 22
#     Avg cluster size: 13.2 frames
#     Max cluster size: 71 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 22 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0968 m, Median: 0.0739 m, Max: 0.3439 m
#   Magnitude Categories:
#     Small (≤0.0668m): 43 (32.8%)
#     Medium (0.0668-0.0903m): 45 (34.4%)
#     Large (>0.0903m): 43 (32.8%)
#   Clustering:
#     Total clusters: 21
#     Avg cluster size: 7.2 frames
#     Max cluster size: 34 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 21 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1646 m, Median: 0.1100 m, Max: 0.9600 m
#   Magnitude Categories:
#     Small (≤0.0900m): 58 (34.5%)
#     Medium (0.0900-0.1300m): 62 (36.9%)
#     Large (>0.1300m): 48 (28.6%)
#   Clustering:
#     Total clusters: 11
#     Avg cluster size: 16.3 frames
#     Max cluster size: 45 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 11 (100.0%)
#
#   ✓ Processed 62 baseline samples, 1 stable segments
# Processing: 2024-08-20_14-22-12
# Pairwise differences computed:
#   diff_fft_nav: 2351 valid samples, mean=-0.349, std=5.519
#   diff_sonar_nav: 2350 valid samples, mean=-0.005, std=0.171
#   diff_fft_sonar: 2398 valid samples, mean=-0.363, std=5.452
#   diff_pitch_fft_nav: 2351 valid samples, mean=-20.280, std=17.801
#   diff_pitch_sonar_nav: 2350 valid samples, mean=4.870, std=8.198
#   diff_pitch_fft_sonar: 2398 valid samples, mean=-24.911, std=17.400
#   diff_x_fft_nav: 2351 valid samples, mean=-0.302, std=5.490
#   diff_x_sonar_nav: 2350 valid samples, mean=-0.039, std=0.180
#   diff_x_fft_sonar: 2398 valid samples, mean=-0.283, std=5.425
#   diff_y_fft_nav: 2351 valid samples, mean=-0.429, std=0.670
#   diff_y_sonar_nav: 2350 valid samples, mean=0.128, std=0.187
#   diff_y_fft_sonar: 2398 valid samples, mean=-0.555, std=0.646
# Rolling window: 75 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 2401 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 576 outliers (23.99%), MAD = 0.0463 m
# Sonar: 141 outliers (5.87%), MAD = 0.0178 m
# DVL: 388 outliers (16.16%), MAD = 0.0222 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 3.3839 m, Median: 1.0918 m, Max: 127.5296 m
#   Magnitude Categories:
#     Small (≤0.5216m): 190 (33.0%)
#     Medium (0.5216-1.8977m): 196 (34.0%)
#     Large (>1.8977m): 190 (33.0%)
#   Clustering:
#     Total clusters: 48
#     Avg cluster size: 13.0 frames
#     Max cluster size: 95 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 48 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0843 m, Median: 0.0764 m, Max: 0.1463 m
#   Magnitude Categories:
#     Small (≤0.0702m): 47 (33.3%)
#     Medium (0.0702-0.0889m): 47 (33.3%)
#     Large (>0.0889m): 47 (33.3%)
#   Clustering:
#     Total clusters: 20
#     Avg cluster size: 8.1 frames
#     Max cluster size: 34 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 20 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2299 m, Median: 0.1600 m, Max: 0.8400 m
#   Magnitude Categories:
#     Small (≤0.1000m): 144 (37.1%)
#     Medium (0.1000-0.2400m): 118 (30.4%)
#     Large (>0.2400m): 126 (32.5%)
#   Clustering:
#     Total clusters: 30
#     Avg cluster size: 13.9 frames
#     Max cluster size: 73 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 30 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_14-24-35
# FFT: 269 outliers (15.58%), MAD = 0.0306 m
# Sonar: 131 outliers (7.59%), MAD = 0.0162 m
# DVL: 168 outliers (9.73%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.0016 m, Median: 0.5553 m, Max: 6.4420 m
#   Magnitude Categories:
#     Small (≤0.1584m): 89 (33.1%)
#     Medium (0.1584-1.3286m): 91 (33.8%)
#     Large (>1.3286m): 89 (33.1%)
#   Clustering:
#     Total clusters: 22
#     Avg cluster size: 13.2 frames
#     Max cluster size: 71 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 22 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0968 m, Median: 0.0739 m, Max: 0.3439 m
#   Magnitude Categories:
#     Small (≤0.0668m): 43 (32.8%)
#     Medium (0.0668-0.0903m): 45 (34.4%)
#     Large (>0.0903m): 43 (32.8%)
#   Clustering:
#     Total clusters: 21
#     Avg cluster size: 7.2 frames
#     Max cluster size: 34 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 21 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1646 m, Median: 0.1100 m, Max: 0.9600 m
#   Magnitude Categories:
#     Small (≤0.0900m): 58 (34.5%)
#     Medium (0.0900-0.1300m): 62 (36.9%)
#     Large (>0.1300m): 48 (28.6%)
#   Clustering:
#     Total clusters: 11
#     Avg cluster size: 16.3 frames
#     Max cluster size: 45 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 11 (100.0%)
#
#   ✓ Processed 62 baseline samples, 1 stable segments
# Processing: 2024-08-20_14-22-12
# Pairwise differences computed:
#   diff_fft_nav: 2351 valid samples, mean=-0.349, std=5.519
#   diff_sonar_nav: 2350 valid samples, mean=-0.005, std=0.171
#   diff_fft_sonar: 2398 valid samples, mean=-0.363, std=5.452
#   diff_pitch_fft_nav: 2351 valid samples, mean=-20.280, std=17.801
#   diff_pitch_sonar_nav: 2350 valid samples, mean=4.870, std=8.198
#   diff_pitch_fft_sonar: 2398 valid samples, mean=-24.911, std=17.400
#   diff_x_fft_nav: 2351 valid samples, mean=-0.302, std=5.490
#   diff_x_sonar_nav: 2350 valid samples, mean=-0.039, std=0.180
#   diff_x_fft_sonar: 2398 valid samples, mean=-0.283, std=5.425
#   diff_y_fft_nav: 2351 valid samples, mean=-0.429, std=0.670
#   diff_y_sonar_nav: 2350 valid samples, mean=0.128, std=0.187
#   diff_y_fft_sonar: 2398 valid samples, mean=-0.555, std=0.646
# Rolling window: 75 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 2401 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 576 outliers (23.99%), MAD = 0.0463 m
# Sonar: 141 outliers (5.87%), MAD = 0.0178 m
# DVL: 388 outliers (16.16%), MAD = 0.0222 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 3.3839 m, Median: 1.0918 m, Max: 127.5296 m
#   Magnitude Categories:
#     Small (≤0.5216m): 190 (33.0%)
#     Medium (0.5216-1.8977m): 196 (34.0%)
#     Large (>1.8977m): 190 (33.0%)
#   Clustering:
#     Total clusters: 48
#     Avg cluster size: 13.0 frames
#     Max cluster size: 95 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 48 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0843 m, Median: 0.0764 m, Max: 0.1463 m
#   Magnitude Categories:
#     Small (≤0.0702m): 47 (33.3%)
#     Medium (0.0702-0.0889m): 47 (33.3%)
#     Large (>0.0889m): 47 (33.3%)
#   Clustering:
#     Total clusters: 20
#     Avg cluster size: 8.1 frames
#     Max cluster size: 34 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 20 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2299 m, Median: 0.1600 m, Max: 0.8400 m
#   Magnitude Categories:
#     Small (≤0.1000m): 144 (37.1%)
#     Medium (0.1000-0.2400m): 118 (30.4%)
#     Large (>0.2400m): 126 (32.5%)
#   Clustering:
#     Total clusters: 30
#     Avg cluster size: 13.9 frames
#     Max cluster size: 73 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 30 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_14-24-35
# Pairwise differences computed:
#   diff_fft_nav: 2666 valid samples, mean=-0.650, std=2.323
#   diff_sonar_nav: 2666 valid samples, mean=-0.165, std=0.165
#   diff_fft_sonar: 2737 valid samples, mean=-0.511, std=2.291
#   diff_pitch_fft_nav: 2666 valid samples, mean=-5.557, std=32.271
#   diff_pitch_sonar_nav: 2666 valid samples, mean=1.418, std=9.850
#   diff_pitch_fft_sonar: 2737 valid samples, mean=-7.384, std=32.710
#   diff_x_fft_nav: 2666 valid samples, mean=-0.756, std=1.880
#   diff_x_sonar_nav: 2666 valid samples, mean=-0.181, std=0.168
#   diff_x_fft_sonar: 2737 valid samples, mean=-0.595, std=1.832
#   diff_y_fft_nav: 2666 valid samples, mean=-0.037, std=1.517
#   diff_y_sonar_nav: 2666 valid samples, mean=0.040, std=0.310
#   diff_y_fft_sonar: 2737 valid samples, mean=-0.104, std=1.513
# Rolling window: 72 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 2738 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 690 outliers (25.20%), MAD = 0.0503 m
# Sonar: 259 outliers (9.46%), MAD = 0.0199 m
# DVL: 348 outliers (12.71%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.7762 m, Median: 0.6608 m, Max: 29.3482 m
#   Magnitude Categories:
#     Small (≤0.3843m): 228 (33.0%)
#     Medium (0.3843-1.1975m): 234 (33.9%)
#     Large (>1.1975m): 228 (33.0%)
#   Clustering:
#     Total clusters: 63
#     Avg cluster size: 11.9 frames
#     Max cluster size: 67 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 63 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1931 m, Median: 0.1271 m, Max: 0.6238 m
#   Magnitude Categories:
#     Small (≤0.1101m): 87 (33.6%)
#     Medium (0.1101-0.1849m): 86 (33.2%)
#     Large (>0.1849m): 86 (33.2%)
#   Clustering:
#     Total clusters: 29
#     Avg cluster size: 9.9 frames
#     Max cluster size: 43 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 29 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1508 m, Median: 0.0800 m, Max: 0.9800 m
#   Magnitude Categories:
#     Small (≤0.0700m): 118 (33.9%)
#     Medium (0.0700-0.1250m): 116 (33.3%)
#     Large (>0.1250m): 114 (32.8%)
#   Clustering:
#     Total clusters: 19
#     Avg cluster size: 19.3 frames
#     Max cluster size: 144 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 19 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_14-31-29
# Pairwise differences computed:
#   diff_fft_nav: 2666 valid samples, mean=-0.650, std=2.323
#   diff_sonar_nav: 2666 valid samples, mean=-0.165, std=0.165
#   diff_fft_sonar: 2737 valid samples, mean=-0.511, std=2.291
#   diff_pitch_fft_nav: 2666 valid samples, mean=-5.557, std=32.271
#   diff_pitch_sonar_nav: 2666 valid samples, mean=1.418, std=9.850
#   diff_pitch_fft_sonar: 2737 valid samples, mean=-7.384, std=32.710
#   diff_x_fft_nav: 2666 valid samples, mean=-0.756, std=1.880
#   diff_x_sonar_nav: 2666 valid samples, mean=-0.181, std=0.168
#   diff_x_fft_sonar: 2737 valid samples, mean=-0.595, std=1.832
#   diff_y_fft_nav: 2666 valid samples, mean=-0.037, std=1.517
#   diff_y_sonar_nav: 2666 valid samples, mean=0.040, std=0.310
#   diff_y_fft_sonar: 2737 valid samples, mean=-0.104, std=1.513
# Rolling window: 72 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 2738 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 690 outliers (25.20%), MAD = 0.0503 m
# Sonar: 259 outliers (9.46%), MAD = 0.0199 m
# DVL: 348 outliers (12.71%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.7762 m, Median: 0.6608 m, Max: 29.3482 m
#   Magnitude Categories:
#     Small (≤0.3843m): 228 (33.0%)
#     Medium (0.3843-1.1975m): 234 (33.9%)
#     Large (>1.1975m): 228 (33.0%)
#   Clustering:
#     Total clusters: 63
#     Avg cluster size: 11.9 frames
#     Max cluster size: 67 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 63 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1931 m, Median: 0.1271 m, Max: 0.6238 m
#   Magnitude Categories:
#     Small (≤0.1101m): 87 (33.6%)
#     Medium (0.1101-0.1849m): 86 (33.2%)
#     Large (>0.1849m): 86 (33.2%)
#   Clustering:
#     Total clusters: 29
#     Avg cluster size: 9.9 frames
#     Max cluster size: 43 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 29 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1508 m, Median: 0.0800 m, Max: 0.9800 m
#   Magnitude Categories:
#     Small (≤0.0700m): 118 (33.9%)
#     Medium (0.0700-0.1250m): 116 (33.3%)
#     Large (>0.1250m): 114 (32.8%)
#   Clustering:
#     Total clusters: 19
#     Avg cluster size: 19.3 frames
#     Max cluster size: 144 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 19 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_14-31-29
# Pairwise differences computed:
#   diff_fft_nav: 2229 valid samples, mean=-0.609, std=5.203
#   diff_sonar_nav: 2227 valid samples, mean=-0.075, std=0.358
#   diff_fft_sonar: 2228 valid samples, mean=-0.535, std=5.211
#   diff_pitch_fft_nav: 2229 valid samples, mean=-1.045, std=37.488
#   diff_pitch_sonar_nav: 2227 valid samples, mean=2.271, std=16.226
#   diff_pitch_fft_sonar: 2228 valid samples, mean=-3.303, std=38.041
#   diff_x_fft_nav: 2229 valid samples, mean=-0.665, std=5.112
#   diff_x_sonar_nav: 2227 valid samples, mean=-0.114, std=0.299
#   diff_x_fft_sonar: 2228 valid samples, mean=-0.552, std=5.117
#   diff_y_fft_nav: 2229 valid samples, mean=-0.017, std=1.203
#   diff_y_sonar_nav: 2227 valid samples, mean=0.087, std=0.529
#   diff_y_fft_sonar: 2228 valid samples, mean=-0.102, std=1.255
# Rolling window: 73 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 29 / 2235 (1.3%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 563 outliers (25.19%), MAD = 0.0977 m
# Sonar: 421 outliers (18.84%), MAD = 0.0197 m
# DVL: 479 outliers (21.43%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 3.4833 m, Median: 1.5925 m, Max: 105.3858 m
#   Magnitude Categories:
#     Small (≤1.2023m): 188 (33.4%)
#     Medium (1.2023-1.8329m): 192 (34.1%)
#     Large (>1.8329m): 183 (32.5%)
#   Clustering:
# ...
#   diff_sonar_nav: 1148 valid samples, mean=-0.090, std=0.072
#   diff_fft_sonar: 1285 valid samples, mean=-0.389, std=0.564
#   diff_pitch_fft_nav: 1148 valid samples, mean=10.338, std=30.895
#   diff_pitch_sonar_nav: 1148 valid samples, mean=-7.516, std=6.957
#   diff_pitch_fft_sonar: 1285 valid samples, mean=17.081, std=29.501
#   diff_x_fft_nav: 1148 valid samples, mean=-0.510, std=0.575
#   diff_x_sonar_nav: 1148 valid samples, mean=-0.115, std=0.078
#   diff_x_fft_sonar: 1285 valid samples, mean=-0.357, std=0.551
#   diff_y_fft_nav: 1148 valid samples, mean=0.153, std=0.206
#   diff_y_sonar_nav: 1148 valid samples, mean=-0.098, std=0.098
#   diff_y_fft_sonar: 1285 valid samples, mean=0.247, std=0.182
# Rolling window: 72 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 66 / 1286 (5.1%)
#
# Identifying stable baseline segments...
# Found 1 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 16:48:01 - 16:48:02 (1.2 s, 42 samples)
# === OUTLIER DETECTION ===
#
# FFT: 374 outliers (29.08%), MAD = 0.0902 m
# Sonar: 53 outliers (4.12%), MAD = 0.0165 m
# DVL: 23 outliers (1.79%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.9344 m, Median: 0.9677 m, Max: 2.4439 m
#   Magnitude Categories:
#     Small (≤0.9124m): 126 (33.7%)
#     Medium (0.9124-1.0239m): 125 (33.4%)
#     Large (>1.0239m): 123 (32.9%)
#   Clustering:
#     Total clusters: 42
#     Avg cluster size: 9.9 frames
#     Max cluster size: 48 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 42 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0958 m, Median: 0.1048 m, Max: 0.1305 m
#   Magnitude Categories:
#     Small (≤0.0831m): 20 (37.7%)
#     Medium (0.0831-0.1102m): 15 (28.3%)
#     Large (>0.1102m): 18 (34.0%)
#   Clustering:
#     Total clusters: 7
#     Avg cluster size: 8.6 frames
#     Max cluster size: 38 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 7 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.3896 m, Median: 0.5900 m, Max: 0.6100 m
#   Magnitude Categories:
#     Small (≤0.1900m): 10 (43.5%)
#     Medium (0.1900-0.5974m): 5 (21.7%)
#     Large (>0.5974m): 8 (34.8%)
#   Clustering:
#     Total clusters: 7
#     Avg cluster size: 4.3 frames
#     Max cluster size: 6 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 7 (100.0%)
#
#   ✓ Processed 66 baseline samples, 1 stable segments
# Processing: 2024-08-22_14-06-43
# Pairwise differences computed:
#   diff_fft_nav: 962 valid samples, mean=-0.383, std=0.586
#   diff_sonar_nav: 1082 valid samples, mean=0.035, std=0.157
#   diff_fft_sonar: 1036 valid samples, mean=-0.370, std=0.574
#   diff_pitch_fft_nav: 962 valid samples, mean=9.648, std=44.948
#   diff_pitch_sonar_nav: 1082 valid samples, mean=-3.239, std=12.404
#   diff_pitch_fft_sonar: 1036 valid samples, mean=11.409, std=44.772
#   diff_x_fft_nav: 962 valid samples, mean=-0.331, std=0.522
#   diff_x_sonar_nav: 1082 valid samples, mean=-0.018, std=0.114
#   diff_x_fft_sonar: 1036 valid samples, mean=-0.314, std=0.495
#   diff_y_fft_nav: 962 valid samples, mean=0.182, std=0.335
#   diff_y_sonar_nav: 1082 valid samples, mean=-0.055, std=0.202
#   diff_y_fft_sonar: 1036 valid samples, mean=0.183, std=0.345
# Rolling window: 65 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 106 / 1163 (9.1%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:06:54 - 12:06:55 (1.0 s, 36 samples)
#   Segment 2: 12:06:57 - 12:06:59 (1.4 s, 48 samples)
# === OUTLIER DETECTION ===
#
# FFT: 320 outliers (27.52%), MAD = 0.0109 m
# Sonar: 207 outliers (17.80%), MAD = 0.0130 m
# DVL: 72 outliers (6.19%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.5367 m, Median: 0.3887 m, Max: 7.0493 m
#   Magnitude Categories:
#     Small (≤0.1221m): 107 (33.4%)
#     Medium (0.1221-0.6210m): 108 (33.8%)
#     Large (>0.6210m): 105 (32.8%)
#   Clustering:
#     Total clusters: 27
#     Avg cluster size: 12.9 frames
#     Max cluster size: 47 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 27 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1203 m, Median: 0.0812 m, Max: 0.8659 m
#   Magnitude Categories:
#     Small (≤0.0728m): 69 (33.3%)
#     Medium (0.0728-0.0926m): 71 (34.3%)
#     Large (>0.0926m): 67 (32.4%)
#   Clustering:
#     Total clusters: 16
#     Avg cluster size: 13.9 frames
#     Max cluster size: 50 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 16 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2708 m, Median: 0.3000 m, Max: 0.5800 m
#   Magnitude Categories:
#     Small (≤0.0800m): 25 (34.7%)
#     Medium (0.0800-0.3600m): 26 (36.1%)
#     Large (>0.3600m): 21 (29.2%)
#   Clustering:
#     Total clusters: 19
#     Avg cluster size: 4.8 frames
#     Max cluster size: 11 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 19 (100.0%)
#
#   ✓ Processed 106 baseline samples, 2 stable segments
# Processing: 2024-08-22_14-29-05
# Pairwise differences computed:
#   diff_fft_nav: 1737 valid samples, mean=-0.300, std=0.347
#   diff_sonar_nav: 1817 valid samples, mean=0.010, std=0.109
#   diff_fft_sonar: 1849 valid samples, mean=-0.299, std=0.376
#   diff_pitch_fft_nav: 1737 valid samples, mean=4.108, std=41.404
#   diff_pitch_sonar_nav: 1817 valid samples, mean=-4.463, std=10.669
#   diff_pitch_fft_sonar: 1849 valid samples, mean=7.894, std=39.792
#   diff_x_fft_nav: 1737 valid samples, mean=-0.303, std=0.341
#   diff_x_sonar_nav: 1817 valid samples, mean=0.006, std=0.117
#   diff_x_fft_sonar: 1849 valid samples, mean=-0.298, std=0.368
#   diff_y_fft_nav: 1737 valid samples, mean=0.056, std=0.109
#   diff_y_sonar_nav: 1817 valid samples, mean=-0.033, std=0.084
#   diff_y_fft_sonar: 1849 valid samples, mean=0.088, std=0.108
# Rolling window: 65 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 508 / 1930 (26.3%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:29:15 - 12:29:18 (2.2 s, 80 samples)
#   Segment 2: 12:29:56 - 12:30:09 (13.0 s, 430 samples)
# === OUTLIER DETECTION ===
#
# FFT: 628 outliers (32.54%), MAD = 0.0017 m
# Sonar: 180 outliers (9.33%), MAD = 0.0130 m
# DVL: 35 outliers (1.81%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.1400 m, Median: 0.0244 m, Max: 1.6740 m
#   Magnitude Categories:
#     Small (≤0.0171m): 208 (33.1%)
#     Medium (0.0171-0.0479m): 213 (33.9%)
#     Large (>0.0479m): 207 (33.0%)
#   Clustering:
#     Total clusters: 38
#     Avg cluster size: 17.5 frames
#     Max cluster size: 126 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 38 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1191 m, Median: 0.0844 m, Max: 0.3796 m
#   Magnitude Categories:
#     Small (≤0.0663m): 61 (33.9%)
#     Medium (0.0663-0.1300m): 60 (33.3%)
#     Large (>0.1300m): 59 (32.8%)
#   Clustering:
#     Total clusters: 20
#     Avg cluster size: 10.0 frames
#     Max cluster size: 56 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 20 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1396 m, Median: 0.0600 m, Max: 0.4100 m
#   Magnitude Categories:
#     Small (≤0.0600m): 23 (65.7%)
#     Medium (0.0600-0.0639m): 0 (0.0%)
#     Large (>0.0639m): 12 (34.3%)
#   Clustering:
#     Total clusters: 8
#     Avg cluster size: 5.4 frames
#     Max cluster size: 10 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 8 (100.0%)
#
#   ✓ Processed 508 baseline samples, 2 stable segments
# Processing: 2024-08-22_14-47-39
# Pairwise differences computed:
#   diff_fft_nav: 1363 valid samples, mean=-0.334, std=0.375
#   diff_sonar_nav: 1363 valid samples, mean=0.053, std=0.053
#   diff_fft_sonar: 1462 valid samples, mean=-0.370, std=0.380
#   diff_pitch_fft_nav: 1363 valid samples, mean=8.797, std=44.769
#   diff_pitch_sonar_nav: 1363 valid samples, mean=-4.209, std=9.111
#   diff_pitch_fft_sonar: 1462 valid samples, mean=12.587, std=42.977
#   diff_x_fft_nav: 1363 valid samples, mean=-0.337, std=0.362
#   diff_x_sonar_nav: 1363 valid samples, mean=0.052, std=0.058
#   diff_x_fft_sonar: 1462 valid samples, mean=-0.373, std=0.368
#   diff_y_fft_nav: 1363 valid samples, mean=0.066, std=0.136
#   diff_y_sonar_nav: 1363 valid samples, mean=-0.050, std=0.095
#   diff_y_fft_sonar: 1462 valid samples, mean=0.113, std=0.118
# Rolling window: 67 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 280 / 1463 (19.1%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:47:48 - 12:47:53 (4.6 s, 158 samples)
#   Segment 2: 12:48:23 - 12:48:27 (3.6 s, 124 samples)
# === OUTLIER DETECTION ===
#
# FFT: 352 outliers (24.06%), MAD = 0.0098 m
# Sonar: 111 outliers (7.59%), MAD = 0.0127 m
# DVL: 95 outliers (6.49%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3972 m, Median: 0.2754 m, Max: 2.1886 m
#   Magnitude Categories:
#     Small (≤0.0562m): 116 (33.0%)
#     Medium (0.0562-0.5916m): 120 (34.1%)
#     Large (>0.5916m): 116 (33.0%)
#   Clustering:
#     Total clusters: 30
#     Avg cluster size: 12.7 frames
#     Max cluster size: 60 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 30 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1021 m, Median: 0.0755 m, Max: 0.3779 m
#   Magnitude Categories:
#     Small (≤0.0584m): 40 (36.0%)
#     Medium (0.0584-0.0988m): 34 (30.6%)
#     Large (>0.0988m): 37 (33.3%)
#   Clustering:
#     Total clusters: 16
#     Avg cluster size: 7.9 frames
#     Max cluster size: 38 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 16 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.0995 m, Median: 0.0700 m, Max: 0.3900 m
#   Magnitude Categories:
#     Small (≤0.0700m): 55 (57.9%)
#     Medium (0.0700-0.0899m): 8 (8.4%)
#     Large (>0.0899m): 32 (33.7%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 8.3 frames
#     Max cluster size: 41 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
#   ✓ Processed 280 baseline samples, 2 stable segments
# ✓ Summary CSV saved: bag_summary.csv
#   Location: /Volumes/LaCie/SOLAQUA/exports/basic_full_batch/bag_summary.csv
#
# ======================================================================
# ✓ Summary CSV regenerated successfully!
#   Location: /Volumes/LaCie/SOLAQUA/exports/basic_full_batch/bag_summary.csv
#
# The summary now includes:
#   ✓ Outlier magnitude metrics (mean, median, max)
#   ✓ Outlier clustering analysis (cluster count, sizes)
#   ✓ Isolated vs. multi-frame outlier statistics
#
# Re-run the 'Multi-Bag Summary Analysis' cell above to see the updated statistics.
# Pairwise differences computed:
#   diff_fft_nav: 1737 valid samples, mean=-0.300, std=0.347
#   diff_sonar_nav: 1817 valid samples, mean=0.010, std=0.109
#   diff_fft_sonar: 1849 valid samples, mean=-0.299, std=0.376
#   diff_pitch_fft_nav: 1737 valid samples, mean=4.108, std=41.404
#   diff_pitch_sonar_nav: 1817 valid samples, mean=-4.463, std=10.669
#   diff_pitch_fft_sonar: 1849 valid samples, mean=7.894, std=39.792
#   diff_x_fft_nav: 1737 valid samples, mean=-0.303, std=0.341
#   diff_x_sonar_nav: 1817 valid samples, mean=0.006, std=0.117
#   diff_x_fft_sonar: 1849 valid samples, mean=-0.298, std=0.368
#   diff_y_fft_nav: 1737 valid samples, mean=0.056, std=0.109
#   diff_y_sonar_nav: 1817 valid samples, mean=-0.033, std=0.084
#   diff_y_fft_sonar: 1849 valid samples, mean=0.088, std=0.108
# Rolling window: 65 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 508 / 1930 (26.3%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:29:15 - 12:29:18 (2.2 s, 80 samples)
#   Segment 2: 12:29:56 - 12:30:09 (13.0 s, 430 samples)
# === OUTLIER DETECTION ===
#
# FFT: 628 outliers (32.54%), MAD = 0.0017 m
# Sonar: 180 outliers (9.33%), MAD = 0.0130 m
# DVL: 35 outliers (1.81%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.1400 m, Median: 0.0244 m, Max: 1.6740 m
#   Magnitude Categories:
#     Small (≤0.0171m): 208 (33.1%)
#     Medium (0.0171-0.0479m): 213 (33.9%)
#     Large (>0.0479m): 207 (33.0%)
#   Clustering:
#     Total clusters: 38
#     Avg cluster size: 17.5 frames
#     Max cluster size: 126 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 38 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1191 m, Median: 0.0844 m, Max: 0.3796 m
#   Magnitude Categories:
#     Small (≤0.0663m): 61 (33.9%)
#     Medium (0.0663-0.1300m): 60 (33.3%)
#     Large (>0.1300m): 59 (32.8%)
#   Clustering:
#     Total clusters: 20
#     Avg cluster size: 10.0 frames
#     Max cluster size: 56 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 20 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1396 m, Median: 0.0600 m, Max: 0.4100 m
#   Magnitude Categories:
#     Small (≤0.0600m): 23 (65.7%)
#     Medium (0.0600-0.0639m): 0 (0.0%)
#     Large (>0.0639m): 12 (34.3%)
#   Clustering:
#     Total clusters: 8
#     Avg cluster size: 5.4 frames
#     Max cluster size: 10 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 8 (100.0%)
#
#   ✓ Processed 508 baseline samples, 2 stable segments
# Processing: 2024-08-22_14-47-39
# Pairwise differences computed:
#   diff_fft_nav: 1363 valid samples, mean=-0.334, std=0.375
#   diff_sonar_nav: 1363 valid samples, mean=0.053, std=0.053
#   diff_fft_sonar: 1462 valid samples, mean=-0.370, std=0.380
#   diff_pitch_fft_nav: 1363 valid samples, mean=8.797, std=44.769
#   diff_pitch_sonar_nav: 1363 valid samples, mean=-4.209, std=9.111
#   diff_pitch_fft_sonar: 1462 valid samples, mean=12.587, std=42.977
#   diff_x_fft_nav: 1363 valid samples, mean=-0.337, std=0.362
#   diff_x_sonar_nav: 1363 valid samples, mean=0.052, std=0.058
#   diff_x_fft_sonar: 1462 valid samples, mean=-0.373, std=0.368
#   diff_y_fft_nav: 1363 valid samples, mean=0.066, std=0.136
#   diff_y_sonar_nav: 1363 valid samples, mean=-0.050, std=0.095
#   diff_y_fft_sonar: 1462 valid samples, mean=0.113, std=0.118
# Rolling window: 67 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 280 / 1463 (19.1%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:47:48 - 12:47:53 (4.6 s, 158 samples)
#   Segment 2: 12:48:23 - 12:48:27 (3.6 s, 124 samples)
# === OUTLIER DETECTION ===
#
# FFT: 352 outliers (24.06%), MAD = 0.0098 m
# Sonar: 111 outliers (7.59%), MAD = 0.0127 m
# DVL: 95 outliers (6.49%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3972 m, Median: 0.2754 m, Max: 2.1886 m
#   Magnitude Categories:
#     Small (≤0.0562m): 116 (33.0%)
#     Medium (0.0562-0.5916m): 120 (34.1%)
#     Large (>0.5916m): 116 (33.0%)
#   Clustering:
#     Total clusters: 30
#     Avg cluster size: 12.7 frames
#     Max cluster size: 60 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 30 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1021 m, Median: 0.0755 m, Max: 0.3779 m
#   Magnitude Categories:
#     Small (≤0.0584m): 40 (36.0%)
#     Medium (0.0584-0.0988m): 34 (30.6%)
#     Large (>0.0988m): 37 (33.3%)
#   Clustering:
#     Total clusters: 16
#     Avg cluster size: 7.9 frames
#     Max cluster size: 38 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 16 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.0995 m, Median: 0.0700 m, Max: 0.3900 m
#   Magnitude Categories:
#     Small (≤0.0700m): 55 (57.9%)
#     Medium (0.0700-0.0899m): 8 (8.4%)
#     Large (>0.0899m): 32 (33.7%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 8.3 frames
#     Max cluster size: 41 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
#   ✓ Processed 280 baseline samples, 2 stable segments
# ✓ Summary CSV saved: bag_summary.csv
#   Location: /Volumes/LaCie/SOLAQUA/exports/basic_full_batch/bag_summary.csv
#
# ======================================================================
# ✓ Summary CSV regenerated successfully!
#   Location: /Volumes/LaCie/SOLAQUA/exports/basic_full_batch/bag_summary.csv
#
# The summary now includes:
#   ✓ Outlier magnitude metrics (mean, median, max)
#   ✓ Outlier clustering analysis (cluster count, sizes)
#   ✓ Isolated vs. multi-frame outlier statistics
#
# Re-run the 'Multi-Bag Summary Analysis' cell above to see the updated statistics.

# %% [markdown]
# ## Multi-Bag Summary Analysis
#
# Load and analyze the comprehensive summary CSV containing all processed bags.

# %%
# Load and display multi-bag summary statistics
summary_csv_path = COMPARISON_DATA_DIR / "bag_summary.csv"
summary_df = print_multi_bag_summary(summary_csv_path)

# Optional: further analysis on summary_df
if summary_df is not None:
    print("\n📊 Additional insights:")
    print(f"  DataFrame available for custom analysis")
    print(f"  Example: summary_df[summary_df['baseline_percentage'] > 50]")
    
    # Check if outlier magnitude columns exist
    has_magnitude = any('outlier_mean_magnitude' in col for col in summary_df.columns)
    has_clustering = any('outlier_cluster_count' in col for col in summary_df.columns)
    
    if not has_magnitude or not has_clustering:
        print("\n⚠️  NOTE: Outlier magnitude and clustering metrics not found.")
        print("  The bag_summary.csv needs to be regenerated with the updated analysis.")
        print("  Run the cell below or: python scripts/generate_bag_summary.py")
        print("  Then re-run this cell to see outlier characteristics.")
# Out:
# Loading multi-bag summary from: bag_summary.csv
#
# ======================================================================
# MULTI-BAG SUMMARY STATISTICS
# ======================================================================
#
# 📊 DATASET OVERVIEW
#   Total bags analyzed: 46
#   Total recording time: 52.7 hours
#   Total samples: 54,347.0
#
# 🔧 SYSTEM AVAILABILITY
#   FFT: 23/46 bags (50.0%)
#   Sonar: 23/46 bags (50.0%)
#   DVL: 23/46 bags (50.0%)
#
# 📈 BASELINE SEGMENTS (Stable Data)
#   Avg baseline percentage: 7.2%
#   Median baseline percentage: 0.7%
#   Avg segments per bag: 2.7
#   Total baseline time: 0.1 hours
#
# 📏 DISTANCE MEASUREMENT NOISE (Baseline STD)
#   FFT: mean=0.1011m, median=0.0778m, min=0.0306m, max=0.2175m
#   SONAR: mean=0.0805m, median=0.0635m, min=0.0091m, max=0.1780m
#   DVL: mean=0.1105m, median=0.1175m, min=0.0178m, max=0.2309m
#
# 📐 PITCH MEASUREMENT NOISE (Baseline STD)
#   FFT: mean=6.9139°, median=6.4276°, min=0.8609°, max=23.4524°
#   SONAR: mean=3.3747°, median=2.8412°, min=0.1932°, max=6.4171°
#   DVL: mean=5.3954°, median=4.1033°, min=1.7077°, max=15.2511°
#
# 🧭 POSITION NOISE (Baseline STD)
#   X FFT: mean=0.1056m, median=0.0812m, min=0.0333m, max=0.2146m
#   X SONAR: mean=0.0814m, median=0.0765m, min=0.0063m, max=0.1793m
#   X DVL: mean=0.1166m, median=0.1306m, min=0.0139m, max=0.2867m
#   Y FFT: mean=0.1187m, median=0.1167m, min=0.0204m, max=0.2742m
#   Y SONAR: mean=0.0616m, median=0.0445m, min=0.0057m, max=0.1527m
#   Y DVL: mean=0.0802m, median=0.0707m, min=0.0309m, max=0.2105m
#
# ⚖️  PAIRWISE BIASES (Systematic Differences)
#   FFT vs DVL: mean=+0.0326m, median=+0.0368m, std=0.0538m
#   Sonar vs DVL: mean=-0.0212m, median=-0.0530m, std=0.0715m
#   FFT vs Sonar: mean=+0.0538m, median=+0.0803m, std=0.0814m
#
# 📉 LINEAR RELATIONSHIP QUALITY (R² scores)
#   Distance: FFT vs DVL: mean=0.4696, median=0.3630, min=0.0001
#   Distance: Sonar vs DVL: mean=0.4263, median=0.3911, min=0.0012
#   Pitch: FFT vs DVL: mean=0.0554, median=0.0178, min=0.0000
#   Pitch: Sonar vs DVL: mean=0.2185, median=0.1606, min=0.0006
#
# ⚠️  OUTLIER RATES
#   FFT: mean=21.18%, median=22.19%, max=40.24%
#   SONAR: mean=12.90%, median=11.95%, max=25.54%
#   DVL: mean=12.99%, median=12.71%, max=34.23%
#
# 📏 OUTLIER MAGNITUDE
#   FFT: mean=1.5681m, median=1.0016m, max=7.3143m
#   SONAR: mean=0.1732m, median=0.1601m, max=0.6043m
#   DVL: mean=0.2625m, median=0.2048m, max=0.8688m
#
# 🔗 OUTLIER CLUSTERING (Multi-frame events)
#   FFT: avg_cluster_size=13.0 frames, isolated=0.0%
#   SONAR: avg_cluster_size=10.7 frames, isolated=0.0%
#   DVL: avg_cluster_size=15.7 frames, isolated=0.0%
#
# 📊 OUTLIER MAGNITUDE CATEGORIES
#   FFT: small=33.3%, medium=33.9%, large=32.8%
#   SONAR: small=33.5%, medium=33.6%, large=32.8%
#   DVL: small=38.4%, medium=30.3%, large=31.3%
#
# 🏆 TOP 5 BAGS (by baseline percentage)
#   2024-08-20_17-02-00: 56.3% baseline, 3 segments
#   2024-08-20_17-08-14: 38.4% baseline, 6 segments
#   2024-08-20_15-00-24: 30.3% baseline, 7 segments
#   2024-08-20_13-57-42: 17.5% baseline, 5 segments
#   2024-08-20_17-40-54: 11.3% baseline, 4 segments
#
# ⚠️  BOTTOM 5 BAGS (by baseline percentage)
#   2024-08-20_13-39-34: 0.0% baseline, 0 segments
#   2024-08-20_13-42-51: 0.0% baseline, 0 segments
#   2024-08-20_13-55-34: 0.0% baseline, 0 segments
#   2024-08-20_14-22-12: 0.0% baseline, 0 segments
#   2024-08-20_14-24-35: 0.0% baseline, 0 segments
#
# ======================================================================
# ✓ Multi-bag summary complete
#   Full data available in: bag_summary.csv
#   Columns: 139
#
#   Column categories:
#     Metadata: 11
#     Distance metrics: 24
#     Pitch metrics: 24
#     X/Y position metrics: 12
#     Outlier metrics: 54
#     Correlation metrics: 0
#
# 📊 Additional insights:
#   DataFrame available for custom analysis
#   Example: summary_df[summary_df['baseline_percentage'] > 50]
