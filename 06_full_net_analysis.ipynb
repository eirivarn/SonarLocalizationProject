# %% [markdown]
# # Full Net Tracking Analysis: Multi-System Performance Assessment
#
# This notebook performs comprehensive analysis of synchronized comparison data from three net-tracking systems using the `comparison_analysis` utility module.
#
# **What this does:**
# 1. Loads and optionally smooths comparison data
# 2. Detects stable baseline segments
# 3. Computes noise, bias, and outlier statistics
# 4. Generates visualizations and summary reports
#
# **Quick Start:**
# 1. Set `TARGET_BAG` to your bag ID
# 2. Run all cells
# 3. Check outputs in comparison_data and plots directories
#
# #### **Generate for summary to csv for all of the available comparison data:**
# `Use defaults`
# python scripts/generate_bag_summary.py

# %% [markdown]
# ## Configuration

# %%
from pathlib import Path
from utils.comparison_analysis import (
    load_and_prepare_data,
    compute_pairwise_differences,
    detect_stable_segments,
    compute_baseline_statistics,
    detect_outliers,
    analyze_failure_correlation,
    create_visualizations,
    generate_summary_report,
    print_multi_bag_summary
)

# Configuration
TARGET_BAG = "2024-08-20_13-57-42"
COMPARISON_DATA_DIR = Path("/Volumes/LaCie/SOLAQUA/comparison_data")
PLOTS_DIR = Path("/Volumes/LaCie/SOLAQUA/exports/plots")
PLOTS_DIR.mkdir(parents=True, exist_ok=True)

# Analysis parameters
SMOOTHING_ALPHA = None  # None = no smoothing, 0-1 = smoothing factor
ROLLING_WINDOW_SEC = 3.0
SIGMA_THRESH = 0.15
DELTA_THRESH = 0.15
MIN_SEGMENT_SEC = 1.0
OUTLIER_K = 3.5

print(f"Target: {TARGET_BAG}")
print(f"Smoothing: {'Disabled' if SMOOTHING_ALPHA is None else f'α={SMOOTHING_ALPHA:.2f}'}")
print(f"Stability thresholds: σ={SIGMA_THRESH}m, Δ={DELTA_THRESH}m")
# Out:
#  CONFIG VALIDATION WARNING:
#    Missing TRACKING_CONFIG keys: {'corridor_both_directions', 'use_corridor_splitting', 'corridor_widen'}
# Target: 2024-08-20_13-57-42
# Smoothing: Disabled
# Stability thresholds: σ=0.15m, Δ=0.15m

# %% [markdown]
# ## Load and Process Data

# %%
# Load comparison data
data_path = COMPARISON_DATA_DIR / f"{TARGET_BAG}_raw_comparison.csv"
df, sampling_rate, available_systems = load_and_prepare_data(data_path, SMOOTHING_ALPHA)

# Compute pairwise differences
df = compute_pairwise_differences(df)
# Out:
# Loading data from: 2024-08-20_13-57-42_raw_comparison.csv
#
# Data loaded: 2744 samples
# Time range: 2024-08-20 11:57:45.106798649+00:00 to 2024-08-20 11:59:04.976633549+00:00
# Duration: 79.9 seconds
# Median sampling interval: 0.025 s (39.2 Hz)
# Available systems: FFT, Sonar, DVL
# Pairwise differences computed:
#   diff_fft_nav: 2704 valid samples, mean=-0.133, std=1.176
#   diff_sonar_nav: 2704 valid samples, mean=-0.021, std=0.169
#   diff_fft_sonar: 2744 valid samples, mean=-0.110, std=1.148
#   diff_pitch_fft_nav: 2704 valid samples, mean=-1.633, std=21.451
#   diff_pitch_sonar_nav: 2704 valid samples, mean=-1.389, std=8.883
#   diff_pitch_fft_sonar: 2744 valid samples, mean=-0.085, std=21.371
#   diff_x_fft_nav: 2704 valid samples, mean=-0.145, std=1.167
#   diff_x_sonar_nav: 2704 valid samples, mean=-0.022, std=0.185
#   diff_x_fft_sonar: 2744 valid samples, mean=-0.120, std=1.136
#   diff_y_fft_nav: 2704 valid samples, mean=-0.003, std=0.430
#   diff_y_sonar_nav: 2704 valid samples, mean=-0.037, std=0.212
#   diff_y_fft_sonar: 2744 valid samples, mean=0.037, std=0.430

# %% [markdown]
# ## Detect Stable Baseline Segments

# %%
df, segments, window_samples = detect_stable_segments(
    df, sampling_rate,
    rolling_window_sec=ROLLING_WINDOW_SEC,
    sigma_thresh=SIGMA_THRESH,
    delta_thresh=DELTA_THRESH,
    min_segment_sec=MIN_SEGMENT_SEC
)
# Out:
# Rolling window: 117 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 1017 / 2744 (37.1%)
#
# Identifying stable baseline segments...
# Found 3 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 11:57:58 - 11:58:09 (11.6 s, 405 samples)
#   Segment 2: 11:58:22 - 11:58:26 (4.2 s, 149 samples)
#   Segment 3: 11:58:50 - 11:59:02 (12.6 s, 421 samples)

# %% [markdown]
# ## Baseline Statistics

# %%
baseline_stats = compute_baseline_statistics(df)
# Out:
# === BASELINE STATISTICS (1017 samples) ===
#
# 1. PER-METHOD NOISE - DISTANCE
#   FFT: σ = 0.1124 m, MAD = 0.1410 m
#   Sonar: σ = 0.0975 m, MAD = 0.0759 m
#   DVL: σ = 0.1115 m, MAD = 0.1038 m
#
# 2. PER-METHOD NOISE - PITCH
#   FFT: σ = 6.7911°, MAD = 6.6285°
#   Sonar: σ = 8.9854°, MAD = 9.2353°
#   DVL: σ = 8.3640°, MAD = 10.3814°
#
# 3. PER-METHOD NOISE - X POSITION
#   FFT: σ = 0.1142 m, MAD = 0.1380 m
#   Sonar: σ = 0.1001 m, MAD = 0.0862 m
#   DVL: σ = 0.1106 m, MAD = 0.1185 m
#
# 4. PER-METHOD NOISE - Y POSITION
#   FFT: σ = 0.1701 m, MAD = 0.1673 m
#   Sonar: σ = 0.2134 m, MAD = 0.2416 m
#   DVL: σ = 0.2088 m, MAD = 0.2640 m
#
# 5. PAIRWISE BIASES - DISTANCE
#   FFT vs DVL: Bias = +0.0343 m, Std = 0.0721 m
#   Sonar vs DVL: Bias = -0.0460 m, Std = 0.0656 m
#   FFT vs Sonar: Bias = +0.0803 m, Std = 0.0811 m
#
# 6. PAIRWISE BIASES - PITCH
#   FFT vs DVL: Bias = +5.4050 °, Std = 10.5018 °
#   Sonar vs DVL: Bias = -0.9884 °, Std = 4.5380 °
#   FFT vs Sonar: Bias = +6.3934 °, Std = 10.7871 °
#
# 7. PAIRWISE BIASES - X POSITION
#   FFT vs DVL: Bias = +0.0368 m, Std = 0.0858 m
#   Sonar vs DVL: Bias = -0.0484 m, Std = 0.0657 m
#   FFT vs Sonar: Bias = +0.0852 m, Std = 0.0856 m
#
# 8. PAIRWISE BIASES - Y POSITION
#   FFT vs DVL: Bias = +0.1371 m, Std = 0.2594 m
#   Sonar vs DVL: Bias = -0.0241 m, Std = 0.1096 m
#   FFT vs Sonar: Bias = +0.1612 m, Std = 0.2575 m
#
# 9. LINEAR RELATIONSHIPS (in baseline)
#   Distance - FFT vs DVL: R² = 0.6284
#   Distance - Sonar vs DVL: R² = 0.6580
#   Pitch - FFT vs DVL: R² = 0.0026
#   Pitch - Sonar vs DVL: R² = 0.7492

# %% [markdown]
# ## Outlier Detection

# %%
df, outlier_stats = detect_outliers(df, window_samples, outlier_k=OUTLIER_K)
correlation_stats = analyze_failure_correlation(df)
# Out:
# === OUTLIER DETECTION ===
#
# FFT: 518 outliers (18.88%), MAD = 0.0598 m
# Sonar: 157 outliers (5.72%), MAD = 0.0211 m
# DVL: 345 outliers (12.57%), MAD = 0.0297 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.3346 m, Median: 1.0244 m, Max: 19.5926 m
#   Magnitude Categories:
#     Small (≤0.4784m): 171 (33.0%)
#     Medium (0.4784-1.2642m): 176 (34.0%)
#     Large (>1.2642m): 171 (33.0%)
#   Clustering:
#     Total clusters: 33
#     Avg cluster size: 16.7 frames
#     Max cluster size: 120 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 33 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1032 m, Median: 0.1065 m, Max: 0.1430 m
#   Magnitude Categories:
#     Small (≤0.0917m): 52 (33.1%)
#     Medium (0.0917-0.1128m): 53 (33.8%)
#     Large (>0.1128m): 52 (33.1%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 13.1 frames
#     Max cluster size: 65 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2162 m, Median: 0.1500 m, Max: 0.8100 m
#   Magnitude Categories:
#     Small (≤0.1250m): 117 (33.9%)
#     Medium (0.1250-0.2348m): 114 (33.0%)
#     Large (>0.2348m): 114 (33.0%)
#   Clustering:
#     Total clusters: 19
#     Avg cluster size: 19.2 frames
#     Max cluster size: 67 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 19 (100.0%)
#
#
# === FAILURE CORRELATION ===
#
# 1. INDIVIDUAL OUTLIER RATES
#   P(FFT outlier) = 18.88%
#   P(SONAR outlier) = 5.72%
#   P(DVL outlier) = 12.57%
#
# 2. CO-OCCURRENCE ANALYSIS
#   Jaccard(FFT, SONAR) = 0.001
#     P(SONAR outlier | FFT outlier) = 0.002
#     P(FFT outlier | SONAR outlier) = 0.006
#   Jaccard(FFT, DVL) = 0.000
#     P(DVL outlier | FFT outlier) = 0.000
#     P(FFT outlier | DVL outlier) = 0.000
#   Jaccard(SONAR, DVL) = 0.084
#     P(DVL outlier | SONAR outlier) = 0.248
#     P(SONAR outlier | DVL outlier) = 0.113

# %% [markdown]
# ## Generate Visualizations

# %%
print("\n=== GENERATING VISUALIZATIONS ===\n")

figs = create_visualizations(
    df, segments, TARGET_BAG, PLOTS_DIR,
    sigma_thresh=SIGMA_THRESH,
    outlier_k=OUTLIER_K
)

# Display plots
for name, fig in figs.items():
    print(f"\nDisplaying {name}...")
    fig.show()

print(f"\n✓ All plots saved to: {PLOTS_DIR}")
# Out:
# === GENERATING VISUALIZATIONS ===
# /Users/eirikvarnes/code/SOLAQUA/venv/lib/python3.13/site-packages/plotly/io/_json.py:558: UserWarning:
#
# Discarding nonzero nanoseconds in conversion.
# Saved: 2024-08-20_13-57-42_timeseries.html
# Saved: 2024-08-20_13-57-42_stability.html
# Saved: 2024-08-20_13-57-42_outliers.html
#
# Displaying timeseries...
# Displaying stability...
# Displaying outliers...
# ✓ All plots saved to: /Volumes/LaCie/SOLAQUA/exports/plots

# %% [markdown]
# ## Generate Summary Report

# %%
config = {
    'Smoothing': f'α={SMOOTHING_ALPHA:.2f}' if SMOOTHING_ALPHA else 'Disabled',
    'Rolling Window': f'{ROLLING_WINDOW_SEC} s ({window_samples} samples)',
    'Stability σ Threshold': f'{SIGMA_THRESH} m',
    'Stability Δ Threshold': f'{DELTA_THRESH} m',
    'Min Segment Length': f'{MIN_SEGMENT_SEC} s',
    'Outlier Threshold': f'{OUTLIER_K} × MAD'
}

report_path = COMPARISON_DATA_DIR / f"{TARGET_BAG}_analysis_summary.md"
generate_summary_report(
    df, segments, baseline_stats, available_systems,
    TARGET_BAG, report_path, config, outlier_stats
)

print(f"\n✓ Analysis complete!")
print(f"  Plots: {PLOTS_DIR}")
print(f"  Report: {report_path}")
# Out:
# === GENERATING SUMMARY REPORT ===
#
# ✓ Summary report saved: 2024-08-20_13-57-42_analysis_summary.md
#   Location: /Volumes/LaCie/SOLAQUA/comparison_data/2024-08-20_13-57-42_analysis_summary.md
#
# ✓ Analysis complete!
#   Plots: /Volumes/LaCie/SOLAQUA/exports/plots
#   Report: /Volumes/LaCie/SOLAQUA/comparison_data/2024-08-20_13-57-42_analysis_summary.md

# %% [markdown]
# ## Multi-Bag Summary Analysis
#
# Load and analyze the comprehensive summary CSV containing all processed bags.

# %%
# Load and display multi-bag summary statistics
summary_csv_path = COMPARISON_DATA_DIR / "bag_summary.csv"
summary_df = print_multi_bag_summary(summary_csv_path)

# Optional: further analysis on summary_df
if summary_df is not None:
    print("\n📊 Additional insights:")
    print(f"  DataFrame available for custom analysis")
    print(f"  Example: summary_df[summary_df['baseline_percentage'] > 50]")
    
    # Check if outlier magnitude columns exist
    has_magnitude = any('outlier_mean_magnitude' in col for col in summary_df.columns)
    has_clustering = any('outlier_cluster_count' in col for col in summary_df.columns)
    
    if not has_magnitude or not has_clustering:
        print("\n⚠️  NOTE: Outlier magnitude and clustering metrics not found.")
        print("  The bag_summary.csv needs to be regenerated with the updated analysis.")
        print("  Run the cell below or: python scripts/generate_bag_summary.py")
        print("  Then re-run this cell to see outlier characteristics.")
# Out:
# Loading multi-bag summary from: bag_summary.csv
#
# ======================================================================
# MULTI-BAG SUMMARY STATISTICS
# ======================================================================
#
# 📊 DATASET OVERVIEW
#   Total bags analyzed: 46
#   Total recording time: 52.7 hours
#   Total samples: 54,347.0
#
# 🔧 SYSTEM AVAILABILITY
#   FFT: 23/46 bags (50.0%)
#   Sonar: 23/46 bags (50.0%)
#   DVL: 23/46 bags (50.0%)
#
# 📈 BASELINE SEGMENTS (Stable Data)
#   Avg baseline percentage: 9.5%
#   Median baseline percentage: 1.3%
#   Avg segments per bag: 2.6
#   Total baseline time: 0.1 hours
#
# 📏 DISTANCE MEASUREMENT NOISE (Baseline STD)
#   FFT: mean=0.1115m, median=0.0951m, min=0.0255m, max=0.2357m
#   SONAR: mean=0.0983m, median=0.0709m, min=0.0178m, max=0.2221m
#   DVL: mean=0.1101m, median=0.0949m, min=0.0130m, max=0.2500m
#
# 📐 PITCH MEASUREMENT NOISE (Baseline STD)
#   FFT: mean=7.7254°, median=7.0645°, min=4.1893°, max=15.9795°
#   SONAR: mean=3.7445°, median=3.7934°, min=0.8143°, max=8.9854°
#   DVL: mean=4.5033°, median=4.3645°, min=1.7703°, max=8.3640°
#
# ⚖️  PAIRWISE BIASES (Systematic Differences)
#   FFT vs DVL: mean=+0.0369m, median=+0.0460m, std=0.0597m
#   Sonar vs DVL: mean=-0.0428m, median=-0.0547m, std=0.0412m
#   FFT vs Sonar: mean=+0.0797m, median=+0.1041m, std=0.0678m
#
# 📉 LINEAR RELATIONSHIP QUALITY (R² scores)
#   Distance: FFT vs DVL: mean=0.5825, median=0.7291, min=0.0035
#   Distance: Sonar vs DVL: mean=0.5709, median=0.6912, min=0.0492
#   Pitch: FFT vs DVL: mean=0.0569, median=0.0115, min=0.0000
#   Pitch: Sonar vs DVL: mean=0.2137, median=0.1567, min=0.0025
#
# ⚠️  OUTLIER RATES
#   FFT: mean=21.33%, median=20.52%, max=41.19%
#   SONAR: mean=9.86%, median=8.27%, max=24.26%
#   DVL: mean=11.52%, median=10.86%, max=23.44%
#
# 📏 OUTLIER MAGNITUDE
#   FFT: mean=1.6335m, median=0.9860m, max=7.2592m
#   SONAR: mean=0.1979m, median=0.1335m, max=1.2715m
#   DVL: mean=0.3072m, median=0.2162m, max=1.0633m
#
# 🔗 OUTLIER CLUSTERING (Multi-frame events)
#   FFT: avg_cluster_size=14.5 frames, isolated=0.0%
#   SONAR: avg_cluster_size=18.3 frames, isolated=0.0%
#   DVL: avg_cluster_size=17.3 frames, isolated=0.0%
#
# 📊 OUTLIER MAGNITUDE CATEGORIES
#   FFT: small=33.3%, medium=34.0%, large=32.7%
#   SONAR: small=33.4%, medium=33.9%, large=32.8%
#   DVL: small=35.9%, medium=32.9%, large=31.2%
#
# 🏆 TOP 5 BAGS (by baseline percentage)
#   2024-08-20_17-08-14: 44.5% baseline, 3 segments
#   2024-08-20_15-00-24: 44.0% baseline, 6 segments
#   2024-08-20_17-02-00: 43.0% baseline, 2 segments
#   2024-08-20_13-57-42: 35.6% baseline, 3 segments
#   2024-08-20_17-40-54: 18.4% baseline, 3 segments
#
# ⚠️  BOTTOM 5 BAGS (by baseline percentage)
#   2024-08-20_13-39-34: 0.0% baseline, 0 segments
#   2024-08-20_13-40-35: 0.0% baseline, 0 segments
#   2024-08-20_13-42-51: 0.0% baseline, 0 segments
#   2024-08-20_18-47-40: 0.0% baseline, 0 segments
#   2024-08-22_14-06-43: 0.0% baseline, 0 segments
#
# ======================================================================
# ✓ Multi-bag summary complete
#   Full data available in: bag_summary.csv
#   Columns: 139
#
#   Column categories:
#     Metadata: 11
#     Distance metrics: 24
#     Pitch metrics: 24
#     X/Y position metrics: 12
#     Outlier metrics: 54
#     Correlation metrics: 0
#
# 📊 Additional insights:
#   DataFrame available for custom analysis
#   Example: summary_df[summary_df['baseline_percentage'] > 50]

# %% [markdown]
# ## Regenerate Multi-Bag Summary (Optional)
#
# Run this cell to regenerate the comprehensive bag summary CSV with all updated metrics including outlier characteristics.

# %%
# Regenerate the multi-bag summary CSV with all metrics
from utils.comparison_analysis import generate_multi_bag_summary_csv

print("Regenerating bag_summary.csv with all metrics...")
print("This may take a few minutes depending on the number of bags.\n")

output_path = generate_multi_bag_summary_csv(
    comparison_data_dir=COMPARISON_DATA_DIR,
    output_path=COMPARISON_DATA_DIR / "bag_summary.csv"
)

if output_path:
    print("\n" + "="*70)
    print("✓ Summary CSV regenerated successfully!")
    print(f"  Location: {output_path}")
    print("\nThe summary now includes:")
    print("  ✓ Outlier magnitude metrics (mean, median, max)")
    print("  ✓ Outlier clustering analysis (cluster count, sizes)")
    print("  ✓ Isolated vs. multi-frame outlier statistics")
    print("\nRe-run the 'Multi-Bag Summary Analysis' cell above to see the updated statistics.")
else:
    print("\n✗ Failed to regenerate summary CSV")
# Out:
# Regenerating bag_summary.csv with all metrics...
# This may take a few minutes depending on the number of bags.
#
#
# === GENERATING MULTI-BAG SUMMARY CSV ===
#
# Found 46 bags to process
#
# Processing: ._2024-08-20_13-39-34
#   ✗ Error processing ._2024-08-20_13-39-34: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-40-35
#   ✗ Error processing ._2024-08-20_13-40-35: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-42-51
#   ✗ Error processing ._2024-08-20_13-42-51: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-55-34
#   ✗ Error processing ._2024-08-20_13-55-34: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-57-42
#   ✗ Error processing ._2024-08-20_13-57-42: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-16-05
#   ✗ Error processing ._2024-08-20_14-16-05: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-22-12
#   ✗ Error processing ._2024-08-20_14-22-12: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-24-35
#   ✗ Error processing ._2024-08-20_14-24-35: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-31-29
#   ✗ Error processing ._2024-08-20_14-31-29: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-57-38
#   ✗ Error processing ._2024-08-20_14-57-38: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_15-00-24
#   ✗ Error processing ._2024-08-20_15-00-24: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_15-14-40
#   ✗ Error processing ._2024-08-20_15-14-40: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_16-57-46
#   ✗ Error processing ._2024-08-20_16-57-46: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-02-00
#   ✗ Error processing ._2024-08-20_17-02-00: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-08-14
#   ✗ Error processing ._2024-08-20_17-08-14: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-14-36
#   ✗ Error processing ._2024-08-20_17-14-36: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-39-32
#   ✗ Error processing ._2024-08-20_17-39-32: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-40-54
#   ✗ Error processing ._2024-08-20_17-40-54: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_18-12-20
#   ✗ Error processing ._2024-08-20_18-12-20: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_18-47-40
#   ✗ Error processing ._2024-08-20_18-47-40: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-06-43
#   ✗ Error processing ._2024-08-22_14-06-43: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-29-05
#   ✗ Error processing ._2024-08-22_14-29-05: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-47-39
#   ✗ Error processing ._2024-08-22_14-47-39: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: 2024-08-20_13-39-34
# Pairwise differences computed:
#   diff_fft_nav: 1453 valid samples, mean=-0.474, std=0.591
#   diff_sonar_nav: 1453 valid samples, mean=0.537, std=0.572
#   diff_fft_sonar: 1502 valid samples, mean=-1.009, std=0.182
#   diff_pitch_fft_nav: 1453 valid samples, mean=-8.567, std=19.733
#   diff_pitch_sonar_nav: 1453 valid samples, mean=-8.905, std=17.342
#   diff_pitch_fft_sonar: 1502 valid samples, mean=0.630, std=18.768
#   diff_x_fft_nav: 1453 valid samples, mean=-0.436, std=0.609
#   diff_x_sonar_nav: 1453 valid samples, mean=0.483, std=0.603
#   diff_x_fft_sonar: 1502 valid samples, mean=-0.916, std=0.226
#   diff_y_fft_nav: 1453 valid samples, mean=-0.221, std=0.462
#   diff_y_sonar_nav: 1453 valid samples, mean=-0.301, std=0.495
#   diff_y_fft_sonar: 1502 valid samples, mean=0.093, std=0.675
# Rolling window: 111 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1502 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 88 outliers (5.86%), MAD = 0.0420 m
# Sonar: 174 outliers (11.58%), MAD = 0.0252 m
# DVL: 295 outliers (19.64%), MAD = 0.0890 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3614 m, Median: 0.1971 m, Max: 1.5304 m
#   Magnitude Categories:
#     Small (≤0.1692m): 29 (33.0%)
#     Medium (0.1692-0.2210m): 31 (35.2%)
#     Large (>0.2210m): 28 (31.8%)
#   Clustering:
#     Total clusters: 19
#     Avg cluster size: 5.6 frames
#     Max cluster size: 15 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 19 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1422 m, Median: 0.1329 m, Max: 0.2328 m
#   Magnitude Categories:
#     Small (≤0.1196m): 59 (33.9%)
#     Medium (0.1196-0.1596m): 57 (32.8%)
#     Large (>0.1596m): 58 (33.3%)
#   Clustering:
#     Total clusters: 16
#     Avg cluster size: 11.9 frames
#     Max cluster size: 61 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 16 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.9742 m, Median: 0.9100 m, Max: 1.7600 m
#   Magnitude Categories:
#     Small (≤0.7602m): 98 (33.2%)
#     Medium (0.7602-1.0598m): 99 (33.6%)
#     Large (>1.0598m): 98 (33.2%)
#   Clustering:
#     Total clusters: 31
#     Avg cluster size: 10.5 frames
#     Max cluster size: 59 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 31 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-40-35
# Pairwise differences computed:
#   diff_fft_nav: 1596 valid samples, mean=-0.379, std=0.779
#   diff_sonar_nav: 1596 valid samples, mean=0.680, std=0.311
#   diff_fft_sonar: 1610 valid samples, mean=-1.058, std=0.675
#   diff_pitch_fft_nav: 1596 valid samples, mean=-1.352, std=25.446
#   diff_pitch_sonar_nav: 1596 valid samples, mean=-17.913, std=13.766
#   diff_pitch_fft_sonar: 1610 valid samples, mean=16.683, std=25.768
#   diff_x_fft_nav: 1596 valid samples, mean=-0.351, std=0.749
#   diff_x_sonar_nav: 1596 valid samples, mean=0.431, std=0.342
#   diff_x_fft_sonar: 1610 valid samples, mean=-0.783, std=0.510
#   diff_y_fft_nav: 1596 valid samples, mean=-0.027, std=0.537
#   diff_y_sonar_nav: 1596 valid samples, mean=-0.764, std=0.473
#   diff_y_fft_sonar: 1610 valid samples, mean=0.741, std=0.791
# Rolling window: 113 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1611 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 156 outliers (9.68%), MAD = 0.0716 m
# Sonar: 108 outliers (6.70%), MAD = 0.0265 m
# DVL: 175 outliers (10.86%), MAD = 0.1038 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.4426 m, Median: 0.3444 m, Max: 3.0585 m
#   Magnitude Categories:
#     Small (≤0.3020m): 52 (33.3%)
#     Medium (0.3020-0.3803m): 52 (33.3%)
#     Large (>0.3803m): 52 (33.3%)
#   Clustering:
#     Total clusters: 17
#     Avg cluster size: 10.2 frames
#     Max cluster size: 26 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 17 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1950 m, Median: 0.1944 m, Max: 0.4161 m
#   Magnitude Categories:
#     Small (≤0.1720m): 36 (33.3%)
#     Medium (0.1720-0.2280m): 36 (33.3%)
#     Large (>0.2280m): 36 (33.3%)
#   Clustering:
#     Total clusters: 8
#     Avg cluster size: 14.5 frames
#     Max cluster size: 69 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 8 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.5672 m, Median: 0.4900 m, Max: 1.2600 m
#   Magnitude Categories:
#     Small (≤0.4700m): 66 (37.7%)
#     Medium (0.4700-0.5500m): 57 (32.6%)
#     Large (>0.5500m): 52 (29.7%)
#   Clustering:
#     Total clusters: 14
#     Avg cluster size: 13.5 frames
#     Max cluster size: 58 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 14 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-42-51
# Pairwise differences computed:
#   diff_fft_nav: 1499 valid samples, mean=-0.973, std=0.990
#   diff_sonar_nav: 1593 valid samples, mean=0.683, std=0.751
#   diff_fft_sonar: 1518 valid samples, mean=-1.672, std=1.136
#   diff_pitch_fft_nav: 1499 valid samples, mean=6.985, std=35.772
#   diff_pitch_sonar_nav: 1593 valid samples, mean=-17.923, std=32.231
#   diff_pitch_fft_sonar: 1518 valid samples, mean=24.151, std=42.558
#   diff_x_fft_nav: 1499 valid samples, mean=-0.835, std=0.979
#   diff_x_sonar_nav: 1593 valid samples, mean=0.005, std=0.788
#   diff_x_fft_sonar: 1518 valid samples, mean=-0.877, std=0.591
#   diff_y_fft_nav: 1499 valid samples, mean=0.294, std=0.770
#   diff_y_sonar_nav: 1593 valid samples, mean=-1.040, std=1.509
#   diff_y_fft_sonar: 1518 valid samples, mean=1.305, std=1.654
# Rolling window: 100 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1612 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 294 outliers (18.24%), MAD = 0.0714 m
# Sonar: 391 outliers (24.26%), MAD = 0.0435 m
# DVL: 250 outliers (15.51%), MAD = 0.1779 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.1300 m, Median: 0.9731 m, Max: 4.5954 m
#   Magnitude Categories:
#     Small (≤0.8144m): 97 (33.0%)
#     Medium (0.8144-1.1157m): 100 (34.0%)
#     Large (>1.1157m): 97 (33.0%)
#   Clustering:
#     Total clusters: 33
#     Avg cluster size: 9.9 frames
#     Max cluster size: 41 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 33 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.3939 m, Median: 0.3049 m, Max: 1.0430 m
#   Magnitude Categories:
#     Small (≤0.2276m): 129 (33.0%)
#     Medium (0.2276-0.3881m): 133 (34.0%)
#     Large (>0.3881m): 129 (33.0%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 31.1 frames
#     Max cluster size: 86 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 1.0633 m, Median: 0.9000 m, Max: 2.3400 m
#   Magnitude Categories:
#     Small (≤0.7800m): 84 (33.6%)
#     Medium (0.7800-1.1100m): 86 (34.4%)
#     Large (>1.1100m): 80 (32.0%)
#   Clustering:
#     Total clusters: 25
#     Avg cluster size: 11.0 frames
#     Max cluster size: 62 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 25 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-55-34
# Pairwise differences computed:
#   diff_fft_nav: 1470 valid samples, mean=-2.023, std=1.227
#   diff_sonar_nav: 1467 valid samples, mean=0.105, std=0.717
#   diff_fft_sonar: 1471 valid samples, mean=-2.122, std=1.500
#   diff_pitch_fft_nav: 1470 valid samples, mean=-2.462, std=42.578
#   diff_pitch_sonar_nav: 1467 valid samples, mean=-6.174, std=17.699
#   diff_pitch_fft_sonar: 1471 valid samples, mean=3.589, std=46.027
#   diff_x_fft_nav: 1470 valid samples, mean=-1.992, std=1.217
#   diff_x_sonar_nav: 1467 valid samples, mean=-0.048, std=0.266
#   diff_x_fft_sonar: 1471 valid samples, mean=-1.938, std=1.252
#   diff_y_fft_nav: 1470 valid samples, mean=-0.078, std=0.549
#   diff_y_sonar_nav: 1467 valid samples, mean=-0.418, std=1.250
#   diff_y_fft_sonar: 1471 valid samples, mean=0.341, std=1.218
# Rolling window: 95 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 82 / 1476 (5.6%)
#
# Identifying stable baseline segments...
# Found 1 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 11:55:40 - 11:55:42 (2.3 s, 83 samples)
# === OUTLIER DETECTION ===
#
# FFT: 608 outliers (41.19%), MAD = 0.0011 m
# Sonar: 143 outliers (9.69%), MAD = 0.0255 m
# DVL: 155 outliers (10.50%), MAD = 0.0297 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.6533 m, Median: 0.1165 m, Max: 6.2905 m
#   Magnitude Categories:
#     Small (≤0.0541m): 207 (34.0%)
#     Medium (0.0541-0.2949m): 200 (32.9%)
#     Large (>0.2949m): 201 (33.1%)
#   Clustering:
#     Total clusters: 46
#     Avg cluster size: 14.2 frames
#     Max cluster size: 289 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 46 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 1.2715 m, Median: 0.8614 m, Max: 2.9525 m
#   Magnitude Categories:
#     Small (≤0.2935m): 47 (32.9%)
#     Medium (0.2935-2.3619m): 54 (37.8%)
#     Large (>2.3619m): 42 (29.4%)
#   Clustering:
#     Total clusters: 7
#     Avg cluster size: 21.4 frames
#     Max cluster size: 87 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 7 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2793 m, Median: 0.1800 m, Max: 0.5900 m
#   Magnitude Categories:
#     Small (≤0.1400m): 53 (34.2%)
#     Medium (0.1400-0.3918m): 51 (32.9%)
#     Large (>0.3918m): 51 (32.9%)
#   Clustering:
#     Total clusters: 12
#     Avg cluster size: 13.8 frames
#     Max cluster size: 40 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 12 (100.0%)
#
#   ✓ Processed 82 baseline samples, 1 stable segments
# Processing: 2024-08-20_13-57-42
# Pairwise differences computed:
#   diff_fft_nav: 2704 valid samples, mean=-0.133, std=1.176
#   diff_sonar_nav: 2704 valid samples, mean=-0.021, std=0.169
#   diff_fft_sonar: 2744 valid samples, mean=-0.110, std=1.148
#   diff_pitch_fft_nav: 2704 valid samples, mean=-1.633, std=21.451
#   diff_pitch_sonar_nav: 2704 valid samples, mean=-1.389, std=8.883
#   diff_pitch_fft_sonar: 2744 valid samples, mean=-0.085, std=21.371
#   diff_x_fft_nav: 2704 valid samples, mean=-0.145, std=1.167
#   diff_x_sonar_nav: 2704 valid samples, mean=-0.022, std=0.185
#   diff_x_fft_sonar: 2744 valid samples, mean=-0.120, std=1.136
#   diff_y_fft_nav: 2704 valid samples, mean=-0.003, std=0.430
#   diff_y_sonar_nav: 2704 valid samples, mean=-0.037, std=0.212
#   diff_y_fft_sonar: 2744 valid samples, mean=0.037, std=0.430
# Rolling window: 117 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 1017 / 2744 (37.1%)
#
# Identifying stable baseline segments...
# Found 3 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 11:57:58 - 11:58:09 (11.6 s, 405 samples)
#   Segment 2: 11:58:22 - 11:58:26 (4.2 s, 149 samples)
#   Segment 3: 11:58:50 - 11:59:02 (12.6 s, 421 samples)
# === OUTLIER DETECTION ===
#
# FFT: 518 outliers (18.88%), MAD = 0.0598 m
# Sonar: 157 outliers (5.72%), MAD = 0.0211 m
# DVL: 345 outliers (12.57%), MAD = 0.0297 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.3346 m, Median: 1.0244 m, Max: 19.5926 m
#   Magnitude Categories:
#     Small (≤0.4784m): 171 (33.0%)
#     Medium (0.4784-1.2642m): 176 (34.0%)
#     Large (>1.2642m): 171 (33.0%)
#   Clustering:
#     Total clusters: 33
#     Avg cluster size: 16.7 frames
#     Max cluster size: 120 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 33 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1032 m, Median: 0.1065 m, Max: 0.1430 m
#   Magnitude Categories:
#     Small (≤0.0917m): 52 (33.1%)
#     Medium (0.0917-0.1128m): 53 (33.8%)
#     Large (>0.1128m): 52 (33.1%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 13.1 frames
#     Max cluster size: 65 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2162 m, Median: 0.1500 m, Max: 0.8100 m
#   Magnitude Categories:
#     Small (≤0.1250m): 117 (33.9%)
#     Medium (0.1250-0.2348m): 114 (33.0%)
#     Large (>0.2348m): 114 (33.0%)
#   Clustering:
#     Total clusters: 19
#     Avg cluster size: 19.2 frames
#     Max cluster size: 67 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 19 (100.0%)
#
#   ✓ Processed 1017 baseline samples, 3 stable segments
# Processing: 2024-08-20_14-16-05
# Pairwise differences computed:
#   diff_fft_nav: 1602 valid samples, mean=0.007, std=0.679
#   diff_sonar_nav: 1602 valid samples, mean=-0.023, std=0.140
#   diff_fft_sonar: 1726 valid samples, mean=0.051, std=0.622
#   diff_pitch_fft_nav: 1602 valid samples, mean=-13.677, std=15.095
#   diff_pitch_sonar_nav: 1602 valid samples, mean=4.797, std=7.998
#   diff_pitch_fft_sonar: 1726 valid samples, mean=-17.926, std=12.851
#   diff_x_fft_nav: 1602 valid samples, mean=0.035, std=0.681
#   diff_x_sonar_nav: 1602 valid samples, mean=-0.047, std=0.157
#   diff_x_fft_sonar: 1726 valid samples, mean=0.100, std=0.614
#   diff_y_fft_nav: 1602 valid samples, mean=-0.354, std=0.293
#   diff_y_sonar_nav: 1602 valid samples, mean=0.111, std=0.154
#   diff_y_fft_sonar: 1726 valid samples, mean=-0.450, std=0.267
# Rolling window: 112 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 558 / 1727 (32.3%)
#
# Identifying stable baseline segments...
# Found 4 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:16:13 - 12:16:16 (2.4 s, 79 samples)
#   Segment 2: 12:16:16 - 12:16:19 (3.2 s, 113 samples)
#   Segment 3: 12:16:23 - 12:16:29 (6.7 s, 233 samples)
#   Segment 4: 12:16:32 - 12:16:33 (1.5 s, 51 samples)
# === OUTLIER DETECTION ===
#
# FFT: 271 outliers (15.69%), MAD = 0.0414 m
# Sonar: 108 outliers (6.25%), MAD = 0.0311 m
# DVL: 165 outliers (9.55%), MAD = 0.0297 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.9860 m, Median: 0.7034 m, Max: 6.4394 m
#   Magnitude Categories:
#     Small (≤0.1987m): 93 (34.3%)
#     Medium (0.1987-0.9911m): 88 (32.5%)
#     Large (>0.9911m): 90 (33.2%)
#   Clustering:
#     Total clusters: 19
#     Avg cluster size: 15.2 frames
#     Max cluster size: 106 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 19 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1497 m, Median: 0.1365 m, Max: 0.3039 m
#   Magnitude Categories:
#     Small (≤0.1351m): 36 (33.3%)
#     Medium (0.1351-0.1483m): 36 (33.3%)
#     Large (>0.1483m): 36 (33.3%)
#   Clustering:
#     Total clusters: 11
#     Avg cluster size: 10.8 frames
#     Max cluster size: 33 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 11 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2109 m, Median: 0.1600 m, Max: 0.9150 m
#   Magnitude Categories:
#     Small (≤0.1306m): 55 (33.3%)
#     Medium (0.1306-0.1900m): 62 (37.6%)
#     Large (>0.1900m): 48 (29.1%)
#   Clustering:
#     Total clusters: 11
#     Avg cluster size: 16.0 frames
#     Max cluster size: 43 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 11 (100.0%)
#
#   ✓ Processed 558 baseline samples, 4 stable segments
# Processing: 2024-08-20_14-22-12
# Pairwise differences computed:
#   diff_fft_nav: 2351 valid samples, mean=-0.349, std=5.519
#   diff_sonar_nav: 2350 valid samples, mean=-0.009, std=0.179
#   diff_fft_sonar: 2398 valid samples, mean=-0.357, std=5.448
#   diff_pitch_fft_nav: 2351 valid samples, mean=-20.280, std=17.801
#   diff_pitch_sonar_nav: 2350 valid samples, mean=5.881, std=8.084
#   diff_pitch_fft_sonar: 2398 valid samples, mean=-25.899, std=17.454
#   diff_x_fft_nav: 2351 valid samples, mean=-0.302, std=5.490
#   diff_x_sonar_nav: 2350 valid samples, mean=-0.052, std=0.186
#   diff_x_fft_sonar: 2398 valid samples, mean=-0.268, std=5.422
#   diff_y_fft_nav: 2351 valid samples, mean=-0.429, std=0.670
#   diff_y_sonar_nav: 2350 valid samples, mean=0.150, std=0.182
#   diff_y_fft_sonar: 2398 valid samples, mean=-0.575, std=0.646
# Rolling window: 113 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 635 / 2401 (26.4%)
#
# Identifying stable baseline segments...
# Found 4 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:22:23 - 12:22:29 (5.8 s, 201 samples)
#   Segment 2: 12:22:53 - 12:22:59 (5.9 s, 203 samples)
#   Segment 3: 12:22:59 - 12:23:05 (5.7 s, 196 samples)
#   Segment 4: 12:23:09 - 12:23:10 (1.1 s, 39 samples)
# === OUTLIER DETECTION ===
#
# FFT: 532 outliers (22.16%), MAD = 0.0716 m
# Sonar: 196 outliers (8.16%), MAD = 0.0327 m
# DVL: 267 outliers (11.12%), MAD = 0.0445 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 3.7420 m, Median: 1.2976 m, Max: 128.4813 m
#   Magnitude Categories:
#     Small (≤0.8193m): 177 (33.3%)
#     Medium (0.8193-1.9963m): 180 (33.8%)
#     Large (>1.9963m): 175 (32.9%)
#   Clustering:
#     Total clusters: 43
#     Avg cluster size: 13.4 frames
#     Max cluster size: 57 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 43 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1578 m, Median: 0.1463 m, Max: 0.4251 m
#   Magnitude Categories:
#     Small (≤0.1346m): 65 (33.2%)
#     Medium (0.1346-0.1583m): 67 (34.2%)
#     Large (>0.1583m): 64 (32.7%)
#   Clustering:
#     Total clusters: 30
#     Avg cluster size: 7.5 frames
#     Max cluster size: 59 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 30 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.3049 m, Median: 0.2200 m, Max: 0.8400 m
#   Magnitude Categories:
#     Small (≤0.1900m): 91 (34.1%)
#     Medium (0.1900-0.3244m): 88 (33.0%)
#     Large (>0.3244m): 88 (33.0%)
#   Clustering:
#     Total clusters: 19
#     Avg cluster size: 15.0 frames
#     Max cluster size: 43 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 19 (100.0%)
#
#   ✓ Processed 635 baseline samples, 4 stable segments
# Processing: 2024-08-20_14-24-35
# Pairwise differences computed:
#   diff_fft_nav: 2666 valid samples, mean=-0.650, std=2.323
#   diff_sonar_nav: 2666 valid samples, mean=-0.150, std=0.137
#   diff_fft_sonar: 2737 valid samples, mean=-0.527, std=2.294
#   diff_pitch_fft_nav: 2666 valid samples, mean=-5.557, std=32.271
#   diff_pitch_sonar_nav: 2666 valid samples, mean=0.192, std=7.324
#   diff_pitch_fft_sonar: 2737 valid samples, mean=-6.209, std=32.491
#   diff_x_fft_nav: 2666 valid samples, mean=-0.756, std=1.880
#   diff_x_sonar_nav: 2666 valid samples, mean=-0.152, std=0.141
#   diff_x_fft_sonar: 2737 valid samples, mean=-0.623, std=1.848
#   diff_y_fft_nav: 2666 valid samples, mean=-0.037, std=1.517
#   diff_y_sonar_nav: 2666 valid samples, mean=-0.005, std=0.213
#   diff_y_fft_sonar: 2737 valid samples, mean=-0.061, std=1.500
# Rolling window: 109 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 434 / 2738 (15.9%)
#
# Identifying stable baseline segments...
# Found 3 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:25:38 - 12:25:41 (3.2 s, 104 samples)
#   Segment 2: 12:25:42 - 12:25:47 (4.7 s, 160 samples)
#   Segment 3: 12:25:53 - 12:25:56 (3.3 s, 114 samples)
# === OUTLIER DETECTION ===
#
# FFT: 668 outliers (24.40%), MAD = 0.0660 m
# Sonar: 131 outliers (4.78%), MAD = 0.0307 m
# DVL: 279 outliers (10.19%), MAD = 0.0297 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.9365 m, Median: 0.9948 m, Max: 28.7613 m
#   Magnitude Categories:
#     Small (≤0.6501m): 222 (33.2%)
#     Medium (0.6501-1.2519m): 226 (33.8%)
#     Large (>1.2519m): 220 (32.9%)
#   Clustering:
#     Total clusters: 55
#     Avg cluster size: 13.1 frames
#     Max cluster size: 92 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 55 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1416 m, Median: 0.1321 m, Max: 0.2074 m
#   Magnitude Categories:
#     Small (≤0.1257m): 44 (33.6%)
#     Medium (0.1257-0.1421m): 44 (33.6%)
#     Large (>0.1421m): 43 (32.8%)
#   Clustering:
#     Total clusters: 17
#     Avg cluster size: 8.6 frames
#     Max cluster size: 58 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 17 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2026 m, Median: 0.1500 m, Max: 0.9200 m
#   Magnitude Categories:
#     Small (≤0.1337m): 92 (33.0%)
#     Medium (0.1337-0.1800m): 97 (34.8%)
#     Large (>0.1800m): 90 (32.3%)
#   Clustering:
#     Total clusters: 14
#     Avg cluster size: 20.9 frames
#     Max cluster size: 157 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 14 (100.0%)
#
#   ✓ Processed 434 baseline samples, 3 stable segments
# Processing: 2024-08-20_14-31-29
# Pairwise differences computed:
#   diff_fft_nav: 2229 valid samples, mean=-0.609, std=5.203
#   diff_sonar_nav: 2229 valid samples, mean=-0.064, std=0.256
#   diff_fft_sonar: 2230 valid samples, mean=-0.545, std=5.209
#   diff_pitch_fft_nav: 2229 valid samples, mean=-1.045, std=37.488
#   diff_pitch_sonar_nav: 2229 valid samples, mean=-3.083, std=22.084
#   diff_pitch_fft_sonar: 2230 valid samples, mean=2.032, std=38.617
#   diff_x_fft_nav: 2229 valid samples, mean=-0.665, std=5.112
#   diff_x_sonar_nav: 2229 valid samples, mean=-0.122, std=0.228
#   diff_x_fft_sonar: 2230 valid samples, mean=-0.543, std=5.115
#   diff_y_fft_nav: 2229 valid samples, mean=-0.017, std=1.203
#   diff_y_sonar_nav: 2229 valid samples, mean=-0.100, std=0.682
#   diff_y_fft_sonar: 2230 valid samples, mean=0.084, std=1.283
# Rolling window: 110 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 150 / 2235 (6.7%)
#
# Identifying stable baseline segments...
# Found 1 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:31:48 - 12:31:52 (4.3 s, 151 samples)
# === OUTLIER DETECTION ===
#
# FFT: 583 outliers (26.09%), MAD = 0.1341 m
# Sonar: 236 outliers (10.56%), MAD = 0.0309 m
# DVL: 446 outliers (19.96%), MAD = 0.0297 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 3.4211 m, Median: 1.5494 m, Max: 105.3777 m
#   Magnitude Categories:
#     Small (≤1.1076m): 193 (33.1%)
#     Medium (1.1076-1.7853m): 198 (34.0%)
#     Large (>1.7853m): 192 (32.9%)
#   Clustering:
#     Total clusters: 71
#     Avg cluster size: 9.2 frames
#     Max cluster size: 75 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 71 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.2085 m, Median: 0.1734 m, Max: 0.4384 m
#   Magnitude Categories:
#     Small (≤0.1535m): 78 (33.1%)
#     Medium (0.1535-0.2254m): 82 (34.7%)
#     Large (>0.2254m): 76 (32.2%)
#   Clustering:
#     Total clusters: 20
#     Avg cluster size: 12.8 frames
#     Max cluster size: 73 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 20 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.3962 m, Median: 0.3100 m, Max: 1.3400 m
#   Magnitude Categories:
#     Small (≤0.1900m): 148 (33.2%)
#     Medium (0.1900-0.5400m): 152 (34.1%)
#     Large (>0.5400m): 146 (32.7%)
#   Clustering:
#     Total clusters: 20
#     Avg cluster size: 23.3 frames
#     Max cluster size: 102 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 20 (100.0%)
#
#   ✓ Processed 150 baseline samples, 1 stable segments
# Processing: 2024-08-20_14-57-38
# Pairwise differences computed:
#   diff_fft_nav: 3115 valid samples, mean=-0.193, std=4.748
#   diff_sonar_nav: 3115 valid samples, mean=-0.039, std=0.117
#   diff_fft_sonar: 3162 valid samples, mean=-0.179, std=4.715
#   diff_pitch_fft_nav: 3115 valid samples, mean=0.796, std=23.489
#   diff_pitch_sonar_nav: 3115 valid samples, mean=-0.861, std=5.404
#   diff_pitch_fft_sonar: 3162 valid samples, mean=0.961, std=23.706
#   diff_x_fft_nav: 3115 valid samples, mean=-0.228, std=4.740
#   diff_x_sonar_nav: 3115 valid samples, mean=-0.039, std=0.123
#   diff_x_fft_sonar: 3162 valid samples, mean=-0.211, std=4.705
#   diff_y_fft_nav: 3115 valid samples, mean=0.066, std=0.451
#   diff_y_sonar_nav: 3115 valid samples, mean=-0.026, std=0.108
#   diff_y_fft_sonar: 3162 valid samples, mean=0.079, std=0.458
# Rolling window: 111 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 1420 / 3163 (44.9%)
#
# Identifying stable baseline segments...
# Found 4 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:58:05 - 12:58:16 (11.1 s, 387 samples)
#   Segment 2: 12:58:35 - 12:58:53 (18.7 s, 645 samples)
#   Segment 3: 12:58:55 - 12:59:04 (8.4 s, 288 samples)
#   Segment 4: 12:59:10 - 12:59:12 (2.9 s, 100 samples)
# === OUTLIER DETECTION ===
#
# FFT: 776 outliers (24.53%), MAD = 0.0322 m
# Sonar: 493 outliers (15.59%), MAD = 0.0174 m
# DVL: 435 outliers (13.75%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.7860 m, Median: 0.5009 m, Max: 143.1498 m
#   Magnitude Categories:
#     Small (≤0.2688m): 256 (33.0%)
#     Medium (0.2688-0.8739m): 267 (34.4%)
#     Large (>0.8739m): 253 (32.6%)
#   Clustering:
#     Total clusters: 37
#     Avg cluster size: 22.0 frames
#     Max cluster size: 113 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 37 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0987 m, Median: 0.0883 m, Max: 0.2451 m
#   Magnitude Categories:
#     Small (≤0.0755m): 167 (33.9%)
#     Medium (0.0755-0.1074m): 164 (33.3%)
#     Large (>0.1074m): 162 (32.9%)
#   Clustering:
#     Total clusters: 24
#     Avg cluster size: 21.5 frames
#     Max cluster size: 93 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 24 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1432 m, Median: 0.1100 m, Max: 0.5500 m
#   Magnitude Categories:
#     Small (≤0.0750m): 146 (33.6%)
#     Medium (0.0750-0.1700m): 147 (33.8%)
#     Large (>0.1700m): 142 (32.6%)
#   Clustering:
#     Total clusters: 31
#     Avg cluster size: 15.0 frames
#     Max cluster size: 117 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 31 (100.0%)
#
#   ✓ Processed 1420 baseline samples, 4 stable segments
# Processing: 2024-08-20_15-00-24
# Pairwise differences computed:
#   diff_fft_nav: 2914 valid samples, mean=-0.452, std=9.694
#   diff_sonar_nav: 2914 valid samples, mean=-0.105, std=0.077
#   diff_fft_sonar: 3029 valid samples, mean=-0.334, std=9.507
#   diff_pitch_fft_nav: 2914 valid samples, mean=-3.343, std=12.403
#   diff_pitch_sonar_nav: 2914 valid samples, mean=-0.139, std=4.696
#   diff_pitch_fft_sonar: 3029 valid samples, mean=-3.520, std=13.108
#   diff_x_fft_nav: 2914 valid samples, mean=-0.477, std=9.686
#   diff_x_sonar_nav: 2914 valid samples, mean=-0.105, std=0.079
#   diff_x_fft_sonar: 3029 valid samples, mean=-0.360, std=9.499
#   diff_y_fft_nav: 2914 valid samples, mean=-0.062, std=0.481
#   diff_y_sonar_nav: 2914 valid samples, mean=-0.004, std=0.113
#   diff_y_fft_sonar: 3029 valid samples, mean=-0.067, std=0.485
# Rolling window: 115 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 1352 / 3029 (44.6%)
#
# Identifying stable baseline segments...
# Found 6 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 13:00:29 - 13:00:43 (14.4 s, 512 samples)
#   Segment 2: 13:00:49 - 13:00:58 (8.8 s, 312 samples)
#   Segment 3: 13:01:07 - 13:01:09 (2.0 s, 73 samples)
#   Segment 4: 13:01:23 - 13:01:26 (2.2 s, 78 samples)
#   Segment 5: 13:01:33 - 13:01:42 (8.8 s, 316 samples)
#   Segment 6: 13:01:46 - 13:01:48 (1.8 s, 67 samples)
# === OUTLIER DETECTION ===
#
# FFT: 487 outliers (16.08%), MAD = 0.0387 m
# Sonar: 189 outliers (6.24%), MAD = 0.0236 m
# DVL: 212 outliers (7.00%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 3.2939 m, Median: 0.3387 m, Max: 259.6188 m
#   Magnitude Categories:
#     Small (≤0.2208m): 162 (33.3%)
#     Medium (0.2208-0.6668m): 167 (34.3%)
#     Large (>0.6668m): 158 (32.4%)
#   Clustering:
#     Total clusters: 55
#     Avg cluster size: 9.9 frames
#     Max cluster size: 71 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 55 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1232 m, Median: 0.1026 m, Max: 0.2266 m
#   Magnitude Categories:
#     Small (≤0.0946m): 64 (33.9%)
#     Medium (0.0946-0.1250m): 62 (32.8%)
#     Large (>0.1250m): 63 (33.3%)
#   Clustering:
#     Total clusters: 22
#     Avg cluster size: 9.6 frames
#     Max cluster size: 73 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 22 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1028 m, Median: 0.0700 m, Max: 0.8550 m
#   Magnitude Categories:
#     Small (≤0.0600m): 79 (37.3%)
#     Medium (0.0600-0.0800m): 74 (34.9%)
#     Large (>0.0800m): 59 (27.8%)
#   Clustering:
#     Total clusters: 6
#     Avg cluster size: 36.3 frames
#     Max cluster size: 65 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 6 (100.0%)
#
#   ✓ Processed 1352 baseline samples, 6 stable segments
# Processing: 2024-08-20_15-14-40
# Pairwise differences computed:
#   diff_fft_nav: 5567 valid samples, mean=-0.253, std=4.413
#   diff_sonar_nav: 5567 valid samples, mean=-0.091, std=0.075
#   diff_fft_sonar: 5665 valid samples, mean=-0.159, std=4.374
#   diff_pitch_fft_nav: 5567 valid samples, mean=-5.336, std=16.359
#   diff_pitch_sonar_nav: 5567 valid samples, mean=-0.121, std=5.888
#   diff_pitch_fft_sonar: 5665 valid samples, mean=-5.025, std=17.295
#   diff_x_fft_nav: 5567 valid samples, mean=-0.278, std=4.336
#   diff_x_sonar_nav: 5567 valid samples, mean=-0.096, std=0.073
#   diff_x_fft_sonar: 5665 valid samples, mean=-0.177, std=4.298
#   diff_y_fft_nav: 5567 valid samples, mean=-0.086, std=0.853
#   diff_y_sonar_nav: 5567 valid samples, mean=-0.008, std=0.128
#   diff_y_fft_sonar: 5665 valid samples, mean=-0.074, std=0.858
# Rolling window: 114 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 3434 / 5668 (60.6%)
#
# Identifying stable baseline segments...
# Found 7 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 13:14:47 - 13:15:16 (28.4 s, 990 samples)
#   Segment 2: 13:15:17 - 13:15:27 (10.7 s, 375 samples)
#   Segment 3: 13:15:29 - 13:15:33 (3.9 s, 130 samples)
#   Segment 4: 13:15:38 - 13:15:58 (20.4 s, 710 samples)
#   Segment 5: 13:16:48 - 13:17:00 (12.3 s, 421 samples)
#   Segment 6: 13:17:01 - 13:17:05 (4.1 s, 140 samples)
#   Segment 7: 13:17:06 - 13:17:26 (19.8 s, 649 samples)
# === OUTLIER DETECTION ===
#
# FFT: 1163 outliers (20.52%), MAD = 0.0324 m
# Sonar: 287 outliers (5.06%), MAD = 0.0144 m
# DVL: 120 outliers (2.12%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 2.2058 m, Median: 0.5033 m, Max: 98.6382 m
#   Magnitude Categories:
#     Small (≤0.2184m): 384 (33.0%)
#     Medium (0.2184-1.0395m): 395 (34.0%)
#     Large (>1.0395m): 384 (33.0%)
#   Clustering:
#     Total clusters: 108
#     Avg cluster size: 11.8 frames
#     Max cluster size: 86 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 108 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0815 m, Median: 0.0684 m, Max: 0.1795 m
#   Magnitude Categories:
#     Small (≤0.0592m): 97 (33.8%)
#     Medium (0.0592-0.0838m): 98 (34.1%)
#     Large (>0.0838m): 92 (32.1%)
#   Clustering:
#     Total clusters: 31
#     Avg cluster size: 10.3 frames
#     Max cluster size: 74 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 31 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.0936 m, Median: 0.0800 m, Max: 0.6700 m
#   Magnitude Categories:
#     Small (≤0.0700m): 59 (49.2%)
#     Medium (0.0700-0.0800m): 34 (28.3%)
#     Large (>0.0800m): 27 (22.5%)
#   Clustering:
#     Total clusters: 12
#     Avg cluster size: 11.0 frames
#     Max cluster size: 39 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 12 (100.0%)
#
#   ✓ Processed 3434 baseline samples, 7 stable segments
# Processing: 2024-08-20_16-57-46
# Pairwise differences computed:
#   diff_fft_nav: 4286 valid samples, mean=0.433, std=12.076
#   diff_sonar_nav: 4346 valid samples, mean=-0.089, std=0.102
#   diff_fft_sonar: 4307 valid samples, mean=0.522, std=12.049
#   diff_pitch_fft_nav: 4286 valid samples, mean=-11.636, std=16.120
#   diff_pitch_sonar_nav: 4346 valid samples, mean=-1.893, std=9.438
#   diff_pitch_fft_sonar: 4307 valid samples, mean=-10.286, std=13.551
#   diff_x_fft_nav: 4286 valid samples, mean=0.394, std=12.072
#   diff_x_sonar_nav: 4346 valid samples, mean=-0.090, std=0.108
#   diff_x_fft_sonar: 4307 valid samples, mean=0.484, std=12.046
#   diff_y_fft_nav: 4286 valid samples, mean=-0.255, std=0.447
#   diff_y_sonar_nav: 4346 valid samples, mean=-0.043, std=0.186
#   diff_y_fft_sonar: 4307 valid samples, mean=-0.223, std=0.450
# Rolling window: 107 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 2715 / 4370 (62.1%)
#
# Identifying stable baseline segments...
# Found 6 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 14:57:51 - 14:57:53 (2.0 s, 69 samples)
#   Segment 2: 14:57:54 - 14:58:38 (44.2 s, 1514 samples)
#   Segment 3: 14:58:48 - 14:59:01 (13.0 s, 432 samples)
#   Segment 4: 14:59:02 - 14:59:05 (3.0 s, 99 samples)
#   Segment 5: 14:59:08 - 14:59:18 (9.8 s, 313 samples)
#   Segment 6: 14:59:32 - 14:59:41 (9.1 s, 286 samples)
# === OUTLIER DETECTION ===
#
# FFT: 1059 outliers (24.23%), MAD = 0.0220 m
# Sonar: 348 outliers (7.96%), MAD = 0.0105 m
# DVL: 482 outliers (11.03%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 2.7390 m, Median: 0.3042 m, Max: 390.9647 m
#   Magnitude Categories:
#     Small (≤0.1835m): 350 (33.1%)
#     Medium (0.1835-0.7095m): 359 (33.9%)
#     Large (>0.7095m): 350 (33.1%)
#   Clustering:
#     Total clusters: 76
#     Avg cluster size: 14.9 frames
#     Max cluster size: 85 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 76 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1129 m, Median: 0.0869 m, Max: 0.3963 m
#   Magnitude Categories:
#     Small (≤0.0703m): 115 (33.0%)
#     Medium (0.0703-0.1095m): 119 (34.2%)
#     Large (>0.1095m): 114 (32.8%)
#   Clustering:
#     Total clusters: 18
#     Avg cluster size: 20.3 frames
#     Max cluster size: 95 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 18 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2032 m, Median: 0.1700 m, Max: 0.7600 m
#   Magnitude Categories:
#     Small (≤0.1337m): 159 (33.0%)
#     Medium (0.1337-0.2300m): 167 (34.6%)
#     Large (>0.2300m): 156 (32.4%)
#   Clustering:
#     Total clusters: 17
#     Avg cluster size: 29.3 frames
#     Max cluster size: 195 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 17 (100.0%)
#
#   ✓ Processed 2715 baseline samples, 6 stable segments
# Processing: 2024-08-20_17-02-00
# Pairwise differences computed:
#   diff_fft_nav: 1739 valid samples, mean=-0.268, std=0.444
#   diff_sonar_nav: 1813 valid samples, mean=0.035, std=0.448
#   diff_fft_sonar: 1769 valid samples, mean=-0.238, std=0.523
#   diff_pitch_fft_nav: 1739 valid samples, mean=5.272, std=17.470
#   diff_pitch_sonar_nav: 1813 valid samples, mean=-4.176, std=13.194
#   diff_pitch_fft_sonar: 1769 valid samples, mean=8.841, std=17.994
#   diff_x_fft_nav: 1739 valid samples, mean=-0.258, std=0.415
#   diff_x_sonar_nav: 1813 valid samples, mean=-0.004, std=0.313
#   diff_x_fft_sonar: 1769 valid samples, mean=-0.227, std=0.461
#   diff_y_fft_nav: 1739 valid samples, mean=0.101, std=0.227
#   diff_y_sonar_nav: 1813 valid samples, mean=-0.123, std=0.453
#   diff_y_fft_sonar: 1769 valid samples, mean=0.152, std=0.275
# Rolling window: 100 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 846 / 1851 (45.7%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 15:02:08 - 15:02:17 (9.7 s, 326 samples)
#   Segment 2: 15:02:27 - 15:02:43 (16.2 s, 522 samples)
# === OUTLIER DETECTION ===
#
# FFT: 312 outliers (16.86%), MAD = 0.0181 m
# Sonar: 237 outliers (12.80%), MAD = 0.0129 m
# DVL: 406 outliers (21.93%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.5415 m, Median: 0.4179 m, Max: 2.7162 m
#   Magnitude Categories:
#     Small (≤0.1087m): 105 (33.7%)
#     Medium (0.1087-0.7361m): 105 (33.7%)
#     Large (>0.7361m): 102 (32.7%)
#   Clustering:
#     Total clusters: 14
#     Avg cluster size: 23.3 frames
#     Max cluster size: 106 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 14 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.3307 m, Median: 0.0843 m, Max: 1.0479 m
#   Magnitude Categories:
#     Small (≤0.0684m): 79 (33.3%)
#     Medium (0.0684-0.3092m): 80 (33.8%)
#     Large (>0.3092m): 78 (32.9%)
#   Clustering:
#     Total clusters: 10
#     Avg cluster size: 24.6 frames
#     Max cluster size: 91 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 10 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.3828 m, Median: 0.2000 m, Max: 2.2100 m
#   Magnitude Categories:
#     Small (≤0.1482m): 134 (33.0%)
#     Medium (0.1482-0.3200m): 140 (34.5%)
#     Large (>0.3200m): 132 (32.5%)
#   Clustering:
#     Total clusters: 12
#     Avg cluster size: 34.8 frames
#     Max cluster size: 80 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 12 (100.0%)
#
#   ✓ Processed 846 baseline samples, 2 stable segments
# Processing: 2024-08-20_17-08-14
# Pairwise differences computed:
#   diff_fft_nav: 3742 valid samples, mean=0.212, std=21.111
#   diff_sonar_nav: 3775 valid samples, mean=-0.070, std=0.076
#   diff_fft_sonar: 3762 valid samples, mean=0.281, std=21.054
#   diff_pitch_fft_nav: 3742 valid samples, mean=-5.963, std=25.207
#   diff_pitch_sonar_nav: 3775 valid samples, mean=-2.001, std=9.052
#   diff_pitch_fft_sonar: 3762 valid samples, mean=-4.080, std=26.538
#   diff_x_fft_nav: 3742 valid samples, mean=0.200, std=21.094
#   diff_x_sonar_nav: 3775 valid samples, mean=-0.071, std=0.081
#   diff_x_fft_sonar: 3762 valid samples, mean=0.271, std=21.038
#   diff_y_fft_nav: 3742 valid samples, mean=-0.116, std=0.843
#   diff_y_sonar_nav: 3775 valid samples, mean=-0.008, std=0.078
#   diff_y_fft_sonar: 3762 valid samples, mean=-0.108, std=0.843
# Rolling window: 113 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 1753 / 3795 (46.2%)
#
# Identifying stable baseline segments...
# Found 3 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 15:08:52 - 15:09:18 (26.5 s, 914 samples)
#   Segment 2: 15:09:28 - 15:09:44 (16.1 s, 559 samples)
#   Segment 3: 15:09:55 - 15:10:03 (8.1 s, 283 samples)
# === OUTLIER DETECTION ===
#
# FFT: 759 outliers (20.00%), MAD = 0.0137 m
# Sonar: 242 outliers (6.38%), MAD = 0.0109 m
# DVL: 358 outliers (9.43%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 7.2592 m, Median: 0.5238 m, Max: 587.6757 m
#   Magnitude Categories:
#     Small (≤0.2714m): 251 (33.1%)
#     Medium (0.2714-0.7543m): 259 (34.1%)
#     Large (>0.7543m): 249 (32.8%)
#   Clustering:
#     Total clusters: 38
#     Avg cluster size: 21.0 frames
#     Max cluster size: 101 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 38 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0973 m, Median: 0.0766 m, Max: 0.2536 m
#   Magnitude Categories:
#     Small (≤0.0521m): 81 (33.5%)
#     Medium (0.0521-0.1012m): 81 (33.5%)
#     Large (>0.1012m): 80 (33.1%)
#   Clustering:
#     Total clusters: 29
#     Avg cluster size: 9.3 frames
#     Max cluster size: 59 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 29 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1475 m, Median: 0.1300 m, Max: 0.4900 m
#   Magnitude Categories:
#     Small (≤0.0800m): 120 (33.5%)
#     Medium (0.0800-0.1700m): 124 (34.6%)
#     Large (>0.1700m): 114 (31.8%)
#   Clustering:
#     Total clusters: 18
#     Avg cluster size: 20.9 frames
#     Max cluster size: 93 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 18 (100.0%)
#
#   ✓ Processed 1753 baseline samples, 3 stable segments
# Processing: 2024-08-20_17-14-36
# Pairwise differences computed:
#   diff_fft_nav: 1566 valid samples, mean=-0.348, std=0.711
#   diff_sonar_nav: 1597 valid samples, mean=-0.044, std=0.246
#   diff_fft_sonar: 1572 valid samples, mean=-0.294, std=0.757
#   diff_pitch_fft_nav: 1566 valid samples, mean=-9.926, std=28.037
#   diff_pitch_sonar_nav: 1597 valid samples, mean=-2.439, std=13.958
#   diff_pitch_fft_sonar: 1572 valid samples, mean=-7.729, std=28.243
#   diff_x_fft_nav: 1566 valid samples, mean=-0.364, std=0.688
#   diff_x_sonar_nav: 1597 valid samples, mean=-0.038, std=0.254
#   diff_x_fft_sonar: 1572 valid samples, mean=-0.314, std=0.727
#   diff_y_fft_nav: 1566 valid samples, mean=-0.188, std=0.319
#   diff_y_sonar_nav: 1597 valid samples, mean=-0.052, std=0.277
#   diff_y_fft_sonar: 1572 valid samples, mean=-0.139, std=0.345
# Rolling window: 105 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 243 / 1604 (15.1%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 15:14:46 - 15:14:50 (3.1 s, 109 samples)
#   Segment 2: 15:14:53 - 15:14:57 (3.9 s, 136 samples)
# === OUTLIER DETECTION ===
#
# FFT: 328 outliers (20.45%), MAD = 0.0642 m
# Sonar: 159 outliers (9.91%), MAD = 0.0215 m
# DVL: 376 outliers (23.44%), MAD = 0.0445 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.3018 m, Median: 1.3455 m, Max: 2.4553 m
#   Magnitude Categories:
#     Small (≤1.1253m): 110 (33.5%)
#     Medium (1.1253-1.4965m): 113 (34.5%)
#     Large (>1.4965m): 105 (32.0%)
#   Clustering:
#     Total clusters: 23
#     Avg cluster size: 15.3 frames
#     Max cluster size: 96 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 23 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1335 m, Median: 0.1128 m, Max: 0.3735 m
#   Magnitude Categories:
#     Small (≤0.0978m): 53 (33.3%)
#     Medium (0.0978-0.1353m): 53 (33.3%)
#     Large (>0.1353m): 53 (33.3%)
#   Clustering:
#     Total clusters: 12
#     Avg cluster size: 14.2 frames
#     Max cluster size: 54 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 12 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.3495 m, Median: 0.3000 m, Max: 0.9400 m
#   Magnitude Categories:
#     Small (≤0.2300m): 126 (33.5%)
#     Medium (0.2300-0.4000m): 129 (34.3%)
#     Large (>0.4000m): 121 (32.2%)
#   Clustering:
#     Total clusters: 17
#     Avg cluster size: 23.1 frames
#     Max cluster size: 78 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 17 (100.0%)
#
#   ✓ Processed 243 baseline samples, 2 stable segments
# Processing: 2024-08-20_17-39-32
# Pairwise differences computed:
#   diff_fft_nav: 1501 valid samples, mean=-0.120, std=0.477
#   diff_sonar_nav: 1527 valid samples, mean=-0.043, std=0.225
#   diff_fft_sonar: 1516 valid samples, mean=-0.089, std=0.629
#   diff_pitch_fft_nav: 1501 valid samples, mean=-10.210, std=25.117
#   diff_pitch_sonar_nav: 1527 valid samples, mean=-5.063, std=10.244
#   diff_pitch_fft_sonar: 1516 valid samples, mean=-4.953, std=24.388
#   diff_x_fft_nav: 1501 valid samples, mean=-0.152, std=0.454
#   diff_x_sonar_nav: 1527 valid samples, mean=-0.045, std=0.220
#   diff_x_fft_sonar: 1516 valid samples, mean=-0.117, std=0.583
#   diff_y_fft_nav: 1501 valid samples, mean=-0.233, std=0.224
#   diff_y_sonar_nav: 1527 valid samples, mean=-0.102, std=0.223
#   diff_y_fft_sonar: 1516 valid samples, mean=-0.123, std=0.286
# Rolling window: 112 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 689 / 1543 (44.7%)
#
# Identifying stable baseline segments...
# Found 4 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 15:39:38 - 15:39:43 (5.0 s, 174 samples)
#   Segment 2: 15:39:47 - 15:39:51 (3.9 s, 132 samples)
#   Segment 3: 15:39:54 - 15:39:58 (3.6 s, 129 samples)
#   Segment 4: 15:40:01 - 15:40:08 (6.6 s, 233 samples)
# === OUTLIER DETECTION ===
#
# FFT: 246 outliers (15.94%), MAD = 0.0320 m
# Sonar: 166 outliers (10.76%), MAD = 0.0241 m
# DVL: 161 outliers (10.43%), MAD = 0.0593 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.6747 m, Median: 0.4313 m, Max: 1.8870 m
#   Magnitude Categories:
#     Small (≤0.2628m): 84 (34.1%)
#     Medium (0.2628-0.8835m): 82 (33.3%)
#     Large (>0.8835m): 80 (32.5%)
#   Clustering:
#     Total clusters: 10
#     Avg cluster size: 25.6 frames
#     Max cluster size: 64 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 10 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1415 m, Median: 0.1259 m, Max: 0.2562 m
#   Magnitude Categories:
#     Small (≤0.1077m): 56 (33.7%)
#     Medium (0.1077-0.1595m): 56 (33.7%)
#     Large (>0.1595m): 54 (32.5%)
#   Clustering:
#     Total clusters: 12
#     Avg cluster size: 14.8 frames
#     Max cluster size: 75 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 12 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.3539 m, Median: 0.2700 m, Max: 0.6400 m
#   Magnitude Categories:
#     Small (≤0.2550m): 54 (33.5%)
#     Medium (0.2550-0.3900m): 56 (34.8%)
#     Large (>0.3900m): 51 (31.7%)
#   Clustering:
#     Total clusters: 23
#     Avg cluster size: 8.0 frames
#     Max cluster size: 42 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 23 (100.0%)
#
#   ✓ Processed 689 baseline samples, 4 stable segments
# Processing: 2024-08-20_17-40-54
# Pairwise differences computed:
#   diff_fft_nav: 2038 valid samples, mean=0.026, std=0.273
#   diff_sonar_nav: 2038 valid samples, mean=-0.080, std=0.112
#   diff_fft_sonar: 2168 valid samples, mean=0.099, std=0.311
#   diff_pitch_fft_nav: 2038 valid samples, mean=-11.745, std=13.113
#   diff_pitch_sonar_nav: 2038 valid samples, mean=-1.220, std=7.128
#   diff_pitch_fft_sonar: 2168 valid samples, mean=-10.000, std=12.456
#   diff_x_fft_nav: 2038 valid samples, mean=-0.001, std=0.274
#   diff_x_sonar_nav: 2038 valid samples, mean=-0.077, std=0.120
#   diff_x_fft_sonar: 2168 valid samples, mean=0.067, std=0.308
#   diff_y_fft_nav: 2038 valid samples, mean=-0.226, std=0.187
#   diff_y_sonar_nav: 2038 valid samples, mean=-0.020, std=0.112
#   diff_y_fft_sonar: 2168 valid samples, mean=-0.205, std=0.170
# Rolling window: 115 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 704 / 2169 (32.5%)
#
# Identifying stable baseline segments...
# Found 3 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 15:41:03 - 15:41:09 (5.4 s, 185 samples)
#   Segment 2: 15:41:12 - 15:41:17 (5.1 s, 177 samples)
#   Segment 3: 15:41:37 - 15:41:45 (8.0 s, 272 samples)
# === OUTLIER DETECTION ===
#
# FFT: 211 outliers (9.73%), MAD = 0.0452 m
# Sonar: 284 outliers (13.09%), MAD = 0.0171 m
# DVL: 301 outliers (13.88%), MAD = 0.0297 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.8506 m, Median: 0.9767 m, Max: 2.4767 m
#   Magnitude Categories:
#     Small (≤0.4748m): 70 (33.2%)
#     Medium (0.4748-1.0870m): 72 (34.1%)
#     Large (>1.0870m): 69 (32.7%)
#   Clustering:
#     Total clusters: 21
#     Avg cluster size: 11.0 frames
#     Max cluster size: 52 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 21 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0878 m, Median: 0.0801 m, Max: 0.1795 m
#   Magnitude Categories:
#     Small (≤0.0725m): 94 (33.1%)
#     Medium (0.0725-0.0927m): 97 (34.2%)
#     Large (>0.0927m): 93 (32.7%)
#   Clustering:
#     Total clusters: 12
#     Avg cluster size: 24.7 frames
#     Max cluster size: 53 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 12 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2076 m, Median: 0.1600 m, Max: 0.7200 m
#   Magnitude Categories:
#     Small (≤0.1400m): 117 (38.9%)
#     Medium (0.1400-0.2200m): 88 (29.2%)
#     Large (>0.2200m): 96 (31.9%)
#   Clustering:
#     Total clusters: 18
#     Avg cluster size: 17.7 frames
#     Max cluster size: 48 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 18 (100.0%)
#
#   ✓ Processed 704 baseline samples, 3 stable segments
# Processing: 2024-08-20_18-12-20
# Pairwise differences computed:
#   diff_fft_nav: 3215 valid samples, mean=-0.098, std=0.883
#   diff_sonar_nav: 3263 valid samples, mean=-0.077, std=0.063
#   diff_fft_sonar: 3214 valid samples, mean=-0.020, std=0.892
#   diff_pitch_fft_nav: 3215 valid samples, mean=-16.864, std=26.158
#   diff_pitch_sonar_nav: 3263 valid samples, mean=0.482, std=5.161
#   diff_pitch_fft_sonar: 3214 valid samples, mean=-17.396, std=26.203
#   diff_x_fft_nav: 3215 valid samples, mean=-0.145, std=0.867
#   diff_x_sonar_nav: 3263 valid samples, mean=-0.077, std=0.063
#   diff_x_fft_sonar: 3214 valid samples, mean=-0.067, std=0.874
#   diff_y_fft_nav: 3215 valid samples, mean=-0.284, std=0.244
#   diff_y_sonar_nav: 3263 valid samples, mean=0.007, std=0.086
#   diff_y_fft_sonar: 3214 valid samples, mean=-0.292, std=0.243
# Rolling window: 112 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 1474 / 3267 (45.1%)
#
# Identifying stable baseline segments...
# Found 3 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 16:12:55 - 16:12:59 (4.0 s, 137 samples)
#   Segment 2: 16:13:10 - 16:13:28 (17.9 s, 627 samples)
#   Segment 3: 16:13:37 - 16:13:58 (20.6 s, 713 samples)
# === OUTLIER DETECTION ===
#
# FFT: 693 outliers (21.21%), MAD = 0.0195 m
# Sonar: 393 outliers (12.03%), MAD = 0.0128 m
# DVL: 406 outliers (12.43%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.7403 m, Median: 0.5327 m, Max: 20.2306 m
#   Magnitude Categories:
#     Small (≤0.3035m): 230 (33.2%)
#     Medium (0.3035-0.6285m): 235 (33.9%)
#     Large (>0.6285m): 228 (32.9%)
#   Clustering:
#     Total clusters: 50
#     Avg cluster size: 14.9 frames
#     Max cluster size: 130 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 50 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1096 m, Median: 0.0957 m, Max: 0.2450 m
#   Magnitude Categories:
#     Small (≤0.0751m): 130 (33.1%)
#     Medium (0.0751-0.1268m): 133 (33.8%)
#     Large (>0.1268m): 130 (33.1%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 31.2 frames
#     Max cluster size: 79 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1353 m, Median: 0.1200 m, Max: 0.4600 m
#   Magnitude Categories:
#     Small (≤0.0900m): 138 (34.0%)
#     Medium (0.0900-0.1550m): 134 (33.0%)
#     Large (>0.1550m): 134 (33.0%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 32.2 frames
#     Max cluster size: 86 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
#   ✓ Processed 1474 baseline samples, 3 stable segments
# Processing: 2024-08-20_18-47-40
# Pairwise differences computed:
#   diff_fft_nav: 1148 valid samples, mean=-0.517, std=0.592
#   diff_sonar_nav: 1148 valid samples, mean=-0.088, std=0.071
#   diff_fft_sonar: 1285 valid samples, mean=-0.391, std=0.564
#   diff_pitch_fft_nav: 1148 valid samples, mean=10.338, std=30.895
#   diff_pitch_sonar_nav: 1148 valid samples, mean=-7.591, std=6.951
#   diff_pitch_fft_sonar: 1285 valid samples, mean=17.190, std=29.536
#   diff_x_fft_nav: 1148 valid samples, mean=-0.510, std=0.575
#   diff_x_sonar_nav: 1148 valid samples, mean=-0.114, std=0.078
#   diff_x_fft_sonar: 1285 valid samples, mean=-0.358, std=0.551
#   diff_y_fft_nav: 1148 valid samples, mean=0.153, std=0.206
#   diff_y_sonar_nav: 1148 valid samples, mean=-0.100, std=0.098
#   diff_y_fft_sonar: 1285 valid samples, mean=0.250, std=0.182
# Rolling window: 108 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1286 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 418 outliers (32.50%), MAD = 0.1299 m
# Sonar: 87 outliers (6.77%), MAD = 0.0198 m
# DVL: 39 outliers (3.03%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.9402 m, Median: 0.9671 m, Max: 2.4439 m
#   Magnitude Categories:
#     Small (≤0.9059m): 138 (33.0%)
#     Medium (0.9059-1.0127m): 146 (34.9%)
#     Large (>1.0127m): 134 (32.1%)
#   Clustering:
#     Total clusters: 44
#     Avg cluster size: 10.5 frames
#     Max cluster size: 54 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 44 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1491 m, Median: 0.1650 m, Max: 0.2240 m
#   Magnitude Categories:
#     Small (≤0.1007m): 29 (33.3%)
#     Medium (0.1007-0.1919m): 29 (33.3%)
#     Large (>0.1919m): 29 (33.3%)
#   Clustering:
#     Total clusters: 4
#     Avg cluster size: 22.8 frames
#     Max cluster size: 65 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 4 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2577 m, Median: 0.0800 m, Max: 0.6000 m
#   Magnitude Categories:
#     Small (≤0.0800m): 15 (38.5%)
#     Medium (0.0800-0.3740m): 11 (28.2%)
#     Large (>0.3740m): 13 (33.3%)
#   Clustering:
#     Total clusters: 6
#     Avg cluster size: 7.5 frames
#     Max cluster size: 20 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 6 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-22_14-06-43
# Pairwise differences computed:
#   diff_fft_nav: 962 valid samples, mean=-0.383, std=0.586
#   diff_sonar_nav: 1084 valid samples, mean=0.049, std=0.133
#   diff_fft_sonar: 1038 valid samples, mean=-0.387, std=0.578
#   diff_pitch_fft_nav: 962 valid samples, mean=9.648, std=44.948
#   diff_pitch_sonar_nav: 1084 valid samples, mean=-4.894, std=10.227
#   diff_pitch_fft_sonar: 1038 valid samples, mean=13.530, std=44.587
#   diff_x_fft_nav: 962 valid samples, mean=-0.331, std=0.522
#   diff_x_sonar_nav: 1084 valid samples, mean=-0.013, std=0.103
#   diff_x_fft_sonar: 1038 valid samples, mean=-0.313, std=0.493
#   diff_y_fft_nav: 962 valid samples, mean=0.182, std=0.335
#   diff_y_sonar_nav: 1084 valid samples, mean=-0.081, std=0.158
#   diff_y_fft_sonar: 1038 valid samples, mean=0.214, std=0.363
# Rolling window: 97 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1163 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 389 outliers (33.45%), MAD = 0.0060 m
# Sonar: 209 outliers (17.97%), MAD = 0.0116 m
# DVL: 88 outliers (7.57%), MAD = 0.0222 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.5143 m, Median: 0.4570 m, Max: 7.0490 m
#   Magnitude Categories:
#     Small (≤0.1552m): 130 (33.4%)
#     Medium (0.1552-0.6157m): 130 (33.4%)
#     Large (>0.6157m): 129 (33.2%)
#   Clustering:
#     Total clusters: 27
#     Avg cluster size: 15.4 frames
#     Max cluster size: 59 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 27 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1121 m, Median: 0.0773 m, Max: 0.2783 m
#   Magnitude Categories:
#     Small (≤0.0629m): 69 (33.0%)
#     Medium (0.0629-0.1052m): 71 (34.0%)
#     Large (>0.1052m): 69 (33.0%)
#   Clustering:
#     Total clusters: 7
#     Avg cluster size: 30.9 frames
#     Max cluster size: 70 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 7 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2397 m, Median: 0.1550 m, Max: 0.5500 m
#   Magnitude Categories:
#     Small (≤0.0971m): 29 (33.0%)
#     Medium (0.0971-0.3500m): 32 (36.4%)
#     Large (>0.3500m): 27 (30.7%)
#   Clustering:
#     Total clusters: 22
#     Avg cluster size: 5.0 frames
#     Max cluster size: 13 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 22 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-22_14-29-05
# Pairwise differences computed:
#   diff_fft_nav: 1737 valid samples, mean=-0.300, std=0.347
#   diff_sonar_nav: 1817 valid samples, mean=0.041, std=0.047
#   diff_fft_sonar: 1849 valid samples, mean=-0.330, std=0.362
#   diff_pitch_fft_nav: 1737 valid samples, mean=4.108, std=41.404
#   diff_pitch_sonar_nav: 1817 valid samples, mean=-2.061, std=7.004
#   diff_pitch_fft_sonar: 1849 valid samples, mean=5.528, std=39.442
#   diff_x_fft_nav: 1737 valid samples, mean=-0.303, std=0.341
#   diff_x_sonar_nav: 1817 valid samples, mean=0.040, std=0.049
#   diff_x_fft_sonar: 1849 valid samples, mean=-0.332, std=0.355
#   diff_y_fft_nav: 1737 valid samples, mean=0.056, std=0.109
#   diff_y_sonar_nav: 1817 valid samples, mean=-0.022, std=0.072
#   diff_y_fft_sonar: 1849 valid samples, mean=0.078, std=0.106
# Rolling window: 97 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 477 / 1930 (24.7%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:29:16 - 12:29:17 (1.1 s, 38 samples)
#   Segment 2: 12:29:55 - 12:30:09 (13.3 s, 441 samples)
# === OUTLIER DETECTION ===
#
# FFT: 615 outliers (31.87%), MAD = 0.0020 m
# Sonar: 120 outliers (6.22%), MAD = 0.0154 m
# DVL: 44 outliers (2.28%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.1775 m, Median: 0.0251 m, Max: 1.6740 m
#   Magnitude Categories:
#     Small (≤0.0170m): 203 (33.0%)
#     Medium (0.0170-0.0554m): 211 (34.3%)
#     Large (>0.0554m): 201 (32.7%)
#   Clustering:
#     Total clusters: 40
#     Avg cluster size: 16.4 frames
#     Max cluster size: 56 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 40 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0802 m, Median: 0.0802 m, Max: 0.1239 m
#   Magnitude Categories:
#     Small (≤0.0725m): 40 (33.3%)
#     Medium (0.0725-0.0876m): 40 (33.3%)
#     Large (>0.0876m): 40 (33.3%)
#   Clustering:
#     Total clusters: 9
#     Avg cluster size: 14.3 frames
#     Max cluster size: 60 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 9 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1255 m, Median: 0.0600 m, Max: 0.4050 m
#   Magnitude Categories:
#     Small (≤0.0600m): 22 (50.0%)
#     Medium (0.0600-0.0700m): 11 (25.0%)
#     Large (>0.0700m): 11 (25.0%)
#   Clustering:
#     Total clusters: 11
#     Avg cluster size: 5.0 frames
#     Max cluster size: 10 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 11 (100.0%)
#
#   ✓ Processed 477 baseline samples, 2 stable segments
# Processing: 2024-08-22_14-47-39
# Pairwise differences computed:
#   diff_fft_nav: 1363 valid samples, mean=-0.334, std=0.375
#   diff_sonar_nav: 1363 valid samples, mean=0.050, std=0.054
#   diff_fft_sonar: 1462 valid samples, mean=-0.367, std=0.384
#   diff_pitch_fft_nav: 1363 valid samples, mean=8.797, std=44.769
#   diff_pitch_sonar_nav: 1363 valid samples, mean=-3.845, std=9.405
#   diff_pitch_fft_sonar: 1462 valid samples, mean=12.266, std=43.081
#   diff_x_fft_nav: 1363 valid samples, mean=-0.337, std=0.362
#   diff_x_sonar_nav: 1363 valid samples, mean=0.049, std=0.060
#   diff_x_fft_sonar: 1462 valid samples, mean=-0.370, std=0.372
#   diff_y_fft_nav: 1363 valid samples, mean=0.066, std=0.136
#   diff_y_sonar_nav: 1363 valid samples, mean=-0.046, std=0.097
#   diff_y_fft_sonar: 1462 valid samples, mean=0.109, std=0.116
# Rolling window: 101 samples (3.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 205 / 1463 (14.0%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:47:49 - 12:47:52 (3.6 s, 123 samples)
#   Segment 2: 12:48:24 - 12:48:26 (2.5 s, 84 samples)
# === OUTLIER DETECTION ===
#
# FFT: 308 outliers (21.05%), MAD = 0.0137 m
# Sonar: 121 outliers (8.27%), MAD = 0.0143 m
# DVL: 98 outliers (6.70%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.5378 m, Median: 0.5989 m, Max: 2.1886 m
#   Magnitude Categories:
#     Small (≤0.5183m): 104 (33.8%)
#     Medium (0.5183-0.6172m): 107 (34.7%)
#     Large (>0.6172m): 97 (31.5%)
#   Clustering:
#     Total clusters: 22
#     Avg cluster size: 15.0 frames
#     Max cluster size: 62 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 22 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1299 m, Median: 0.1401 m, Max: 0.1788 m
#   Magnitude Categories:
#     Small (≤0.1249m): 41 (33.9%)
#     Medium (0.1249-0.1505m): 41 (33.9%)
#     Large (>0.1505m): 39 (32.2%)
#   Clustering:
#     Total clusters: 3
#     Avg cluster size: 41.3 frames
#     Max cluster size: 78 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 3 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1074 m, Median: 0.0900 m, Max: 0.3900 m
#   Magnitude Categories:
#     Small (≤0.0800m): 38 (38.8%)
#     Medium (0.0800-0.0900m): 29 (29.6%)
#     Large (>0.0900m): 31 (31.6%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 8.5 frames
#     Max cluster size: 44 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
#   ✓ Processed 205 baseline samples, 2 stable segments
# ✓ Summary CSV saved: bag_summary.csv
#   Location: /Volumes/LaCie/SOLAQUA/comparison_data/bag_summary.csv
#
# ======================================================================
# ✓ Summary CSV regenerated successfully!
#   Location: /Volumes/LaCie/SOLAQUA/comparison_data/bag_summary.csv
#
# The summary now includes:
#   ✓ Outlier magnitude metrics (mean, median, max)
#   ✓ Outlier clustering analysis (cluster count, sizes)
#   ✓ Isolated vs. multi-frame outlier statistics
#
# Re-run the 'Multi-Bag Summary Analysis' cell above to see the updated statistics.
