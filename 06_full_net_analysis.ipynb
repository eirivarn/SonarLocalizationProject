# %% [markdown]
# # Full Net Tracking Analysis: Multi-System Performance Assessment
#
# This notebook performs comprehensive analysis of synchronized comparison data from three net-tracking systems using the `comparison_analysis` utility module.
#
# **What this does:**
# 1. Loads and optionally smooths comparison data
# 2. Detects stable baseline segments
# 3. Computes noise, bias, and outlier statistics
# 4. Generates visualizations and summary reports
#
# **Quick Start:**
# 1. Set `TARGET_BAG` to your bag ID
# 2. Run all cells
# 3. Check outputs in comparison_data and plots directories
#
# #### **Generate for summary to csv for all of the available comparison data:**
# `Use defaults`
# python scripts/generate_bag_summary.py

# %% [markdown]
# ## Configuration

# %%
from pathlib import Path
from utils.comparison_analysis import (
    load_and_prepare_data,
    compute_pairwise_differences,
    detect_stable_segments,
    compute_baseline_statistics,
    detect_outliers,
    analyze_failure_correlation,
    create_visualizations,
    generate_summary_report,
    print_multi_bag_summary
)

# Configuration
TARGET_BAG = "2024-08-20_13-57-42"
COMPARISON_DATA_DIR = Path("/Volumes/LaCie/SOLAQUA/comparison_data")
PLOTS_DIR = Path("/Volumes/LaCie/SOLAQUA/exports/plots")
PLOTS_DIR.mkdir(parents=True, exist_ok=True)

# Analysis parameters
SMOOTHING_ALPHA = 0.75      # None = no smoothing, 0-1 = smoothing factor
ROLLING_WINDOW_SEC = 2.0
SIGMA_THRESH = 0.25          # increase to allow more variance (e.g., 0.4 → 0.6)
DELTA_THRESH = 0.25          # increase to tolerate larger inter-system drift
MIN_SEGMENT_SEC = 1.0       # lower to accept shorter stable periods
OUTLIER_K = 3.5

print(f"Target: {TARGET_BAG}")
print(f"Smoothing: {'Disabled' if SMOOTHING_ALPHA is None else f'α={SMOOTHING_ALPHA:.2f}'}")
print(f"Stability thresholds: σ={SIGMA_THRESH}m, Δ={DELTA_THRESH}m")
# Out:
# Target: 2024-08-20_13-57-42
# Smoothing: α=0.75
# Stability thresholds: σ=0.25m, Δ=0.25m

# %% [markdown]
# ## Load and Process Data

# %%
# Load comparison data
data_path = COMPARISON_DATA_DIR / f"{TARGET_BAG}_raw_comparison.csv"
df, sampling_rate, available_systems = load_and_prepare_data(data_path, SMOOTHING_ALPHA)

# Compute pairwise differences
df = compute_pairwise_differences(df)
# Out:
# Loading data from: 2024-08-20_13-57-42_raw_comparison.csv
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
#
# Data loaded: 2744 samples
# Time range: 2024-08-20 11:57:45.106798649+00:00 to 2024-08-20 11:59:04.976633549+00:00
# Duration: 79.9 seconds
# Median sampling interval: 0.025 s (39.2 Hz)
# Available systems: FFT, Sonar, DVL
# Pairwise differences computed:
#   diff_fft_nav: 2715 valid samples, mean=-0.132, std=1.123
#   diff_sonar_nav: 2715 valid samples, mean=-0.021, std=0.167
#   diff_fft_sonar: 2744 valid samples, mean=-0.110, std=1.097
#   diff_pitch_fft_nav: 2715 valid samples, mean=-1.628, std=20.708
#   diff_pitch_sonar_nav: 2715 valid samples, mean=-1.391, std=8.712
#   diff_pitch_fft_sonar: 2744 valid samples, mean=-0.084, std=20.741
#   diff_x_fft_nav: 2715 valid samples, mean=-0.144, std=1.115
#   diff_x_sonar_nav: 2715 valid samples, mean=-0.022, std=0.183
#   diff_x_fft_sonar: 2744 valid samples, mean=-0.120, std=1.086
#   diff_y_fft_nav: 2715 valid samples, mean=-0.003, std=0.418
#   diff_y_sonar_nav: 2715 valid samples, mean=-0.037, std=0.209
#   diff_y_fft_sonar: 2744 valid samples, mean=0.037, std=0.420

# %% [markdown]
# ## Detect Stable Baseline Segments

# %%
df, segments, window_samples = detect_stable_segments(
    df, sampling_rate,
    rolling_window_sec=ROLLING_WINDOW_SEC,
    sigma_thresh=SIGMA_THRESH,
    delta_thresh=DELTA_THRESH,
    min_segment_sec=MIN_SEGMENT_SEC
)
# Out:
# Rolling window: 78 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 610 / 2744 (22.2%)
#
# Identifying stable baseline segments...
# Found 5 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 11:58:09 - 11:58:12 (2.8 s, 97 samples)
#   Segment 2: 11:58:21 - 11:58:22 (1.7 s, 60 samples)
#   Segment 3: 11:58:23 - 11:58:26 (2.5 s, 88 samples)
#   Segment 4: 11:58:50 - 11:58:56 (5.9 s, 202 samples)
#   Segment 5: 11:58:58 - 11:59:03 (5.0 s, 168 samples)

# %% [markdown]
# ## Baseline Statistics

# %%
baseline_stats = compute_baseline_statistics(df)
# Out:
# === BASELINE STATISTICS (610 samples) ===
#
# 1. PER-METHOD NOISE - DISTANCE
#   FFT: σ = 0.1297 m, MAD = 0.1326 m
#   Sonar: σ = 0.1198 m, MAD = 0.1347 m
#   DVL: σ = 0.1307 m, MAD = 0.0889 m
#
# 2. PER-METHOD NOISE - PITCH
#   FFT: σ = 6.6722°, MAD = 6.0851°
#   Sonar: σ = 5.3350°, MAD = 3.1061°
#   DVL: σ = 6.1546°, MAD = 7.5401°
#
# 3. PER-METHOD NOISE - X POSITION
#   FFT: σ = 0.1302 m, MAD = 0.1210 m
#   Sonar: σ = 0.1211 m, MAD = 0.1277 m
#   DVL: σ = 0.1329 m, MAD = 0.0890 m
#
# 4. PER-METHOD NOISE - Y POSITION
#   FFT: σ = 0.1679 m, MAD = 0.1611 m
#   Sonar: σ = 0.1263 m, MAD = 0.0816 m
#   DVL: σ = 0.1519 m, MAD = 0.1855 m
#
# 5. PAIRWISE BIASES - DISTANCE
#   FFT vs DVL: Bias = +0.0311 m, Std = 0.0981 m
#   Sonar vs DVL: Bias = -0.0637 m, Std = 0.0899 m
#   FFT vs Sonar: Bias = +0.0947 m, Std = 0.0794 m
#
# 6. PAIRWISE BIASES - PITCH
#   FFT vs DVL: Bias = +1.3891 °, Std = 7.9303 °
#   Sonar vs DVL: Bias = +0.3609 °, Std = 5.9444 °
#   FFT vs Sonar: Bias = +1.0282 °, Std = 7.1647 °
#
# 7. PAIRWISE BIASES - X POSITION
#   FFT vs DVL: Bias = +0.0267 m, Std = 0.1088 m
#   Sonar vs DVL: Bias = -0.0616 m, Std = 0.0992 m
#   FFT vs Sonar: Bias = +0.0883 m, Std = 0.0860 m
#
# 8. PAIRWISE BIASES - Y POSITION
#   FFT vs DVL: Bias = +0.0425 m, Std = 0.1954 m
#   Sonar vs DVL: Bias = +0.0060 m, Std = 0.1429 m
#   FFT vs Sonar: Bias = +0.0365 m, Std = 0.1756 m
#
# 9. LINEAR RELATIONSHIPS (in baseline)
#   Distance - FFT vs DVL: R² = 0.5127
#   Distance - Sonar vs DVL: R² = 0.5557
#   Pitch - FFT vs DVL: R² = 0.0564
#   Pitch - Sonar vs DVL: R² = 0.2229

# %% [markdown]
# ## Outlier Detection

# %%
df, outlier_stats = detect_outliers(df, window_samples, outlier_k=OUTLIER_K)
correlation_stats = analyze_failure_correlation(df)
# Out:
# === OUTLIER DETECTION ===
#
# FFT: 603 outliers (21.98%), MAD = 0.0418 m
# Sonar: 274 outliers (9.99%), MAD = 0.0107 m
# DVL: 473 outliers (17.24%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.0950 m, Median: 0.6326 m, Max: 19.0845 m
#   Magnitude Categories:
#     Small (≤0.2717m): 199 (33.0%)
#     Medium (0.2717-1.1094m): 205 (34.0%)
#     Large (>1.1094m): 199 (33.0%)
#   Clustering:
#     Total clusters: 62
#     Avg cluster size: 10.7 frames
#     Max cluster size: 41 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 62 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0592 m, Median: 0.0514 m, Max: 0.1116 m
#   Magnitude Categories:
#     Small (≤0.0454m): 91 (33.2%)
#     Medium (0.0454-0.0665m): 92 (33.6%)
#     Large (>0.0665m): 91 (33.2%)
#   Clustering:
#     Total clusters: 26
#     Avg cluster size: 11.5 frames
#     Max cluster size: 60 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 26 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1667 m, Median: 0.1124 m, Max: 0.8088 m
#   Magnitude Categories:
#     Small (≤0.0847m): 156 (33.0%)
#     Medium (0.0847-0.1643m): 161 (34.0%)
#     Large (>0.1643m): 156 (33.0%)
#   Clustering:
#     Total clusters: 25
#     Avg cluster size: 19.9 frames
#     Max cluster size: 71 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 25 (100.0%)
#
#
# === FAILURE CORRELATION ===
#
# 1. INDIVIDUAL OUTLIER RATES
#   P(FFT outlier) = 21.98%
#   P(SONAR outlier) = 9.99%
#   P(DVL outlier) = 17.24%
#
# 2. CO-OCCURRENCE ANALYSIS
#   Jaccard(FFT, SONAR) = 0.053
#     P(SONAR outlier | FFT outlier) = 0.073
#     P(FFT outlier | SONAR outlier) = 0.161
#   Jaccard(FFT, DVL) = 0.047
#     P(DVL outlier | FFT outlier) = 0.080
#     P(FFT outlier | DVL outlier) = 0.101
#   Jaccard(SONAR, DVL) = 0.125
#     P(DVL outlier | SONAR outlier) = 0.303
#     P(SONAR outlier | DVL outlier) = 0.175

# %% [markdown]
# ## Generate Visualizations

# %%
print("\n=== GENERATING VISUALIZATIONS ===\n")

figs = create_visualizations(
    df, segments, TARGET_BAG, PLOTS_DIR,
    sigma_thresh=SIGMA_THRESH,
    outlier_k=OUTLIER_K
)

# Display plots
for name, fig in figs.items():
    print(f"\nDisplaying {name}...")
    fig.show()

print(f"\n✓ All plots saved to: {PLOTS_DIR}")
# Out:
# === GENERATING VISUALIZATIONS ===
# /Users/eirikvarnes/code/SOLAQUA/venv/lib/python3.13/site-packages/plotly/io/_json.py:558: UserWarning:
#
# Discarding nonzero nanoseconds in conversion.
# Saved: 2024-08-20_13-57-42_xy_positions.html
# Saved: 2024-08-20_13-57-42_timeseries.html
# Saved: 2024-08-20_13-57-42_timeseries.html
# Saved: 2024-08-20_13-57-42_stability.html
# Saved: 2024-08-20_13-57-42_stability.html
# Saved: 2024-08-20_13-57-42_outliers.html
# Saved: 2024-08-20_13-57-42_outliers.html
# Saved: 2024-08-20_13-57-42_xy_positions.html
#
# Displaying timeseries...
# Saved: 2024-08-20_13-57-42_xy_positions.html
#
# Displaying timeseries...
# Displaying stability...
# Displaying outliers...
# Displaying xy_positions...
# ✓ All plots saved to: /Volumes/LaCie/SOLAQUA/exports/plots

# %% [markdown]
# ## Generate Summary Report

# %%
config = {
    'Smoothing': f'α={SMOOTHING_ALPHA:.2f}' if SMOOTHING_ALPHA else 'Disabled',
    'Rolling Window': f'{ROLLING_WINDOW_SEC} s ({window_samples} samples)',
    'Stability σ Threshold': f'{SIGMA_THRESH} m',
    'Stability Δ Threshold': f'{DELTA_THRESH} m',
    'Min Segment Length': f'{MIN_SEGMENT_SEC} s',
    'Outlier Threshold': f'{OUTLIER_K} × MAD'
}

report_path = COMPARISON_DATA_DIR / f"{TARGET_BAG}_analysis_summary.md"
generate_summary_report(
    df, segments, baseline_stats, available_systems,
    TARGET_BAG, report_path, config, outlier_stats
)

print(f"\n✓ Analysis complete!")
print(f"  Plots: {PLOTS_DIR}")
print(f"  Report: {report_path}")
# Out:
# === GENERATING SUMMARY REPORT ===
#
# ✓ Summary report saved: 2024-08-20_13-57-42_analysis_summary.md
#   Location: /Volumes/LaCie/SOLAQUA/comparison_data/2024-08-20_13-57-42_analysis_summary.md
#
# ✓ Analysis complete!
#   Plots: /Volumes/LaCie/SOLAQUA/exports/plots
#   Report: /Volumes/LaCie/SOLAQUA/comparison_data/2024-08-20_13-57-42_analysis_summary.md
# ✓ Summary report saved: 2024-08-20_13-57-42_analysis_summary.md
#   Location: /Volumes/LaCie/SOLAQUA/comparison_data/2024-08-20_13-57-42_analysis_summary.md
#
# ✓ Analysis complete!
#   Plots: /Volumes/LaCie/SOLAQUA/exports/plots
#   Report: /Volumes/LaCie/SOLAQUA/comparison_data/2024-08-20_13-57-42_analysis_summary.md

# %%
# Regenerate the multi-bag summary CSV with all metrics
from utils.comparison_analysis import generate_multi_bag_summary_csv

print("Regenerating bag_summary.csv with all metrics...")
print("This may take a few minutes depending on the number of bags.\n")

output_path = generate_multi_bag_summary_csv(
    comparison_data_dir=COMPARISON_DATA_DIR,
    output_path=COMPARISON_DATA_DIR / "bag_summary.csv",
    smoothing_alpha=SMOOTHING_ALPHA,
    rolling_window_sec=ROLLING_WINDOW_SEC,
    sigma_thresh=SIGMA_THRESH,
    delta_thresh=DELTA_THRESH,
    min_segment_sec=MIN_SEGMENT_SEC,
    outlier_k=OUTLIER_K
)

if output_path:
    print("\n" + "="*70)
    print("✓ Summary CSV regenerated successfully!")
    print(f"  Location: {output_path}")
    print("\nThe summary now includes:")
    print("  ✓ Outlier magnitude metrics (mean, median, max)")
    print("  ✓ Outlier clustering analysis (cluster count, sizes)")
    print("  ✓ Isolated vs. multi-frame outlier statistics")
    print("\nRe-run the 'Multi-Bag Summary Analysis' cell above to see the updated statistics.")
else:
    print("\n✗ Failed to regenerate summary CSV")
# Out:
# Regenerating bag_summary.csv with all metrics...
# This may take a few minutes depending on the number of bags.
#
#
# === GENERATING MULTI-BAG SUMMARY CSV ===
#
# Found 46 bags to process
#
# Processing: ._2024-08-20_13-39-34
#   ✗ Error processing ._2024-08-20_13-39-34: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-40-35
#   ✗ Error processing ._2024-08-20_13-40-35: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-42-51
#   ✗ Error processing ._2024-08-20_13-42-51: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-55-34
#   ✗ Error processing ._2024-08-20_13-55-34: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_13-57-42
#   ✗ Error processing ._2024-08-20_13-57-42: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-16-05
#   ✗ Error processing ._2024-08-20_14-16-05: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-22-12
#   ✗ Error processing ._2024-08-20_14-22-12: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-24-35
#   ✗ Error processing ._2024-08-20_14-24-35: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-31-29
#   ✗ Error processing ._2024-08-20_14-31-29: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_14-57-38
#   ✗ Error processing ._2024-08-20_14-57-38: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_15-00-24
#   ✗ Error processing ._2024-08-20_15-00-24: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_15-14-40
#   ✗ Error processing ._2024-08-20_15-14-40: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_16-57-46
#   ✗ Error processing ._2024-08-20_16-57-46: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-02-00
#   ✗ Error processing ._2024-08-20_17-02-00: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-08-14
#   ✗ Error processing ._2024-08-20_17-08-14: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-14-36
#   ✗ Error processing ._2024-08-20_17-14-36: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-39-32
#   ✗ Error processing ._2024-08-20_17-39-32: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_17-40-54
#   ✗ Error processing ._2024-08-20_17-40-54: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_18-12-20
#   ✗ Error processing ._2024-08-20_18-12-20: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-20_18-47-40
#   ✗ Error processing ._2024-08-20_18-47-40: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-06-43
#   ✗ Error processing ._2024-08-22_14-06-43: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-29-05
#   ✗ Error processing ._2024-08-22_14-29-05: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: ._2024-08-22_14-47-39
#   ✗ Error processing ._2024-08-22_14-47-39: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processing: 2024-08-20_13-39-34
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1465 valid samples, mean=-0.474, std=0.579
#   diff_sonar_nav: 1465 valid samples, mean=0.537, std=0.562
#   diff_fft_sonar: 1502 valid samples, mean=-1.009, std=0.176
#   diff_pitch_fft_nav: 1465 valid samples, mean=-8.492, std=18.899
#   diff_pitch_sonar_nav: 1465 valid samples, mean=-9.044, std=16.915
#   diff_pitch_fft_sonar: 1502 valid samples, mean=0.625, std=18.342
#   diff_x_fft_nav: 1465 valid samples, mean=-0.436, std=0.595
#   diff_x_sonar_nav: 1465 valid samples, mean=0.480, std=0.594
#   diff_x_fft_sonar: 1502 valid samples, mean=-0.916, std=0.220
#   diff_y_fft_nav: 1465 valid samples, mean=-0.218, std=0.450
#   diff_y_sonar_nav: 1465 valid samples, mean=-0.307, std=0.493
#   diff_y_fft_sonar: 1502 valid samples, mean=0.093, std=0.670
# Rolling window: 74 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1502 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 78 outliers (5.19%), MAD = 0.0338 m
# Sonar: 164 outliers (10.92%), MAD = 0.0192 m
# DVL: 363 outliers (24.17%), MAD = 0.0671 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3578 m, Median: 0.1853 m, Max: 1.5242 m
#   Magnitude Categories:
#     Small (≤0.1462m): 26 (33.3%)
#     Medium (0.1462-0.2362m): 26 (33.3%)
#     Large (>0.2362m): 26 (33.3%)
#   Clustering:
#     Total clusters: 25
#     Avg cluster size: 4.1 frames
#     Max cluster size: 11 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 25 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1059 m, Median: 0.1031 m, Max: 0.2040 m
#   Magnitude Categories:
#     Small (≤0.0877m): 54 (32.9%)
#     Medium (0.0877-0.1145m): 56 (34.1%)
#     Large (>0.1145m): 54 (32.9%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 13.6 frames
#     Max cluster size: 45 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.6647 m, Median: 0.6380 m, Max: 1.5361 m
#   Magnitude Categories:
#     Small (≤0.4006m): 120 (33.1%)
#     Medium (0.4006-0.7987m): 123 (33.9%)
#     Large (>0.7987m): 120 (33.1%)
#   Clustering:
#     Total clusters: 41
#     Avg cluster size: 9.9 frames
#     Max cluster size: 34 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 41 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-40-35
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1611 valid samples, mean=-0.376, std=0.774
#   diff_sonar_nav: 1611 valid samples, mean=0.683, std=0.308
#   diff_fft_sonar: 1611 valid samples, mean=-1.059, std=0.673
#   diff_pitch_fft_nav: 1611 valid samples, mean=-1.174, std=24.803
#   diff_pitch_sonar_nav: 1611 valid samples, mean=-17.867, std=13.508
#   diff_pitch_fft_sonar: 1611 valid samples, mean=16.692, std=25.186
#   diff_x_fft_nav: 1611 valid samples, mean=-0.349, std=0.743
#   diff_x_sonar_nav: 1611 valid samples, mean=0.434, std=0.339
#   diff_x_fft_sonar: 1611 valid samples, mean=-0.783, std=0.507
#   diff_y_fft_nav: 1611 valid samples, mean=-0.023, std=0.529
#   diff_y_sonar_nav: 1611 valid samples, mean=-0.765, std=0.468
#   diff_y_fft_sonar: 1611 valid samples, mean=0.741, std=0.786
# Rolling window: 75 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1611 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 180 outliers (11.17%), MAD = 0.0553 m
# Sonar: 107 outliers (6.64%), MAD = 0.0209 m
# DVL: 346 outliers (21.48%), MAD = 0.0741 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3427 m, Median: 0.2522 m, Max: 2.9847 m
#   Magnitude Categories:
#     Small (≤0.2258m): 60 (33.3%)
#     Medium (0.2258-0.2779m): 60 (33.3%)
#     Large (>0.2779m): 60 (33.3%)
#   Clustering:
#     Total clusters: 26
#     Avg cluster size: 7.9 frames
#     Max cluster size: 24 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 26 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1340 m, Median: 0.1095 m, Max: 0.3462 m
#   Magnitude Categories:
#     Small (≤0.0889m): 35 (32.7%)
#     Medium (0.0889-0.1639m): 37 (34.6%)
#     Large (>0.1639m): 35 (32.7%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 9.2 frames
#     Max cluster size: 40 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.4274 m, Median: 0.3355 m, Max: 0.9872 m
#   Magnitude Categories:
#     Small (≤0.3089m): 114 (32.9%)
#     Medium (0.3089-0.3942m): 118 (34.1%)
#     Large (>0.3942m): 114 (32.9%)
#   Clustering:
#     Total clusters: 33
#     Avg cluster size: 11.5 frames
#     Max cluster size: 80 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 33 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-42-51
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1604 valid samples, mean=-1.055, std=1.044
#   diff_sonar_nav: 1604 valid samples, mean=0.681, std=0.738
#   diff_fft_sonar: 1612 valid samples, mean=-1.752, std=1.174
#   diff_pitch_fft_nav: 1604 valid samples, mean=4.964, std=34.787
#   diff_pitch_sonar_nav: 1604 valid samples, mean=-17.844, std=31.673
#   diff_pitch_fft_sonar: 1612 valid samples, mean=22.999, std=41.009
#   diff_x_fft_nav: 1604 valid samples, mean=-0.920, std=1.034
#   diff_x_sonar_nav: 1604 valid samples, mean=0.008, std=0.775
#   diff_x_fft_sonar: 1612 valid samples, mean=-0.932, std=0.603
#   diff_y_fft_nav: 1604 valid samples, mean=0.304, std=0.749
#   diff_y_sonar_nav: 1604 valid samples, mean=-1.034, std=1.504
#   diff_y_fft_sonar: 1612 valid samples, mean=1.354, std=1.662
# Rolling window: 67 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1612 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 308 outliers (19.11%), MAD = 0.0540 m
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1465 valid samples, mean=-0.474, std=0.579
#   diff_sonar_nav: 1465 valid samples, mean=0.537, std=0.562
#   diff_fft_sonar: 1502 valid samples, mean=-1.009, std=0.176
#   diff_pitch_fft_nav: 1465 valid samples, mean=-8.492, std=18.899
#   diff_pitch_sonar_nav: 1465 valid samples, mean=-9.044, std=16.915
#   diff_pitch_fft_sonar: 1502 valid samples, mean=0.625, std=18.342
#   diff_x_fft_nav: 1465 valid samples, mean=-0.436, std=0.595
#   diff_x_sonar_nav: 1465 valid samples, mean=0.480, std=0.594
#   diff_x_fft_sonar: 1502 valid samples, mean=-0.916, std=0.220
#   diff_y_fft_nav: 1465 valid samples, mean=-0.218, std=0.450
#   diff_y_sonar_nav: 1465 valid samples, mean=-0.307, std=0.493
#   diff_y_fft_sonar: 1502 valid samples, mean=0.093, std=0.670
# Rolling window: 74 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1502 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 78 outliers (5.19%), MAD = 0.0338 m
# Sonar: 164 outliers (10.92%), MAD = 0.0192 m
# DVL: 363 outliers (24.17%), MAD = 0.0671 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3578 m, Median: 0.1853 m, Max: 1.5242 m
#   Magnitude Categories:
#     Small (≤0.1462m): 26 (33.3%)
#     Medium (0.1462-0.2362m): 26 (33.3%)
#     Large (>0.2362m): 26 (33.3%)
#   Clustering:
#     Total clusters: 25
#     Avg cluster size: 4.1 frames
#     Max cluster size: 11 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 25 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1059 m, Median: 0.1031 m, Max: 0.2040 m
#   Magnitude Categories:
#     Small (≤0.0877m): 54 (32.9%)
#     Medium (0.0877-0.1145m): 56 (34.1%)
#     Large (>0.1145m): 54 (32.9%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 13.6 frames
#     Max cluster size: 45 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.6647 m, Median: 0.6380 m, Max: 1.5361 m
#   Magnitude Categories:
#     Small (≤0.4006m): 120 (33.1%)
#     Medium (0.4006-0.7987m): 123 (33.9%)
#     Large (>0.7987m): 120 (33.1%)
#   Clustering:
#     Total clusters: 41
#     Avg cluster size: 9.9 frames
#     Max cluster size: 34 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 41 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-40-35
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1611 valid samples, mean=-0.376, std=0.774
#   diff_sonar_nav: 1611 valid samples, mean=0.683, std=0.308
#   diff_fft_sonar: 1611 valid samples, mean=-1.059, std=0.673
#   diff_pitch_fft_nav: 1611 valid samples, mean=-1.174, std=24.803
#   diff_pitch_sonar_nav: 1611 valid samples, mean=-17.867, std=13.508
#   diff_pitch_fft_sonar: 1611 valid samples, mean=16.692, std=25.186
#   diff_x_fft_nav: 1611 valid samples, mean=-0.349, std=0.743
#   diff_x_sonar_nav: 1611 valid samples, mean=0.434, std=0.339
#   diff_x_fft_sonar: 1611 valid samples, mean=-0.783, std=0.507
#   diff_y_fft_nav: 1611 valid samples, mean=-0.023, std=0.529
#   diff_y_sonar_nav: 1611 valid samples, mean=-0.765, std=0.468
#   diff_y_fft_sonar: 1611 valid samples, mean=0.741, std=0.786
# Rolling window: 75 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1611 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 180 outliers (11.17%), MAD = 0.0553 m
# Sonar: 107 outliers (6.64%), MAD = 0.0209 m
# DVL: 346 outliers (21.48%), MAD = 0.0741 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3427 m, Median: 0.2522 m, Max: 2.9847 m
#   Magnitude Categories:
#     Small (≤0.2258m): 60 (33.3%)
#     Medium (0.2258-0.2779m): 60 (33.3%)
#     Large (>0.2779m): 60 (33.3%)
#   Clustering:
#     Total clusters: 26
#     Avg cluster size: 7.9 frames
#     Max cluster size: 24 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 26 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1340 m, Median: 0.1095 m, Max: 0.3462 m
#   Magnitude Categories:
#     Small (≤0.0889m): 35 (32.7%)
#     Medium (0.0889-0.1639m): 37 (34.6%)
#     Large (>0.1639m): 35 (32.7%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 9.2 frames
#     Max cluster size: 40 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.4274 m, Median: 0.3355 m, Max: 0.9872 m
#   Magnitude Categories:
#     Small (≤0.3089m): 114 (32.9%)
#     Medium (0.3089-0.3942m): 118 (34.1%)
#     Large (>0.3942m): 114 (32.9%)
#   Clustering:
#     Total clusters: 33
#     Avg cluster size: 11.5 frames
#     Max cluster size: 80 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 33 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-42-51
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1604 valid samples, mean=-1.055, std=1.044
#   diff_sonar_nav: 1604 valid samples, mean=0.681, std=0.738
#   diff_fft_sonar: 1612 valid samples, mean=-1.752, std=1.174
#   diff_pitch_fft_nav: 1604 valid samples, mean=4.964, std=34.787
#   diff_pitch_sonar_nav: 1604 valid samples, mean=-17.844, std=31.673
#   diff_pitch_fft_sonar: 1612 valid samples, mean=22.999, std=41.009
#   diff_x_fft_nav: 1604 valid samples, mean=-0.920, std=1.034
#   diff_x_sonar_nav: 1604 valid samples, mean=0.008, std=0.775
#   diff_x_fft_sonar: 1612 valid samples, mean=-0.932, std=0.603
#   diff_y_fft_nav: 1604 valid samples, mean=0.304, std=0.749
#   diff_y_sonar_nav: 1604 valid samples, mean=-1.034, std=1.504
#   diff_y_fft_sonar: 1612 valid samples, mean=1.354, std=1.662
# Rolling window: 67 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1612 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 308 outliers (19.11%), MAD = 0.0540 m
# Sonar: 392 outliers (24.32%), MAD = 0.0248 m
# DVL: 318 outliers (19.73%), MAD = 0.1181 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.9851 m, Median: 0.8579 m, Max: 4.5225 m
#   Magnitude Categories:
#     Small (≤0.5979m): 102 (33.1%)
#     Medium (0.5979-1.0765m): 104 (33.8%)
#     Large (>1.0765m): 102 (33.1%)
#   Clustering:
#     Total clusters: 33
#     Avg cluster size: 10.3 frames
#     Max cluster size: 48 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 33 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.2703 m, Median: 0.2112 m, Max: 0.8942 m
#   Magnitude Categories:
#     Small (≤0.1636m): 130 (33.2%)
#     Medium (0.1636-0.2532m): 132 (33.7%)
#     Large (>0.2532m): 130 (33.2%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 31.2 frames
#     Max cluster size: 59 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.8665 m, Median: 0.7203 m, Max: 2.3389 m
#   Magnitude Categories:
#     Small (≤0.6058m): 105 (33.0%)
#     Medium (0.6058-0.9904m): 108 (34.0%)
#     Large (>0.9904m): 105 (33.0%)
#   Clustering:
#     Total clusters: 34
#     Avg cluster size: 10.4 frames
#     Max cluster size: 63 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 34 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-55-34
# Sonar: 392 outliers (24.32%), MAD = 0.0248 m
# DVL: 318 outliers (19.73%), MAD = 0.1181 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.9851 m, Median: 0.8579 m, Max: 4.5225 m
#   Magnitude Categories:
#     Small (≤0.5979m): 102 (33.1%)
#     Medium (0.5979-1.0765m): 104 (33.8%)
#     Large (>1.0765m): 102 (33.1%)
#   Clustering:
#     Total clusters: 33
#     Avg cluster size: 10.3 frames
#     Max cluster size: 48 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 33 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.2703 m, Median: 0.2112 m, Max: 0.8942 m
#   Magnitude Categories:
#     Small (≤0.1636m): 130 (33.2%)
#     Medium (0.1636-0.2532m): 132 (33.7%)
#     Large (>0.2532m): 130 (33.2%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 31.2 frames
#     Max cluster size: 59 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.8665 m, Median: 0.7203 m, Max: 2.3389 m
#   Magnitude Categories:
#     Small (≤0.6058m): 105 (33.0%)
#     Medium (0.6058-0.9904m): 108 (34.0%)
#     Large (>0.9904m): 105 (33.0%)
#   Clustering:
#     Total clusters: 34
#     Avg cluster size: 10.4 frames
#     Max cluster size: 63 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 34 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-55-34
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1471 valid samples, mean=-2.023, std=1.196
#   diff_sonar_nav: 1471 valid samples, mean=0.111, std=0.728
#   diff_fft_sonar: 1475 valid samples, mean=-2.129, std=1.481
#   diff_pitch_fft_nav: 1471 valid samples, mean=-2.476, std=40.099
#   diff_pitch_sonar_nav: 1471 valid samples, mean=-6.287, std=17.854
#   diff_pitch_fft_sonar: 1475 valid samples, mean=3.820, std=44.054
#   diff_x_fft_nav: 1471 valid samples, mean=-1.992, std=1.188
#   diff_x_sonar_nav: 1471 valid samples, mean=-0.046, std=0.267
#   diff_x_fft_sonar: 1475 valid samples, mean=-1.941, std=1.224
#   diff_y_fft_nav: 1471 valid samples, mean=-0.078, std=0.541
#   diff_y_sonar_nav: 1471 valid samples, mean=-0.427, std=1.266
#   diff_y_fft_sonar: 1475 valid samples, mean=0.348, std=1.228
# Rolling window: 63 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1476 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 542 outliers (36.72%), MAD = 0.0067 m
# Sonar: 127 outliers (8.60%), MAD = 0.0186 m
# DVL: 185 outliers (12.53%), MAD = 0.0169 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.6965 m, Median: 0.1533 m, Max: 6.2904 m
#   Magnitude Categories:
#     Small (≤0.0799m): 179 (33.0%)
#     Medium (0.0799-0.4719m): 184 (33.9%)
#     Large (>0.4719m): 179 (33.0%)
#   Clustering:
#     Total clusters: 49
#     Avg cluster size: 12.1 frames
#     Max cluster size: 63 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 49 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.2469 m, Median: 0.2487 m, Max: 1.5448 m
#   Magnitude Categories:
#     Small (≤0.2062m): 42 (33.1%)
#     Medium (0.2062-0.2487m): 43 (33.9%)
#     Large (>0.2487m): 42 (33.1%)
#   Clustering:
#     Total clusters: 12
#     Avg cluster size: 11.6 frames
#     Max cluster size: 63 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 12 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2107 m, Median: 0.0848 m, Max: 0.5299 m
#   Magnitude Categories:
#     Small (≤0.0701m): 61 (33.0%)
#     Medium (0.0701-0.3076m): 63 (34.1%)
#     Large (>0.3076m): 61 (33.0%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 15.2 frames
#     Max cluster size: 55 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-57-42
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1471 valid samples, mean=-2.023, std=1.196
#   diff_sonar_nav: 1471 valid samples, mean=0.111, std=0.728
#   diff_fft_sonar: 1475 valid samples, mean=-2.129, std=1.481
#   diff_pitch_fft_nav: 1471 valid samples, mean=-2.476, std=40.099
#   diff_pitch_sonar_nav: 1471 valid samples, mean=-6.287, std=17.854
#   diff_pitch_fft_sonar: 1475 valid samples, mean=3.820, std=44.054
#   diff_x_fft_nav: 1471 valid samples, mean=-1.992, std=1.188
#   diff_x_sonar_nav: 1471 valid samples, mean=-0.046, std=0.267
#   diff_x_fft_sonar: 1475 valid samples, mean=-1.941, std=1.224
#   diff_y_fft_nav: 1471 valid samples, mean=-0.078, std=0.541
#   diff_y_sonar_nav: 1471 valid samples, mean=-0.427, std=1.266
#   diff_y_fft_sonar: 1475 valid samples, mean=0.348, std=1.228
# Rolling window: 63 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 1476 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 542 outliers (36.72%), MAD = 0.0067 m
# Sonar: 127 outliers (8.60%), MAD = 0.0186 m
# DVL: 185 outliers (12.53%), MAD = 0.0169 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.6965 m, Median: 0.1533 m, Max: 6.2904 m
#   Magnitude Categories:
#     Small (≤0.0799m): 179 (33.0%)
#     Medium (0.0799-0.4719m): 184 (33.9%)
#     Large (>0.4719m): 179 (33.0%)
#   Clustering:
#     Total clusters: 49
#     Avg cluster size: 12.1 frames
#     Max cluster size: 63 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 49 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.2469 m, Median: 0.2487 m, Max: 1.5448 m
#   Magnitude Categories:
#     Small (≤0.2062m): 42 (33.1%)
#     Medium (0.2062-0.2487m): 43 (33.9%)
#     Large (>0.2487m): 42 (33.1%)
#   Clustering:
#     Total clusters: 12
#     Avg cluster size: 11.6 frames
#     Max cluster size: 63 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 12 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2107 m, Median: 0.0848 m, Max: 0.5299 m
#   Magnitude Categories:
#     Small (≤0.0701m): 61 (33.0%)
#     Medium (0.0701-0.3076m): 63 (34.1%)
#     Large (>0.3076m): 61 (33.0%)
#   Clustering:
#     Total clusters: 13
#     Avg cluster size: 15.2 frames
#     Max cluster size: 55 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 13 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_13-57-42
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 2715 valid samples, mean=-0.132, std=1.123
#   diff_sonar_nav: 2715 valid samples, mean=-0.021, std=0.167
#   diff_fft_sonar: 2744 valid samples, mean=-0.110, std=1.097
#   diff_pitch_fft_nav: 2715 valid samples, mean=-1.628, std=20.708
#   diff_pitch_sonar_nav: 2715 valid samples, mean=-1.391, std=8.712
#   diff_pitch_fft_sonar: 2744 valid samples, mean=-0.084, std=20.741
#   diff_x_fft_nav: 2715 valid samples, mean=-0.144, std=1.115
#   diff_x_sonar_nav: 2715 valid samples, mean=-0.022, std=0.183
#   diff_x_fft_sonar: 2744 valid samples, mean=-0.120, std=1.086
#   diff_y_fft_nav: 2715 valid samples, mean=-0.003, std=0.418
#   diff_y_sonar_nav: 2715 valid samples, mean=-0.037, std=0.209
#   diff_y_fft_sonar: 2744 valid samples, mean=0.037, std=0.420
# Rolling window: 78 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 610 / 2744 (22.2%)
#
# Identifying stable baseline segments...
# Found 5 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 11:58:09 - 11:58:12 (2.8 s, 97 samples)
#   Segment 2: 11:58:21 - 11:58:22 (1.7 s, 60 samples)
#   Segment 3: 11:58:23 - 11:58:26 (2.5 s, 88 samples)
#   Segment 4: 11:58:50 - 11:58:56 (5.9 s, 202 samples)
#   Segment 5: 11:58:58 - 11:59:03 (5.0 s, 168 samples)
# === OUTLIER DETECTION ===
#
# FFT: 603 outliers (21.98%), MAD = 0.0418 m
# Sonar: 274 outliers (9.99%), MAD = 0.0107 m
# DVL: 473 outliers (17.24%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.0950 m, Median: 0.6326 m, Max: 19.0845 m
#   Magnitude Categories:
#     Small (≤0.2717m): 199 (33.0%)
#     Medium (0.2717-1.1094m): 205 (34.0%)
#     Large (>1.1094m): 199 (33.0%)
#   Clustering:
#     Total clusters: 62
#     Avg cluster size: 10.7 frames
#     Max cluster size: 41 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 62 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0592 m, Median: 0.0514 m, Max: 0.1116 m
#   Magnitude Categories:
#     Small (≤0.0454m): 91 (33.2%)
#     Medium (0.0454-0.0665m): 92 (33.6%)
#     Large (>0.0665m): 91 (33.2%)
#   Clustering:
#     Total clusters: 26
#     Avg cluster size: 11.5 frames
#     Max cluster size: 60 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 26 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1667 m, Median: 0.1124 m, Max: 0.8088 m
#   Magnitude Categories:
#     Small (≤0.0847m): 156 (33.0%)
#     Medium (0.0847-0.1643m): 161 (34.0%)
#     Large (>0.1643m): 156 (33.0%)
#   Clustering:
#     Total clusters: 25
#     Avg cluster size: 19.9 frames
#     Max cluster size: 71 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 25 (100.0%)
#
#   ✓ Processed 610 baseline samples, 5 stable segments
# Processing: 2024-08-20_14-16-05
#   diff_fft_nav: 2715 valid samples, mean=-0.132, std=1.123
#   diff_sonar_nav: 2715 valid samples, mean=-0.021, std=0.167
#   diff_fft_sonar: 2744 valid samples, mean=-0.110, std=1.097
#   diff_pitch_fft_nav: 2715 valid samples, mean=-1.628, std=20.708
#   diff_pitch_sonar_nav: 2715 valid samples, mean=-1.391, std=8.712
#   diff_pitch_fft_sonar: 2744 valid samples, mean=-0.084, std=20.741
#   diff_x_fft_nav: 2715 valid samples, mean=-0.144, std=1.115
#   diff_x_sonar_nav: 2715 valid samples, mean=-0.022, std=0.183
#   diff_x_fft_sonar: 2744 valid samples, mean=-0.120, std=1.086
#   diff_y_fft_nav: 2715 valid samples, mean=-0.003, std=0.418
#   diff_y_sonar_nav: 2715 valid samples, mean=-0.037, std=0.209
#   diff_y_fft_sonar: 2744 valid samples, mean=0.037, std=0.420
# Rolling window: 78 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 610 / 2744 (22.2%)
#
# Identifying stable baseline segments...
# Found 5 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 11:58:09 - 11:58:12 (2.8 s, 97 samples)
#   Segment 2: 11:58:21 - 11:58:22 (1.7 s, 60 samples)
#   Segment 3: 11:58:23 - 11:58:26 (2.5 s, 88 samples)
#   Segment 4: 11:58:50 - 11:58:56 (5.9 s, 202 samples)
#   Segment 5: 11:58:58 - 11:59:03 (5.0 s, 168 samples)
# === OUTLIER DETECTION ===
#
# FFT: 603 outliers (21.98%), MAD = 0.0418 m
# Sonar: 274 outliers (9.99%), MAD = 0.0107 m
# DVL: 473 outliers (17.24%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.0950 m, Median: 0.6326 m, Max: 19.0845 m
#   Magnitude Categories:
#     Small (≤0.2717m): 199 (33.0%)
#     Medium (0.2717-1.1094m): 205 (34.0%)
#     Large (>1.1094m): 199 (33.0%)
#   Clustering:
#     Total clusters: 62
#     Avg cluster size: 10.7 frames
#     Max cluster size: 41 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 62 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0592 m, Median: 0.0514 m, Max: 0.1116 m
#   Magnitude Categories:
#     Small (≤0.0454m): 91 (33.2%)
#     Medium (0.0454-0.0665m): 92 (33.6%)
#     Large (>0.0665m): 91 (33.2%)
#   Clustering:
#     Total clusters: 26
#     Avg cluster size: 11.5 frames
#     Max cluster size: 60 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 26 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1667 m, Median: 0.1124 m, Max: 0.8088 m
#   Magnitude Categories:
#     Small (≤0.0847m): 156 (33.0%)
#     Medium (0.0847-0.1643m): 161 (34.0%)
#     Large (>0.1643m): 156 (33.0%)
#   Clustering:
#     Total clusters: 25
#     Avg cluster size: 19.9 frames
#     Max cluster size: 71 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 25 (100.0%)
#
#   ✓ Processed 610 baseline samples, 5 stable segments
# Processing: 2024-08-20_14-16-05
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1618 valid samples, mean=0.008, std=0.649
#   diff_sonar_nav: 1618 valid samples, mean=-0.024, std=0.138
#   diff_fft_sonar: 1726 valid samples, mean=0.051, std=0.595
#   diff_pitch_fft_nav: 1618 valid samples, mean=-13.553, std=14.674
#   diff_pitch_sonar_nav: 1618 valid samples, mean=4.831, std=7.891
#   diff_pitch_fft_sonar: 1726 valid samples, mean=-17.925, std=12.456
#   diff_x_fft_nav: 1618 valid samples, mean=0.036, std=0.652
#   diff_x_sonar_nav: 1618 valid samples, mean=-0.048, std=0.154
#   diff_x_fft_sonar: 1726 valid samples, mean=0.100, std=0.588
#   diff_y_fft_nav: 1618 valid samples, mean=-0.351, std=0.284
#   diff_y_sonar_nav: 1618 valid samples, mean=0.112, std=0.153
#   diff_y_fft_sonar: 1726 valid samples, mean=-0.450, std=0.258
# Rolling window: 74 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 78 / 1727 (4.5%)
#
# Identifying stable baseline segments...
# Found 1 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:16:56 - 12:16:59 (2.3 s, 79 samples)
# === OUTLIER DETECTION ===
#
# FFT: 270 outliers (15.63%), MAD = 0.0322 m
# Sonar: 180 outliers (10.42%), MAD = 0.0188 m
# DVL: 185 outliers (10.71%), MAD = 0.0144 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.9579 m, Median: 0.5754 m, Max: 6.4105 m
#   Magnitude Categories:
#     Small (≤0.1744m): 89 (33.0%)
#     Medium (0.1744-1.0966m): 92 (34.1%)
#     Large (>1.0966m): 89 (33.0%)
#   Clustering:
#     Total clusters: 19
#     Avg cluster size: 15.2 frames
#     Max cluster size: 80 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 19 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1179 m, Median: 0.1136 m, Max: 0.2946 m
#   Magnitude Categories:
#     Small (≤0.0871m): 60 (33.3%)
#     Medium (0.0871-0.1259m): 60 (33.3%)
#     Large (>0.1259m): 60 (33.3%)
#   Clustering:
#     Total clusters: 17
#     Avg cluster size: 11.6 frames
#     Max cluster size: 52 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 17 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1499 m, Median: 0.1000 m, Max: 0.9158 m
#   Magnitude Categories:
#     Small (≤0.0787m): 61 (33.0%)
#     Medium (0.0787-0.1194m): 63 (34.1%)
#     Large (>0.1194m): 61 (33.0%)
#   Clustering:
#     Total clusters: 11
#     Avg cluster size: 17.7 frames
#     Max cluster size: 51 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 11 (100.0%)
#
#   ✓ Processed 78 baseline samples, 1 stable segments
# Processing: 2024-08-20_14-22-12
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 2352 valid samples, mean=-0.349, std=5.145
#   diff_sonar_nav: 2352 valid samples, mean=-0.009, std=0.176
#   diff_fft_sonar: 2400 valid samples, mean=-0.356, std=5.076
#   diff_pitch_fft_nav: 2352 valid samples, mean=-20.279, std=17.061
#   diff_pitch_sonar_nav: 2352 valid samples, mean=5.882, std=7.964
#   diff_pitch_fft_sonar: 2400 valid samples, mean=-25.893, std=16.690
#   diff_x_fft_nav: 2352 valid samples, mean=-0.302, std=5.120
#   diff_x_sonar_nav: 2352 valid samples, mean=-0.052, std=0.183
#   diff_x_fft_sonar: 2400 valid samples, mean=-0.268, std=5.054
#   diff_y_fft_nav: 2352 valid samples, mean=-0.429, std=0.611
#   diff_y_sonar_nav: 2352 valid samples, mean=0.150, std=0.180
#   diff_y_fft_sonar: 2400 valid samples, mean=-0.575, std=0.586
# Rolling window: 75 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 2401 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 570 outliers (23.74%), MAD = 0.0544 m
# Sonar: 166 outliers (6.91%), MAD = 0.0239 m
# DVL: 463 outliers (19.28%), MAD = 0.0186 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 3.2709 m, Median: 1.0912 m, Max: 125.5358 m
#   Magnitude Categories:
#     Small (≤0.6276m): 188 (33.0%)
#     Medium (0.6276-1.7706m): 194 (34.0%)
#     Large (>1.7706m): 188 (33.0%)
#   Clustering:
#     Total clusters: 44
#     Avg cluster size: 14.0 frames
#     Max cluster size: 44 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 44 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1282 m, Median: 0.1113 m, Max: 0.3178 m
#   Magnitude Categories:
#     Small (≤0.1017m): 55 (33.1%)
#     Medium (0.1017-0.1353m): 56 (33.7%)
#     Large (>0.1353m): 55 (33.1%)
#   Clustering:
#     Total clusters: 42
#     Avg cluster size: 4.9 frames
#     Max cluster size: 15 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 42 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1994 m, Median: 0.1089 m, Max: 0.8200 m
#   Magnitude Categories:
#     Small (≤0.0893m): 153 (33.0%)
#     Medium (0.0893-0.1989m): 157 (33.9%)
#     Large (>0.1989m): 153 (33.0%)
#   Clustering:
#     Total clusters: 29
#     Avg cluster size: 16.9 frames
#     Max cluster size: 83 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 29 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_14-24-35
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1618 valid samples, mean=0.008, std=0.649
#   diff_sonar_nav: 1618 valid samples, mean=-0.024, std=0.138
#   diff_fft_sonar: 1726 valid samples, mean=0.051, std=0.595
#   diff_pitch_fft_nav: 1618 valid samples, mean=-13.553, std=14.674
#   diff_pitch_sonar_nav: 1618 valid samples, mean=4.831, std=7.891
#   diff_pitch_fft_sonar: 1726 valid samples, mean=-17.925, std=12.456
#   diff_x_fft_nav: 1618 valid samples, mean=0.036, std=0.652
#   diff_x_sonar_nav: 1618 valid samples, mean=-0.048, std=0.154
#   diff_x_fft_sonar: 1726 valid samples, mean=0.100, std=0.588
#   diff_y_fft_nav: 1618 valid samples, mean=-0.351, std=0.284
#   diff_y_sonar_nav: 1618 valid samples, mean=0.112, std=0.153
#   diff_y_fft_sonar: 1726 valid samples, mean=-0.450, std=0.258
# Rolling window: 74 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 78 / 1727 (4.5%)
#
# Identifying stable baseline segments...
# Found 1 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:16:56 - 12:16:59 (2.3 s, 79 samples)
# === OUTLIER DETECTION ===
#
# FFT: 270 outliers (15.63%), MAD = 0.0322 m
# Sonar: 180 outliers (10.42%), MAD = 0.0188 m
# DVL: 185 outliers (10.71%), MAD = 0.0144 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.9579 m, Median: 0.5754 m, Max: 6.4105 m
#   Magnitude Categories:
#     Small (≤0.1744m): 89 (33.0%)
#     Medium (0.1744-1.0966m): 92 (34.1%)
#     Large (>1.0966m): 89 (33.0%)
#   Clustering:
#     Total clusters: 19
#     Avg cluster size: 15.2 frames
#     Max cluster size: 80 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 19 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1179 m, Median: 0.1136 m, Max: 0.2946 m
#   Magnitude Categories:
#     Small (≤0.0871m): 60 (33.3%)
#     Medium (0.0871-0.1259m): 60 (33.3%)
#     Large (>0.1259m): 60 (33.3%)
#   Clustering:
#     Total clusters: 17
#     Avg cluster size: 11.6 frames
#     Max cluster size: 52 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 17 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1499 m, Median: 0.1000 m, Max: 0.9158 m
#   Magnitude Categories:
#     Small (≤0.0787m): 61 (33.0%)
#     Medium (0.0787-0.1194m): 63 (34.1%)
#     Large (>0.1194m): 61 (33.0%)
#   Clustering:
#     Total clusters: 11
#     Avg cluster size: 17.7 frames
#     Max cluster size: 51 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 11 (100.0%)
#
#   ✓ Processed 78 baseline samples, 1 stable segments
# Processing: 2024-08-20_14-22-12
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 2352 valid samples, mean=-0.349, std=5.145
#   diff_sonar_nav: 2352 valid samples, mean=-0.009, std=0.176
#   diff_fft_sonar: 2400 valid samples, mean=-0.356, std=5.076
#   diff_pitch_fft_nav: 2352 valid samples, mean=-20.279, std=17.061
#   diff_pitch_sonar_nav: 2352 valid samples, mean=5.882, std=7.964
#   diff_pitch_fft_sonar: 2400 valid samples, mean=-25.893, std=16.690
#   diff_x_fft_nav: 2352 valid samples, mean=-0.302, std=5.120
#   diff_x_sonar_nav: 2352 valid samples, mean=-0.052, std=0.183
#   diff_x_fft_sonar: 2400 valid samples, mean=-0.268, std=5.054
#   diff_y_fft_nav: 2352 valid samples, mean=-0.429, std=0.611
#   diff_y_sonar_nav: 2352 valid samples, mean=0.150, std=0.180
#   diff_y_fft_sonar: 2400 valid samples, mean=-0.575, std=0.586
# Rolling window: 75 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 2401 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 570 outliers (23.74%), MAD = 0.0544 m
# Sonar: 166 outliers (6.91%), MAD = 0.0239 m
# DVL: 463 outliers (19.28%), MAD = 0.0186 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 3.2709 m, Median: 1.0912 m, Max: 125.5358 m
#   Magnitude Categories:
#     Small (≤0.6276m): 188 (33.0%)
#     Medium (0.6276-1.7706m): 194 (34.0%)
#     Large (>1.7706m): 188 (33.0%)
#   Clustering:
#     Total clusters: 44
#     Avg cluster size: 14.0 frames
#     Max cluster size: 44 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 44 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1282 m, Median: 0.1113 m, Max: 0.3178 m
#   Magnitude Categories:
#     Small (≤0.1017m): 55 (33.1%)
#     Medium (0.1017-0.1353m): 56 (33.7%)
#     Large (>0.1353m): 55 (33.1%)
#   Clustering:
#     Total clusters: 42
#     Avg cluster size: 4.9 frames
#     Max cluster size: 15 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 42 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1994 m, Median: 0.1089 m, Max: 0.8200 m
#   Magnitude Categories:
#     Small (≤0.0893m): 153 (33.0%)
#     Medium (0.0893-0.1989m): 157 (33.9%)
#     Large (>0.1989m): 153 (33.0%)
#   Clustering:
#     Total clusters: 29
#     Avg cluster size: 16.9 frames
#     Max cluster size: 83 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 29 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_14-24-35
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 2676 valid samples, mean=-0.647, std=2.169
#   diff_sonar_nav: 2676 valid samples, mean=-0.150, std=0.136
#   diff_fft_sonar: 2737 valid samples, mean=-0.527, std=2.146
#   diff_pitch_fft_nav: 2676 valid samples, mean=-5.679, std=30.629
#   diff_pitch_sonar_nav: 2676 valid samples, mean=0.201, std=7.269
#   diff_pitch_fft_sonar: 2737 valid samples, mean=-6.206, std=30.862
#   diff_x_fft_nav: 2676 valid samples, mean=-0.754, std=1.757
#   diff_x_sonar_nav: 2676 valid samples, mean=-0.152, std=0.140
#   diff_x_fft_sonar: 2737 valid samples, mean=-0.623, std=1.729
#   diff_y_fft_nav: 2676 valid samples, mean=-0.041, std=1.418
#   diff_y_sonar_nav: 2676 valid samples, mean=-0.005, std=0.211
#   diff_y_fft_sonar: 2737 valid samples, mean=-0.061, std=1.404
# Rolling window: 72 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 2738 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 678 outliers (24.76%), MAD = 0.0562 m
# Sonar: 153 outliers (5.59%), MAD = 0.0203 m
# DVL: 402 outliers (14.68%), MAD = 0.0140 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.7136 m, Median: 0.7110 m, Max: 29.1362 m
#   Magnitude Categories:
#     Small (≤0.4107m): 224 (33.0%)
#     Medium (0.4107-1.0984m): 230 (33.9%)
#     Large (>1.0984m): 224 (33.0%)
#   Clustering:
#     Total clusters: 68
#     Avg cluster size: 11.0 frames
#     Max cluster size: 88 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 68 (100.0%)
#
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 2676 valid samples, mean=-0.647, std=2.169
#   diff_sonar_nav: 2676 valid samples, mean=-0.150, std=0.136
#   diff_fft_sonar: 2737 valid samples, mean=-0.527, std=2.146
#   diff_pitch_fft_nav: 2676 valid samples, mean=-5.679, std=30.629
#   diff_pitch_sonar_nav: 2676 valid samples, mean=0.201, std=7.269
#   diff_pitch_fft_sonar: 2737 valid samples, mean=-6.206, std=30.862
#   diff_x_fft_nav: 2676 valid samples, mean=-0.754, std=1.757
#   diff_x_sonar_nav: 2676 valid samples, mean=-0.152, std=0.140
#   diff_x_fft_sonar: 2737 valid samples, mean=-0.623, std=1.729
#   diff_y_fft_nav: 2676 valid samples, mean=-0.041, std=1.418
#   diff_y_sonar_nav: 2676 valid samples, mean=-0.005, std=0.211
#   diff_y_fft_sonar: 2737 valid samples, mean=-0.061, std=1.404
# Rolling window: 72 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 0 / 2738 (0.0%)
#
# Identifying stable baseline segments...
# Found 0 stable baseline segments (≥ 1.0 s):
#
# === OUTLIER DETECTION ===
#
# FFT: 678 outliers (24.76%), MAD = 0.0562 m
# Sonar: 153 outliers (5.59%), MAD = 0.0203 m
# DVL: 402 outliers (14.68%), MAD = 0.0140 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 1.7136 m, Median: 0.7110 m, Max: 29.1362 m
#   Magnitude Categories:
#     Small (≤0.4107m): 224 (33.0%)
#     Medium (0.4107-1.0984m): 230 (33.9%)
#     Large (>1.0984m): 224 (33.0%)
#   Clustering:
#     Total clusters: 68
#     Avg cluster size: 11.0 frames
#     Max cluster size: 88 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 68 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0979 m, Median: 0.0956 m, Max: 0.1589 m
#   Magnitude Categories:
#     Small (≤0.0842m): 51 (33.3%)
#     Medium (0.0842-0.1057m): 51 (33.3%)
#     Large (>0.1057m): 51 (33.3%)
#   Clustering:
#     Total clusters: 30
#     Avg cluster size: 6.1 frames
#     Max cluster size: 31 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 30 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1355 m, Median: 0.0781 m, Max: 0.9760 m
#   Magnitude Categories:
#     Small (≤0.0687m): 133 (33.1%)
#     Medium (0.0687-0.1101m): 136 (33.8%)
#     Large (>0.1101m): 133 (33.1%)
#   Clustering:
#     Total clusters: 20
#     Avg cluster size: 21.1 frames
#     Max cluster size: 145 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 20 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_14-31-29
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 2234 valid samples, mean=-0.614, std=4.790
#   diff_sonar_nav: 2234 valid samples, mean=-0.066, std=0.256
#   diff_fft_sonar: 2234 valid samples, mean=-0.548, std=4.796
#   diff_pitch_fft_nav: 2234 valid samples, mean=-1.216, std=35.555
#   diff_pitch_sonar_nav: 2234 valid samples, mean=-3.217, std=22.186
#   diff_pitch_fft_sonar: 2234 valid samples, mean=2.001, std=36.626
#   diff_x_fft_nav: 2234 valid samples, mean=-0.670, std=4.699
#   diff_x_sonar_nav: 2234 valid samples, mean=-0.125, std=0.230
#   diff_x_fft_sonar: 2234 valid samples, mean=-0.545, std=4.703
#   diff_y_fft_nav: 2234 valid samples, mean=-0.019, std=1.133
#   diff_y_sonar_nav: 2234 valid samples, mean=-0.105, std=0.689
#   diff_y_fft_sonar: 2234 valid samples, mean=0.086, std=1.218
# Rolling window: 73 samples (2.0 s)
#
# Computing rolling statistics...
# SONAR:
#   Magnitude:
#     Mean: 0.0979 m, Median: 0.0956 m, Max: 0.1589 m
#   Magnitude Categories:
#     Small (≤0.0842m): 51 (33.3%)
#     Medium (0.0842-0.1057m): 51 (33.3%)
#     Large (>0.1057m): 51 (33.3%)
#   Clustering:
#     Total clusters: 30
#     Avg cluster size: 6.1 frames
#     Max cluster size: 31 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 30 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1355 m, Median: 0.0781 m, Max: 0.9760 m
#   Magnitude Categories:
#     Small (≤0.0687m): 133 (33.1%)
#     Medium (0.0687-0.1101m): 136 (33.8%)
#     Large (>0.1101m): 133 (33.1%)
#   Clustering:
#     Total clusters: 20
#     Avg cluster size: 21.1 frames
#     Max cluster size: 145 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 20 (100.0%)
#
#   ✓ Processed 0 baseline samples, 0 stable segments
# Processing: 2024-08-20_14-31-29
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 2234 valid samples, mean=-0.614, std=4.790
#   diff_sonar_nav: 2234 valid samples, mean=-0.066, std=0.256
#   diff_fft_sonar: 2234 valid samples, mean=-0.548, std=4.796
#   diff_pitch_fft_nav: 2234 valid samples, mean=-1.216, std=35.555
#   diff_pitch_sonar_nav: 2234 valid samples, mean=-3.217, std=22.186
#   diff_pitch_fft_sonar: 2234 valid samples, mean=2.001, std=36.626
#   diff_x_fft_nav: 2234 valid samples, mean=-0.670, std=4.699
#   diff_x_sonar_nav: 2234 valid samples, mean=-0.125, std=0.230
#   diff_x_fft_sonar: 2234 valid samples, mean=-0.545, std=4.703
#   diff_y_fft_nav: 2234 valid samples, mean=-0.019, std=1.133
#   diff_y_sonar_nav: 2234 valid samples, mean=-0.105, std=0.689
#   diff_y_fft_sonar: 2234 valid samples, mean=0.086, std=1.218
# Rolling window: 73 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 66 / 2235 (3.0%)
#
# Identifying stable baseline segments...
# Found 1 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:31:50 - 12:31:51 (1.1 s, 40 samples)
# === OUTLIER DETECTION ===
#
# FFT: 531 outliers (23.76%), MAD = 0.1346 m
# Sonar: 267 outliers (11.95%), MAD = 0.0228 m
# DVL: 500 outliers (22.37%), MAD = 0.0148 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 3.5556 m, Median: 1.5832 m, Max: 103.7188 m
#   Magnitude Categories:
#     Small (≤1.2169m): 175 (33.0%)
#     Medium (1.2169-1.8274m): 181 (34.1%)
#     Large (>1.8274m): 175 (33.0%)
#   Clustering:
#     Total clusters: 72
#     Avg cluster size: 8.4 frames
#     Max cluster size: 51 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 72 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.1706 m, Median: 0.1512 m, Max: 0.3292 m
#   Magnitude Categories:
#     Small (≤0.1177m): 88 (33.0%)
#     Medium (0.1177-0.1963m): 91 (34.1%)
#     Large (>0.1963m): 88 (33.0%)
#   Clustering:
#     Total clusters: 22
#     Avg cluster size: 13.1 frames
#     Max cluster size: 52 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 22 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.3148 m, Median: 0.2000 m, Max: 1.3434 m
#   Magnitude Categories:
#     Small (≤0.1174m): 165 (33.0%)
#     Medium (0.1174-0.4292m): 170 (34.0%)
#     Large (>0.4292m): 165 (33.0%)
#   Clustering:
#     Total clusters: 21
#     Avg cluster size: 24.8 frames
#     Max cluster size: 109 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 21 (100.0%)
#
#   ✓ Processed 66 baseline samples, 1 stable segments
# Processing: 2024-08-20_14-57-38
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 3125 valid samples, mean=-0.193, std=4.263
#   diff_sonar_nav: 3125 valid samples, mean=-0.040, std=0.116
#   diff_fft_sonar: 3162 valid samples, mean=-0.179, std=4.241
#   diff_pitch_fft_nav: 3125 valid samples, mean=0.823, std=22.496
#   diff_pitch_sonar_nav: 3125 valid samples, mean=-0.818, std=5.348
#   diff_pitch_fft_sonar: 3162 valid samples, mean=0.952, std=22.803
#   diff_x_fft_nav: 3125 valid samples, mean=-0.228, std=4.256
#   diff_x_sonar_nav: 3125 valid samples, mean=-0.039, std=0.122
# ...
#     Mean: 0.0843 m, Median: 0.0868 m, Max: 0.1259 m
#   Magnitude Categories:
#     Small (≤0.0662m): 20 (33.3%)
#     Medium (0.0662-0.1072m): 20 (33.3%)
#     Large (>0.1072m): 20 (33.3%)
#   Clustering:
#     Total clusters: 5
#     Avg cluster size: 13.0 frames
#     Max cluster size: 47 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 5 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2997 m, Median: 0.1843 m, Max: 0.6090 m
#   Magnitude Categories:
#     Small (≤0.1126m): 10 (33.3%)
#     Medium (0.1126-0.4998m): 10 (33.3%)
#     Large (>0.4998m): 10 (33.3%)
#   Clustering:
#     Total clusters: 6
#     Avg cluster size: 6.0 frames
#     Max cluster size: 8 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 6 (100.0%)
#
#   ✓ Processed 70 baseline samples, 1 stable segments
# Processing: 2024-08-22_14-06-43
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1086 valid samples, mean=-0.462, std=0.566
#   diff_sonar_nav: 1086 valid samples, mean=0.050, std=0.129
#   diff_fft_sonar: 1162 valid samples, mean=-0.490, std=0.597
#   diff_pitch_fft_nav: 1086 valid samples, mean=14.175, std=42.175
#   diff_pitch_sonar_nav: 1086 valid samples, mean=-4.912, std=9.696
#   diff_pitch_fft_sonar: 1162 valid samples, mean=18.738, std=42.895
#   diff_x_fft_nav: 1086 valid samples, mean=-0.378, std=0.476
#   diff_x_sonar_nav: 1086 valid samples, mean=-0.014, std=0.098
#   diff_x_fft_sonar: 1162 valid samples, mean=-0.352, std=0.446
#   diff_y_fft_nav: 1086 valid samples, mean=0.249, std=0.365
#   diff_y_sonar_nav: 1086 valid samples, mean=-0.081, std=0.157
#   diff_y_fft_sonar: 1162 valid samples, mean=0.316, std=0.453
# Rolling window: 65 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 165 / 1163 (14.2%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:06:53 - 12:06:55 (2.5 s, 85 samples)
#   Segment 2: 12:06:57 - 12:07:00 (2.3 s, 82 samples)
# === OUTLIER DETECTION ===
#
# FFT: 343 outliers (29.49%), MAD = 0.0112 m
# Sonar: 149 outliers (12.81%), MAD = 0.0080 m
# DVL: 88 outliers (7.57%), MAD = 0.0150 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.4899 m, Median: 0.3451 m, Max: 6.9374 m
#   Magnitude Categories:
#     Small (≤0.1411m): 113 (32.9%)
#     Medium (0.1411-0.6003m): 117 (34.1%)
#     Large (>0.6003m): 113 (32.9%)
#   Clustering:
#     Total clusters: 29
#     Avg cluster size: 12.8 frames
#     Max cluster size: 60 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 29 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0692 m, Median: 0.0731 m, Max: 0.1139 m
#   Magnitude Categories:
#     Small (≤0.0561m): 49 (32.9%)
#     Medium (0.0561-0.0816m): 51 (34.2%)
#     Large (>0.0816m): 49 (32.9%)
#   Clustering:
#     Total clusters: 6
#     Avg cluster size: 25.8 frames
#     Max cluster size: 58 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 6 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2150 m, Median: 0.1302 m, Max: 0.5514 m
#   Magnitude Categories:
#     Small (≤0.0763m): 29 (33.0%)
#     Medium (0.0763-0.3018m): 30 (34.1%)
#     Large (>0.3018m): 29 (33.0%)
#   Clustering:
#     Total clusters: 21
#     Avg cluster size: 5.2 frames
#     Max cluster size: 11 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 21 (100.0%)
#
#   ✓ Processed 165 baseline samples, 2 stable segments
# Processing: 2024-08-22_14-29-05
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1834 valid samples, mean=-0.310, std=0.343
#   diff_sonar_nav: 1834 valid samples, mean=0.041, std=0.045
#   diff_fft_sonar: 1929 valid samples, mean=-0.344, std=0.358
#   diff_pitch_fft_nav: 1834 valid samples, mean=6.403, std=42.273
#   diff_pitch_sonar_nav: 1834 valid samples, mean=-1.905, std=6.962
#   diff_pitch_fft_sonar: 1929 valid samples, mean=7.597, std=40.373
#   diff_x_fft_nav: 1834 valid samples, mean=-0.312, std=0.337
#   diff_x_sonar_nav: 1834 valid samples, mean=0.040, std=0.047
#   diff_x_fft_sonar: 1929 valid samples, mean=-0.346, std=0.351
#   diff_y_fft_nav: 1834 valid samples, mean=0.055, std=0.106
#   diff_y_sonar_nav: 1834 valid samples, mean=-0.020, std=0.073
#   diff_y_fft_sonar: 1929 valid samples, mean=0.075, std=0.102
# Rolling window: 65 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 554 / 1930 (28.7%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:29:15 - 12:29:18 (2.5 s, 89 samples)
#   Segment 2: 12:29:56 - 12:30:10 (13.5 s, 445 samples)
# DVL: 88 outliers (7.57%), MAD = 0.0150 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.4899 m, Median: 0.3451 m, Max: 6.9374 m
#   Magnitude Categories:
#     Small (≤0.1411m): 113 (32.9%)
#     Medium (0.1411-0.6003m): 117 (34.1%)
#     Large (>0.6003m): 113 (32.9%)
#   Clustering:
#     Total clusters: 29
#     Avg cluster size: 12.8 frames
#     Max cluster size: 60 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 29 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0692 m, Median: 0.0731 m, Max: 0.1139 m
#   Magnitude Categories:
#     Small (≤0.0561m): 49 (32.9%)
#     Medium (0.0561-0.0816m): 51 (34.2%)
#     Large (>0.0816m): 49 (32.9%)
#   Clustering:
#     Total clusters: 6
#     Avg cluster size: 25.8 frames
#     Max cluster size: 58 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 6 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.2150 m, Median: 0.1302 m, Max: 0.5514 m
#   Magnitude Categories:
#     Small (≤0.0763m): 29 (33.0%)
#     Medium (0.0763-0.3018m): 30 (34.1%)
#     Large (>0.3018m): 29 (33.0%)
#   Clustering:
#     Total clusters: 21
#     Avg cluster size: 5.2 frames
#     Max cluster size: 11 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 21 (100.0%)
#
#   ✓ Processed 165 baseline samples, 2 stable segments
# Processing: 2024-08-22_14-29-05
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1834 valid samples, mean=-0.310, std=0.343
#   diff_sonar_nav: 1834 valid samples, mean=0.041, std=0.045
#   diff_fft_sonar: 1929 valid samples, mean=-0.344, std=0.358
#   diff_pitch_fft_nav: 1834 valid samples, mean=6.403, std=42.273
#   diff_pitch_sonar_nav: 1834 valid samples, mean=-1.905, std=6.962
#   diff_pitch_fft_sonar: 1929 valid samples, mean=7.597, std=40.373
#   diff_x_fft_nav: 1834 valid samples, mean=-0.312, std=0.337
#   diff_x_sonar_nav: 1834 valid samples, mean=0.040, std=0.047
#   diff_x_fft_sonar: 1929 valid samples, mean=-0.346, std=0.351
#   diff_y_fft_nav: 1834 valid samples, mean=0.055, std=0.106
#   diff_y_sonar_nav: 1834 valid samples, mean=-0.020, std=0.073
#   diff_y_fft_sonar: 1929 valid samples, mean=0.075, std=0.102
# Rolling window: 65 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 554 / 1930 (28.7%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:29:15 - 12:29:18 (2.5 s, 89 samples)
#   Segment 2: 12:29:56 - 12:30:10 (13.5 s, 445 samples)
# === OUTLIER DETECTION ===
#
# FFT: 672 outliers (34.82%), MAD = 0.0014 m
# Sonar: 53 outliers (2.75%), MAD = 0.0133 m
# DVL: 38 outliers (1.97%), MAD = 0.0142 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.1265 m, Median: 0.0235 m, Max: 1.5223 m
#   Magnitude Categories:
#     Small (≤0.0155m): 222 (33.0%)
#     Medium (0.0155-0.0451m): 228 (33.9%)
#     Large (>0.0451m): 222 (33.0%)
#   Clustering:
#     Total clusters: 42
#     Avg cluster size: 17.0 frames
#     Max cluster size: 75 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 42 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0683 m, Median: 0.0702 m, Max: 0.1067 m
#   Magnitude Categories:
#     Small (≤0.0613m): 18 (34.0%)
#     Medium (0.0613-0.0761m): 17 (32.1%)
#     Large (>0.0761m): 18 (34.0%)
#   Clustering:
#     Total clusters: 5
#     Avg cluster size: 11.6 frames
#     Max cluster size: 36 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 5 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1267 m, Median: 0.0599 m, Max: 0.4086 m
#   Magnitude Categories:
#     Small (≤0.0575m): 13 (34.2%)
#     Medium (0.0575-0.0620m): 12 (31.6%)
#     Large (>0.0620m): 13 (34.2%)
#   Clustering:
#     Total clusters: 9
#     Avg cluster size: 5.2 frames
#     Max cluster size: 9 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 9 (100.0%)
#
#   ✓ Processed 554 baseline samples, 2 stable segments
# Processing: 2024-08-22_14-47-39
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1371 valid samples, mean=-0.331, std=0.369
#   diff_sonar_nav: 1371 valid samples, mean=0.050, std=0.053
#   diff_fft_sonar: 1462 valid samples, mean=-0.367, std=0.377
#   diff_pitch_fft_nav: 1371 valid samples, mean=8.762, std=42.822
#   diff_pitch_sonar_nav: 1371 valid samples, mean=-3.836, std=9.121
#   diff_pitch_fft_sonar: 1462 valid samples, mean=12.267, std=41.299
#   diff_x_fft_nav: 1371 valid samples, mean=-0.335, std=0.356
#   diff_x_sonar_nav: 1371 valid samples, mean=0.049, std=0.059
#   diff_x_fft_sonar: 1462 valid samples, mean=-0.370, std=0.366
#   diff_y_fft_nav: 1371 valid samples, mean=0.065, std=0.130
#   diff_y_sonar_nav: 1371 valid samples, mean=-0.046, std=0.094
#   diff_y_fft_sonar: 1462 valid samples, mean=0.109, std=0.112
# Rolling window: 67 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 289 / 1463 (19.8%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:47:48 - 12:47:53 (4.7 s, 159 samples)
#   Segment 2: 12:48:23 - 12:48:27 (3.9 s, 132 samples)
# === OUTLIER DETECTION ===
#
# FFT: 362 outliers (24.74%), MAD = 0.0093 m
# Sonar: 79 outliers (5.40%), MAD = 0.0108 m
# DVL: 108 outliers (7.38%), MAD = 0.0133 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3807 m, Median: 0.2514 m, Max: 2.1867 m
#   Magnitude Categories:
#     Small (≤0.0577m): 120 (33.1%)
#     Medium (0.0577-0.5543m): 122 (33.7%)
#     Large (>0.5543m): 120 (33.1%)
#   Clustering:
#     Total clusters: 31
#     Avg cluster size: 12.7 frames
#     Max cluster size: 43 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 31 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0534 m, Median: 0.0466 m, Max: 0.1043 m
#   Magnitude Categories:
#     Small (≤0.0427m): 26 (32.9%)
#     Medium (0.0427-0.0508m): 27 (34.2%)
#     Large (>0.0508m): 26 (32.9%)
#   Clustering:
#     Total clusters: 8
#     Avg cluster size: 10.9 frames
#     Max cluster size: 27 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 8 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.0886 m, Median: 0.0699 m, Max: 0.3844 m
#   Magnitude Categories:
#     Small (≤0.0605m): 36 (33.3%)
#     Medium (0.0605-0.0734m): 36 (33.3%)
#     Large (>0.0734m): 36 (33.3%)
#   Clustering:
#     Total clusters: 15
#     Avg cluster size: 8.1 frames
#     Max cluster size: 41 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 15 (100.0%)
#
#   ✓ Processed 289 baseline samples, 2 stable segments
# ✓ Summary CSV saved: bag_summary.csv
#   Location: /Volumes/LaCie/SOLAQUA/comparison_data/bag_summary.csv
#
# ======================================================================
# ✓ Summary CSV regenerated successfully!
#   Location: /Volumes/LaCie/SOLAQUA/comparison_data/bag_summary.csv
#
# The summary now includes:
#   ✓ Outlier magnitude metrics (mean, median, max)
#   ✓ Outlier clustering analysis (cluster count, sizes)
#   ✓ Isolated vs. multi-frame outlier statistics
#
# Re-run the 'Multi-Bag Summary Analysis' cell above to see the updated statistics.
# === OUTLIER DETECTION ===
#
# FFT: 672 outliers (34.82%), MAD = 0.0014 m
# Sonar: 53 outliers (2.75%), MAD = 0.0133 m
# DVL: 38 outliers (1.97%), MAD = 0.0142 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.1265 m, Median: 0.0235 m, Max: 1.5223 m
#   Magnitude Categories:
#     Small (≤0.0155m): 222 (33.0%)
#     Medium (0.0155-0.0451m): 228 (33.9%)
#     Large (>0.0451m): 222 (33.0%)
#   Clustering:
#     Total clusters: 42
#     Avg cluster size: 17.0 frames
#     Max cluster size: 75 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 42 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0683 m, Median: 0.0702 m, Max: 0.1067 m
#   Magnitude Categories:
#     Small (≤0.0613m): 18 (34.0%)
#     Medium (0.0613-0.0761m): 17 (32.1%)
#     Large (>0.0761m): 18 (34.0%)
#   Clustering:
#     Total clusters: 5
#     Avg cluster size: 11.6 frames
#     Max cluster size: 36 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 5 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.1267 m, Median: 0.0599 m, Max: 0.4086 m
#   Magnitude Categories:
#     Small (≤0.0575m): 13 (34.2%)
#     Medium (0.0575-0.0620m): 12 (31.6%)
#     Large (>0.0620m): 13 (34.2%)
#   Clustering:
#     Total clusters: 9
#     Avg cluster size: 5.2 frames
#     Max cluster size: 9 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 9 (100.0%)
#
#   ✓ Processed 554 baseline samples, 2 stable segments
# Processing: 2024-08-22_14-47-39
#
# Applying exponential smoothing (α=0.75)...
#   ✓ Smoothed 12 columns
# Pairwise differences computed:
#   diff_fft_nav: 1371 valid samples, mean=-0.331, std=0.369
#   diff_sonar_nav: 1371 valid samples, mean=0.050, std=0.053
#   diff_fft_sonar: 1462 valid samples, mean=-0.367, std=0.377
#   diff_pitch_fft_nav: 1371 valid samples, mean=8.762, std=42.822
#   diff_pitch_sonar_nav: 1371 valid samples, mean=-3.836, std=9.121
#   diff_pitch_fft_sonar: 1462 valid samples, mean=12.267, std=41.299
#   diff_x_fft_nav: 1371 valid samples, mean=-0.335, std=0.356
#   diff_x_sonar_nav: 1371 valid samples, mean=0.049, std=0.059
#   diff_x_fft_sonar: 1462 valid samples, mean=-0.370, std=0.366
#   diff_y_fft_nav: 1371 valid samples, mean=0.065, std=0.130
#   diff_y_sonar_nav: 1371 valid samples, mean=-0.046, std=0.094
#   diff_y_fft_sonar: 1462 valid samples, mean=0.109, std=0.112
# Rolling window: 67 samples (2.0 s)
#
# Computing rolling statistics...
# Applying stability criteria...
# Stable samples: 289 / 1463 (19.8%)
#
# Identifying stable baseline segments...
# Found 2 stable baseline segments (≥ 1.0 s):
#
#   Segment 1: 12:47:48 - 12:47:53 (4.7 s, 159 samples)
#   Segment 2: 12:48:23 - 12:48:27 (3.9 s, 132 samples)
# === OUTLIER DETECTION ===
#
# FFT: 362 outliers (24.74%), MAD = 0.0093 m
# Sonar: 79 outliers (5.40%), MAD = 0.0108 m
# DVL: 108 outliers (7.38%), MAD = 0.0133 m
#
# === OUTLIER CHARACTERISTICS ===
#
# FFT:
#   Magnitude:
#     Mean: 0.3807 m, Median: 0.2514 m, Max: 2.1867 m
#   Magnitude Categories:
#     Small (≤0.0577m): 120 (33.1%)
#     Medium (0.0577-0.5543m): 122 (33.7%)
#     Large (>0.5543m): 120 (33.1%)
#   Clustering:
#     Total clusters: 31
#     Avg cluster size: 12.7 frames
#     Max cluster size: 43 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 31 (100.0%)
#
# SONAR:
#   Magnitude:
#     Mean: 0.0534 m, Median: 0.0466 m, Max: 0.1043 m
#   Magnitude Categories:
#     Small (≤0.0427m): 26 (32.9%)
#     Medium (0.0427-0.0508m): 27 (34.2%)
#     Large (>0.0508m): 26 (32.9%)
#   Clustering:
#     Total clusters: 8
#     Avg cluster size: 10.9 frames
#     Max cluster size: 27 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 8 (100.0%)
#
# DVL:
#   Magnitude:
#     Mean: 0.0886 m, Median: 0.0699 m, Max: 0.3844 m
#   Magnitude Categories:
#     Small (≤0.0605m): 36 (33.3%)
#     Medium (0.0605-0.0734m): 36 (33.3%)
#     Large (>0.0734m): 36 (33.3%)
#   Clustering:
#     Total clusters: 15
#     Avg cluster size: 8.1 frames
#     Max cluster size: 41 frames
#     Isolated outliers: 0 (0.0%)
#     Multi-frame clusters: 15 (100.0%)
#
#   ✓ Processed 289 baseline samples, 2 stable segments
# ✓ Summary CSV saved: bag_summary.csv
#   Location: /Volumes/LaCie/SOLAQUA/comparison_data/bag_summary.csv
#
# ======================================================================
# ✓ Summary CSV regenerated successfully!
#   Location: /Volumes/LaCie/SOLAQUA/comparison_data/bag_summary.csv
#
# The summary now includes:
#   ✓ Outlier magnitude metrics (mean, median, max)
#   ✓ Outlier clustering analysis (cluster count, sizes)
#   ✓ Isolated vs. multi-frame outlier statistics
#
# Re-run the 'Multi-Bag Summary Analysis' cell above to see the updated statistics.

# %% [markdown]
# ## Multi-Bag Summary Analysis
#
# Load and analyze the comprehensive summary CSV containing all processed bags.

# %%
# Load and display multi-bag summary statistics
summary_csv_path = COMPARISON_DATA_DIR / "bag_summary.csv"
summary_df = print_multi_bag_summary(summary_csv_path)

# Optional: further analysis on summary_df
if summary_df is not None:
    print("\n📊 Additional insights:")
    print(f"  DataFrame available for custom analysis")
    print(f"  Example: summary_df[summary_df['baseline_percentage'] > 50]")
    
    # Check if outlier magnitude columns exist
    has_magnitude = any('outlier_mean_magnitude' in col for col in summary_df.columns)
    has_clustering = any('outlier_cluster_count' in col for col in summary_df.columns)
    
    if not has_magnitude or not has_clustering:
        print("\n⚠️  NOTE: Outlier magnitude and clustering metrics not found.")
        print("  The bag_summary.csv needs to be regenerated with the updated analysis.")
        print("  Run the cell below or: python scripts/generate_bag_summary.py")
        print("  Then re-run this cell to see outlier characteristics.")
# Out:
# Loading multi-bag summary from: bag_summary.csv
#
# ======================================================================
# MULTI-BAG SUMMARY STATISTICS
# ======================================================================
#
# 📊 DATASET OVERVIEW
#   Total bags analyzed: 46
#   Total recording time: 52.7 hours
#   Total samples: 54,347.0
#
# 🔧 SYSTEM AVAILABILITY
#   FFT: 23/46 bags (50.0%)
#   Sonar: 23/46 bags (50.0%)
#   DVL: 23/46 bags (50.0%)
#
# 📈 BASELINE SEGMENTS (Stable Data)
#   Avg baseline percentage: 8.1%
#   Median baseline percentage: 0.7%
#   Avg segments per bag: 2.8
#   Total baseline time: 0.1 hours
#
# 📏 DISTANCE MEASUREMENT NOISE (Baseline STD)
#   FFT: mean=0.1156m, median=0.1058m, min=0.0306m, max=0.2196m
#   SONAR: mean=0.0899m, median=0.0848m, min=0.0121m, max=0.1815m
#   DVL: mean=0.1121m, median=0.1227m, min=0.0175m, max=0.2246m
#
# 📐 PITCH MEASUREMENT NOISE (Baseline STD)
#   FFT: mean=6.6144°, median=5.9748°, min=1.9306°, max=20.0705°
#   SONAR: mean=3.5119°, median=3.4452°, min=0.5557°, max=6.2299°
#   DVL: mean=4.8225°, median=3.9342°, min=1.8718°, max=11.6527°
#
# 🧭 POSITION NOISE (Baseline STD)
#   X FFT: mean=0.1165m, median=0.1000m, min=0.0335m, max=0.2224m
#   X SONAR: mean=0.0892m, median=0.0845m, min=0.0113m, max=0.1831m
#   X DVL: mean=0.1168m, median=0.1327m, min=0.0142m, max=0.2292m
#   Y FFT: mean=0.1165m, median=0.1120m, min=0.0455m, max=0.2701m
#   Y SONAR: mean=0.0628m, median=0.0508m, min=0.0159m, max=0.1290m
#   Y DVL: mean=0.0722m, median=0.0668m, min=0.0352m, max=0.1519m
#
# ⚖️  PAIRWISE BIASES (Systematic Differences)
#   FFT vs DVL: mean=+0.0324m, median=+0.0382m, std=0.0510m
#   Sonar vs DVL: mean=-0.0438m, median=-0.0675m, std=0.0556m
#   FFT vs Sonar: mean=+0.0762m, median=+0.0935m, std=0.0606m
#
# 📉 LINEAR RELATIONSHIP QUALITY (R² scores)
#   Distance: FFT vs DVL: mean=0.5677, median=0.7420, min=0.0006
#   Distance: Sonar vs DVL: mean=0.5744, median=0.6172, min=0.0128
#   Pitch: FFT vs DVL: mean=0.0391, median=0.0215, min=0.0000
#   Pitch: Sonar vs DVL: mean=0.1758, median=0.1625, min=0.0008
#
# ⚠️  OUTLIER RATES
#   FFT: mean=21.29%, median=21.98%, max=36.72%
#   SONAR: mean=9.13%, median=9.13%, max=24.32%
#   DVL: mean=13.47%, median=12.53%, max=34.73%
#
# 📏 OUTLIER MAGNITUDE
#   FFT: mean=1.5386m, median=0.9579m, max=7.4226m
#   SONAR: mean=0.1059m, median=0.0906m, max=0.2703m
#   DVL: mean=0.2476m, median=0.1986m, max=0.8665m
#
# 🔗 OUTLIER CLUSTERING (Multi-frame events)
#   FFT: avg_cluster_size=12.3 frames, isolated=0.1%
#   SONAR: avg_cluster_size=13.7 frames, isolated=0.0%
#   DVL: avg_cluster_size=15.4 frames, isolated=0.0%
#
# 📊 OUTLIER MAGNITUDE CATEGORIES
#   FFT: small=33.1%, medium=33.9%, large=33.1%
#   SONAR: small=33.1%, medium=33.8%, large=33.1%
#   DVL: small=33.1%, medium=33.7%, large=33.1%
#
# 🏆 TOP 5 BAGS (by baseline percentage)
#   2024-08-20_17-02-00: 59.1% baseline, 2 segments
#   2024-08-20_17-08-14: 43.1% baseline, 7 segments
#   2024-08-20_15-00-24: 34.4% baseline, 7 segments
#   2024-08-20_13-57-42: 22.4% baseline, 5 segments
#   2024-08-20_17-40-54: 15.4% baseline, 6 segments
#
# ⚠️  BOTTOM 5 BAGS (by baseline percentage)
#   2024-08-20_13-39-34: 0.0% baseline, 0 segments
#   2024-08-20_13-40-35: 0.0% baseline, 0 segments
#   2024-08-20_13-42-51: 0.0% baseline, 0 segments
#   2024-08-20_13-55-34: 0.0% baseline, 0 segments
#   2024-08-20_14-22-12: 0.0% baseline, 0 segments
#
# ======================================================================
# ✓ Multi-bag summary complete
#   Full data available in: bag_summary.csv
#   Columns: 139
#
#   Column categories:
#     Metadata: 11
#     Distance metrics: 24
#     Pitch metrics: 24
#     X/Y position metrics: 12
#     Outlier metrics: 54
#     Correlation metrics: 0
#
# 📊 Additional insights:
#   DataFrame available for custom analysis
#   Example: summary_df[summary_df['baseline_percentage'] > 50]

# %% [markdown]
# ## Regenerate Multi-Bag Summary (Optional)
#
# Run this cell to regenerate the comprehensive bag summary CSV with all updated metrics including outlier characteristics.
